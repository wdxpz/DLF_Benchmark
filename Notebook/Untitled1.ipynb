# %%
from __future__ import print_function
import paddle
import paddle.fluid as fluid
import numpy as np
import sys
import math

CLASS_DIM = 2 #Number of categories for sentiment analysis
EMB_DIM = 64 #Dimensions of the word vector
HID_DIM = 64 #Dimensions of hide layer
STACKED_NUM = 2 #LSTM Layers of the bidirectional stack
BATCH_SIZE = 64 #batch size

# %%
#Textconvolution neural network
def convolution_net(data, input_dim, class_dim, emb_dim, hid_dim):
    emb = fluid.layers.embedding(
        input=data, size=[input_dim, emb_dim], is_sparse=True)
    conv_3 = fluid.nets.sequence_conv_pool(
        input=emb,
        num_filters=hid_dim,
        filter_size=3,
        act="tanh",
        pool_type="sqrt")
    conv_4 = fluid.nets.sequence_conv_pool(
        input=emb,
        num_filters=hid_dim,
        filter_size=4,
        act="tanh",
        pool_type="sqrt")
    prediction = fluid.layers.fc(
        input=[conv_3, conv_4], size=class_dim, act="softmax")
    return prediction

# %%
#Stack Bidirectional LSTM
def stacked_lstm_net(data, input_dim, class_dim, emb_dim, hid_dim, stacked_num):

    # Calculate word vectorvector
    emb = fluid.layers.embedding(input=data, size=[input_dim, emb_dim], is_sparse=True)

    #First stack
    #Fully connected layer
    fc1 = fluid.layers.fc(input=emb, size=hid_dim)
    #lstm layer
    lstm1, cell1 = fluid.layers.dynamic_lstm(input=fc1, size=hid_dim)

    inputs = [fc1, lstm1]

    #All remaining stack structures
    for i in range(2, stacked_num + 1):
        fc = fluid.layers.fc(input=inputs, size=hid_dim)
        lstm, cell = fluid.layers.dynamic_lstm(input=fc, size=hid_dim, is_reverse=(i % 2) == 0)
        inputs = [fc, lstm]

    #pooling layer
    pc_last = fluid.layers.sequence_pool(input=inputs[0], pool_type='max')
    lstm_last = fluid.layers.sequence_pool(input=inputs[1], pool_type='max')

    #Fully connected layer, softmax prediction
    prediction = fluid.layers.fc(
        input=[fc_last, lstm_last], size=class_dim, act='softmax')
    return prediction

# %%
def inference_program(word_dict):
    data = fluid.layers.data(
        name="words", shape=[1], dtype="int64", lod_level=1)

    dict_dim = len(word_dict)
    net = convolution_net(data, dict_dim, CLASS_DIM, EMB_DIM, HID_DIM)
    # net = stacked_lstm_net(data, dict_dim, CLASS_DIM, EMB_DIM, HID_DIM, STACKED_NUM)
    return net

# %%
def train_program(prediction):
    label = fluid.layers.data(name="label", shape=[1], dtype="int64")
    cost = fluid.layers.cross_entropy(input=prediction, label=label)
    avg_cost = fluid.layers.mean(cost)
    accuracy = fluid.layers.accuracy(input=prediction, label=label)
    return [avg_cost, accuracy] #return average cost and accuracy acc

#Optimization function
def optimizer_func():
    return fluid.optimizer.Adagrad(learning_rate=0.002)

# %%
use_cuda = True 
place = fluid.CUDAPlace(0) if use_cuda else fluid.CPUPlace()

# %%
print("Loading IMDB word dict....")
word_dict = paddle.dataset.imdb.word_dict()

print ("Reading training data....")
train_reader = paddle.batch(
    paddle.reader.shuffle(
        paddle.dataset.imdb.train(word_dict), buf_size=25000),
    batch_size=BATCH_SIZE)
print("Reading testing data....")
test_reader = paddle.batch(
    paddle.dataset.imdb.test(word_dict), batch_size=BATCH_SIZE)
# Out:
# Loading IMDB word dict....
# [==================================================]3563afcf9b574c7e56c153aCache file /root/.cache/paddle/dataset/imdb/aclImdb_v1.tar.gz not found, downloading http://ai.stanford.edu/%7Eamaas/data/sentiment/aclImdb_v1.tar.gz
# Reading training data....
# Reading testing data....

# %%
word_dict
# Out:
# {b'the': 0,
#  b'and': 1,
#  b'a': 2,
#  b'of': 3,
#  b'to': 4,
#  b'is': 5,
#  b'in': 6,
#  b'it': 7,
#  b'i': 8,
#  b'this': 9,
#  b'that': 10,
#  b'br': 11,
#  b'was': 12,
#  b'as': 13,
#  b'with': 14,
#  b'for': 15,
#  b'movie': 16,
#  b'but': 17,
#  b'film': 18,
#  b'on': 19,
#  b'not': 20,
#  b'you': 21,
#  b'are': 22,
#  b'his': 23,
#  b'have': 24,
#  b'be': 25,
#  b'he': 26,
#  b'one': 27,
#  b'its': 28,
#  b'at': 29,
#  b'all': 30,
#  b'by': 31,
#  b'an': 32,
#  b'they': 33,
#  b'from': 34,
#  b'who': 35,
#  b'so': 36,
#  b'like': 37,
#  b'or': 38,
#  b'just': 39,
#  b'her': 40,
#  b'about': 41,
#  b'if': 42,
#  b'has': 43,
#  b'out': 44,
#  b'some': 45,
#  b'there': 46,
#  b'what': 47,
#  b'good': 48,
#  b'when': 49,
#  b'more': 50,
#  b'very': 51,
#  b'my': 52,
#  b'even': 53,
#  b'no': 54,
#  b'up': 55,
#  b'would': 56,
#  b'she': 57,
#  b'time': 58,
#  b'only': 59,
#  b'which': 60,
#  b'really': 61,
#  b'their': 62,
#  b'see': 63,
#  b'were': 64,
#  b'story': 65,
#  b'had': 66,
#  b'can': 67,
#  b'me': 68,
#  b'than': 69,
#  b'we': 70,
#  b'much': 71,
#  b'well': 72,
#  b'been': 73,
#  b'get': 74,
#  b'will': 75,
#  b'other': 76,
#  b'do': 77,
#  b'great': 78,
#  b'also': 79,
#  b'into': 80,
#  b'bad': 81,
#  b'because': 82,
#  b'people': 83,
#  b'how': 84,
#  b'most': 85,
#  b'first': 86,
#  b'him': 87,
#  b'dont': 88,
#  b'then': 89,
#  b'movies': 90,
#  b'made': 91,
#  b'them': 92,
#  b'make': 93,
#  b'films': 94,
#  b'could': 95,
#  b'any': 96,
#  b'way': 97,
#  b'too': 98,
#  b'after': 99,
#  b'characters': 100,
#  b'think': 101,
#  b'watch': 102,
#  b'many': 103,
#  b'seen': 104,
#  b'being': 105,
#  b'two': 106,
#  b'character': 107,
#  b'never': 108,
#  b'love': 109,
#  b'acting': 110,
#  b'where': 111,
#  b'did': 112,
#  b'plot': 113,
#  b'little': 114,
#  b'best': 115,
#  b'know': 116,
#  b'show': 117,
#  b'life': 118,
#  b'ever': 119,
#  b'does': 120,
#  b'your': 121,
#  b'better': 122,
#  b'off': 123,
#  b'still': 124,
#  b'these': 125,
#  b'over': 126,
#  b'say': 127,
#  b'end': 128,
#  b'scene': 129,
#  b'man': 130,
#  b'why': 131,
#  b'while': 132,
#  b'scenes': 133,
#  b'here': 134,
#  b'such': 135,
#  b'something': 136,
#  b'go': 137,
#  b'should': 138,
#  b'through': 139,
#  b'im': 140,
#  b'those': 141,
#  b'back': 142,
#  b'real': 143,
#  b'watching': 144,
#  b'thing': 145,
#  b'doesnt': 146,
#  b'now': 147,
#  b'didnt': 148,
#  b'actors': 149,
#  b'years': 150,
#  b'another': 151,
#  b'though': 152,
#  b'actually': 153,
#  b'funny': 154,
#  b'before': 155,
#  b'makes': 156,
#  b'nothing': 157,
#  b'find': 158,
#  b'look': 159,
#  b'going': 160,
#  b'same': 161,
#  b'work': 162,
#  b'lot': 163,
#  b'new': 164,
#  b'every': 165,
#  b'few': 166,
#  b'old': 167,
#  b'us': 168,
#  b'part': 169,
#  b'cant': 170,
#  b'director': 171,
#  b'again': 172,
#  b'thats': 173,
#  b'want': 174,
#  b'quite': 175,
#  b'things': 176,
#  b'pretty': 177,
#  b'cast': 178,
#  b'seems': 179,
#  b'around': 180,
#  b'young': 181,
#  b'got': 182,
#  b'down': 183,
#  b'take': 184,
#  b'however': 185,
#  b'fact': 186,
#  b'world': 187,
#  b'enough': 188,
#  b'both': 189,
#  b'big': 190,
#  b'give': 191,
#  b'horror': 192,
#  b'thought': 193,
#  b'ive': 194,
#  b'may': 195,
#  b'between': 196,
#  b'own': 197,
#  b'without': 198,
#  b'long': 199,
#  b'saw': 200,
#  b'isnt': 201,
#  b'always': 202,
#  b'gets': 203,
#  b'right': 204,
#  b'music': 205,
#  b'almost': 206,
#  b'original': 207,
#  b'must': 208,
#  b'come': 209,
#  b'theres': 210,
#  b'series': 211,
#  b'comedy': 212,
#  b'times': 213,
#  b'whole': 214,
#  b'role': 215,
#  b'least': 216,
#  b'interesting': 217,
#  b'guy': 218,
#  b'action': 219,
#  b'point': 220,
#  b'bit': 221,
#  b'done': 222,
#  b'far': 223,
#  b'might': 224,
#  b'am': 225,
#  b'hes': 226,
#  b'minutes': 227,
#  b'script': 228,
#  b'feel': 229,
#  b'since': 230,
#  b'anything': 231,
#  b'last': 232,
#  b'probably': 233,
#  b'family': 234,
#  b'kind': 235,
#  b'performance': 236,
#  b'tv': 237,
#  b'yet': 238,
#  b'away': 239,
#  b'rather': 240,
#  b'worst': 241,
#  b'sure': 242,
#  b'each': 243,
#  b'anyone': 244,
#  b'fun': 245,
#  b'found': 246,
#  b'played': 247,
#  b'our': 248,
#  b'girl': 249,
#  b'making': 250,
#  b'believe': 251,
#  b'although': 252,
#  b'woman': 253,
#  b'having': 254,
#  b'trying': 255,
#  b'shows': 256,
#  b'especially': 257,
#  b'course': 258,
#  b'comes': 259,
#  b'hard': 260,
#  b'goes': 261,
#  b'everything': 262,
#  b'put': 263,
#  b'day': 264,
#  b'worth': 265,
#  b'maybe': 266,
#  b'looking': 267,
#  b'main': 268,
#  b'different': 269,
#  b'dvd': 270,
#  b'ending': 271,
#  b'place': 272,
#  b'looks': 273,
#  b'wasnt': 274,
#  b'once': 275,
#  b'book': 276,
#  b'watched': 277,
#  b'three': 278,
#  b'reason': 279,
#  b'sense': 280,
#  b'set': 281,
#  b'2': 282,
#  b'screen': 283,
#  b'someone': 284,
#  b'true': 285,
#  b'effects': 286,
#  b'plays': 287,
#  b'play': 288,
#  b'job': 289,
#  b'money': 290,
#  b'during': 291,
#  b'together': 292,
#  b'actor': 293,
#  b'said': 294,
#  b'takes': 295,
#  b'seem': 296,
#  b'10': 297,
#  b'everyone': 298,
#  b'instead': 299,
#  b'american': 300,
#  b'later': 301,
#  b'special': 302,
#  b'beautiful': 303,
#  b'seeing': 304,
#  b'left': 305,
#  b'john': 306,
#  b'audience': 307,
#  b'himself': 308,
#  b'war': 309,
#  b'excellent': 310,
#  b'version': 311,
#  b'idea': 312,
#  b'night': 313,
#  b'shot': 314,
#  b'black': 315,
#  b'simply': 316,
#  b'youre': 317,
#  b'high': 318,
#  b'fan': 319,
#  b'completely': 320,
#  b'used': 321,
#  b'nice': 322,
#  b'house': 323,
#  b'poor': 324,
#  b'read': 325,
#  b'else': 326,
#  b'wife': 327,
#  b'death': 328,
#  b'kids': 329,
#  b'along': 330,
#  b'short': 331,
#  b'friends': 332,
#  b'help': 333,
#  b'second': 334,
#  b'men': 335,
#  b'mind': 336,
#  b'given': 337,
#  b'use': 338,
#  b'less': 339,
#  b'star': 340,
#  b'try': 341,
#  b'need': 342,
#  b'home': 343,
#  b'enjoy': 344,
#  b'half': 345,
#  b'boring': 346,
#  b'year': 347,
#  b'truly': 348,
#  b'until': 349,
#  b'either': 350,
#  b'classic': 351,
#  b'rest': 352,
#  b'next': 353,
#  b'performances': 354,
#  b'dead': 355,
#  b'recommend': 356,
#  b'production': 357,
#  b'couple': 358,
#  b'wrong': 359,
#  b'stupid': 360,
#  b'hollywood': 361,
#  b'line': 362,
#  b'father': 363,
#  b'start': 364,
#  b'tell': 365,
#  b'let': 366,
#  b'came': 367,
#  b'getting': 368,
#  b'women': 369,
#  b'full': 370,
#  b'remember': 371,
#  b'understand': 372,
#  b'perhaps': 373,
#  b'school': 374,
#  b'keep': 375,
#  b'terrible': 376,
#  b'camera': 377,
#  b'awful': 378,
#  b'others': 379,
#  b'sex': 380,
#  b'moments': 381,
#  b'mean': 382,
#  b'wonderful': 383,
#  b'playing': 384,
#  b'video': 385,
#  b'definitely': 386,
#  b'name': 387,
#  b'itself': 388,
#  b'human': 389,
#  b'gives': 390,
#  b'often': 391,
#  b'episode': 392,
#  b'doing': 393,
#  b'small': 394,
#  b'budget': 395,
#  b'couldnt': 396,
#  b'perfect': 397,
#  b'early': 398,
#  b'person': 399,
#  b'top': 400,
#  b'went': 401,
#  b'absolutely': 402,
#  b'lines': 403,
#  b'dialogue': 404,
#  b'finally': 405,
#  b'piece': 406,
#  b'face': 407,
#  b'guys': 408,
#  b'certainly': 409,
#  b'become': 410,
#  b'liked': 411,
#  b'stars': 412,
#  b'title': 413,
#  b'case': 414,
#  b'loved': 415,
#  b'head': 416,
#  b'sort': 417,
#  b'hope': 418,
#  b'yes': 419,
#  b'entire': 420,
#  b'felt': 421,
#  b'supposed': 422,
#  b'several': 423,
#  b'lost': 424,
#  b'overall': 425,
#  b'written': 426,
#  b'live': 427,
#  b'style': 428,
#  b'mother': 429,
#  b'entertaining': 430,
#  b'worse': 431,
#  b'3': 432,
#  b'picture': 433,
#  b'against': 434,
#  b'laugh': 435,
#  b'waste': 436,
#  b'boy': 437,
#  b'problem': 438,
#  b'sound': 439,
#  b'mr': 440,
#  b'oh': 441,
#  b'totally': 442,
#  b'based': 443,
#  b'friend': 444,
#  b'shes': 445,
#  b'beginning': 446,
#  b'seemed': 447,
#  b'wanted': 448,
#  b'cinema': 449,
#  b'dark': 450,
#  b'id': 451,
#  b'despite': 452,
#  b'fans': 453,
#  b'final': 454,
#  b'care': 455,
#  b'becomes': 456,
#  b'already': 457,
#  b'wont': 458,
#  b'humor': 459,
#  b'youll': 460,
#  b'lead': 461,
#  b'direction': 462,
#  b'example': 463,
#  b'guess': 464,
#  b'children': 465,
#  b'evil': 466,
#  b'throughout': 467,
#  b'called': 468,
#  b'lives': 469,
#  b'turn': 470,
#  b'unfortunately': 471,
#  b'able': 472,
#  b'low': 473,
#  b'game': 474,
#  b'drama': 475,
#  b'white': 476,
#  b'wants': 477,
#  b'1': 478,
#  b'girls': 479,
#  b'days': 480,
#  b'fine': 481,
#  b'under': 482,
#  b'\xc2\x96': 483,
#  b'quality': 484,
#  b'horrible': 485,
#  b'theyre': 486,
#  b'amazing': 487,
#  b'writing': 488,
#  b'history': 489,
#  b'tries': 490,
#  b'michael': 491,
#  b'works': 492,
#  b'gave': 493,
#  b'kill': 494,
#  b'turns': 495,
#  b'enjoyed': 496,
#  b'killer': 497,
#  b'act': 498,
#  b'favorite': 499,
#  b'side': 500,
#  b'son': 501,
#  b'parts': 502,
#  b'past': 503,
#  b'flick': 504,
#  b'behind': 505,
#  b'expect': 506,
#  b'matter': 507,
#  b'brilliant': 508,
#  b'obviously': 509,
#  b'car': 510,
#  b'run': 511,
#  b'town': 512,
#  b'eyes': 513,
#  b'starts': 514,
#  b'stuff': 515,
#  b'ones': 516,
#  b'sometimes': 517,
#  b'directed': 518,
#  b'myself': 519,
#  b'killed': 520,
#  b'soon': 521,
#  b'themselves': 522,
#  b'viewer': 523,
#  b'thinking': 524,
#  b'says': 525,
#  b'took': 526,
#  b'highly': 527,
#  b'group': 528,
#  b'decent': 529,
#  b'ill': 530,
#  b'actress': 531,
#  b'heart': 532,
#  b'late': 533,
#  b'art': 534,
#  b'city': 535,
#  b'heard': 536,
#  b'genre': 537,
#  b'happens': 538,
#  b'feeling': 539,
#  b'kid': 540,
#  b'except': 541,
#  b'hell': 542,
#  b'fight': 543,
#  b'child': 544,
#  b'extremely': 545,
#  b'leave': 546,
#  b'wouldnt': 547,
#  b'lack': 548,
#  b'cannot': 549,
#  b'told': 550,
#  b'blood': 551,
#  b'close': 552,
#  b'police': 553,
#  b'coming': 554,
#  b'hour': 555,
#  b'experience': 556,
#  b'moment': 557,
#  b'etc': 558,
#  b'save': 559,
#  b'looked': 560,
#  b'wonder': 561,
#  b'stories': 562,
#  b'score': 563,
#  b'strong': 564,
#  b'involved': 565,
#  b'particularly': 566,
#  b'hand': 567,
#  b'chance': 568,
#  b'type': 569,
#  b'daughter': 570,
#  b'living': 571,
#  b'including': 572,
#  b'attempt': 573,
#  b'complete': 574,
#  b'ok': 575,
#  b'anyway': 576,
#  b'god': 577,
#  b'taken': 578,
#  b'shown': 579,
#  b'itbr': 580,
#  b'violence': 581,
#  b'serious': 582,
#  b'james': 583,
#  b'simple': 584,
#  b'obvious': 585,
#  b'roles': 586,
#  b'hilarious': 587,
#  b'stop': 588,
#  b'happened': 589,
#  b'happen': 590,
#  b'robert': 591,
#  b'cool': 592,
#  b'david': 593,
#  b'murder': 594,
#  b'across': 595,
#  b'voice': 596,
#  b'lets': 597,
#  b'please': 598,
#  b'known': 599,
#  b'exactly': 600,
#  b'opening': 601,
#  b'song': 602,
#  b'usually': 603,
#  b'ago': 604,
#  b'number': 605,
#  b'released': 606,
#  b'saying': 607,
#  b'slow': 608,
#  b'huge': 609,
#  b'wish': 610,
#  b'none': 611,
#  b'seriously': 612,
#  b'jokes': 613,
#  b'reality': 614,
#  b'whose': 615,
#  b'cinematography': 616,
#  b'interest': 617,
#  b'english': 618,
#  b'hours': 619,
#  b'order': 620,
#  b'sad': 621,
#  b'possible': 622,
#  b'relationship': 623,
#  b'crap': 624,
#  b'hit': 625,
#  b'alone': 626,
#  b'running': 627,
#  b'4': 628,
#  b'major': 629,
#  b'shots': 630,
#  b'cut': 631,
#  b'today': 632,
#  b'annoying': 633,
#  b'gore': 634,
#  b'talent': 635,
#  b'call': 636,
#  b'started': 637,
#  b'age': 638,
#  b'yourself': 639,
#  b'5': 640,
#  b'taking': 641,
#  b'career': 642,
#  b'female': 643,
#  b'brother': 644,
#  b'somewhat': 645,
#  b'ridiculous': 646,
#  b'mostly': 647,
#  b'beyond': 648,
#  b'ends': 649,
#  b'hero': 650,
#  b'knew': 651,
#  b'usual': 652,
#  b'important': 653,
#  b'change': 654,
#  b'view': 655,
#  b'documentary': 656,
#  b'knows': 657,
#  b'body': 658,
#  b'turned': 659,
#  b'finds': 660,
#  b'apparently': 661,
#  b'power': 662,
#  b'basically': 663,
#  b'opinion': 664,
#  b'words': 665,
#  b'silly': 666,
#  b'due': 667,
#  b'strange': 668,
#  b'word': 669,
#  b'novel': 670,
#  b'upon': 671,
#  b'talking': 672,
#  b'husband': 673,
#  b'clearly': 674,
#  b'scary': 675,
#  b'local': 676,
#  b'directors': 677,
#  b'happy': 678,
#  b'rating': 679,
#  b'attention': 680,
#  b'four': 681,
#  b'whats': 682,
#  b'cheap': 683,
#  b'episodes': 684,
#  b'country': 685,
#  b'musical': 686,
#  b'arent': 687,
#  b'moviebr': 688,
#  b'level': 689,
#  b'room': 690,
#  b'problems': 691,
#  b'single': 692,
#  b'disappointed': 693,
#  b'jack': 694,
#  b'television': 695,
#  b'british': 696,
#  b'tells': 697,
#  b'events': 698,
#  b'miss': 699,
#  b'sequence': 700,
#  b'talk': 701,
#  b'modern': 702,
#  b'whether': 703,
#  b'add': 704,
#  b'light': 705,
#  b'songs': 706,
#  b'french': 707,
#  b'easily': 708,
#  b'lots': 709,
#  b'appears': 710,
#  b'bring': 711,
#  b'sets': 712,
#  b'predictable': 713,
#  b'giving': 714,
#  b'havent': 715,
#  b'review': 716,
#  b'supporting': 717,
#  b'dialog': 718,
#  b'mention': 719,
#  b'similar': 720,
#  b'falls': 721,
#  b'george': 722,
#  b'ten': 723,
#  b'soundtrack': 724,
#  b'viewers': 725,
#  b'above': 726,
#  b'needs': 727,
#  b'romantic': 728,
#  b'five': 729,
#  b'bunch': 730,
#  b'team': 731,
#  b'within': 732,
#  b'certain': 733,
#  b'enjoyable': 734,
#  b'showing': 735,
#  b'hate': 736,
#  b'filmbr': 737,
#  b'future': 738,
#  b'moving': 739,
#  b'entertainment': 740,
#  b'tried': 741,
#  b'message': 742,
#  b'surprised': 743,
#  b'parents': 744,
#  b'earth': 745,
#  b'comic': 746,
#  b'among': 747,
#  b'clear': 748,
#  b'filmed': 749,
#  b'space': 750,
#  b'storyline': 751,
#  b'middle': 752,
#  b'sorry': 753,
#  b'dull': 754,
#  b'named': 755,
#  b'fall': 756,
#  b'theme': 757,
#  b'stay': 758,
#  b'easy': 759,
#  b'king': 760,
#  b'sequel': 761,
#  b'using': 762,
#  b'theater': 763,
#  b'typical': 764,
#  b'comments': 765,
#  b'ways': 766,
#  b'feels': 767,
#  b'near': 768,
#  b'kept': 769,
#  b'release': 770,
#  b'buy': 771,
#  b'thriller': 772,
#  b'gone': 773,
#  b'greatest': 774,
#  b'writer': 775,
#  b'nearly': 776,
#  b'working': 777,
#  b'doubt': 778,
#  b'effort': 779,
#  b'actual': 780,
#  b'avoid': 781,
#  b'deal': 782,
#  b'elements': 783,
#  b'means': 784,
#  b'monster': 785,
#  b'dr': 786,
#  b'peter': 787,
#  b'richard': 788,
#  b'tale': 789,
#  b'imagine': 790,
#  b'suspense': 791,
#  b'fantastic': 792,
#  b'subject': 793,
#  b'brought': 794,
#  b'straight': 795,
#  b'editing': 796,
#  b'80s': 797,
#  b'rock': 798,
#  b'youve': 799,
#  b'famous': 800,
#  b'die': 801,
#  b'lady': 802,
#  b'boys': 803,
#  b'herself': 804,
#  b'realistic': 805,
#  b'points': 806,
#  b'sister': 807,
#  b'general': 808,
#  b'leads': 809,
#  b'feature': 810,
#  b'viewing': 811,
#  b'move': 812,
#  b'somehow': 813,
#  b'check': 814,
#  b'class': 815,
#  b'okay': 816,
#  b'form': 817,
#  b'forget': 818,
#  b'mystery': 819,
#  b'reviews': 820,
#  b'begins': 821,
#  b'hear': 822,
#  b'material': 823,
#  b'rent': 824,
#  b'dog': 825,
#  b'eventually': 826,
#  b'learn': 827,
#  b'paul': 828,
#  b'sit': 829,
#  b'animation': 830,
#  b'whos': 831,
#  b'figure': 832,
#  b'tom': 833,
#  b'particular': 834,
#  b'weak': 835,
#  b'premise': 836,
#  b'surprise': 837,
#  b'period': 838,
#  b'believable': 839,
#  b'killing': 840,
#  b'sequences': 841,
#  b'decided': 842,
#  b'expected': 843,
#  b'red': 844,
#  b'atmosphere': 845,
#  b'crime': 846,
#  b'wait': 847,
#  b'fast': 848,
#  b'eye': 849,
#  b'difficult': 850,
#  b'york': 851,
#  b'deep': 852,
#  b'indeed': 853,
#  b'leaves': 854,
#  b'possibly': 855,
#  b'became': 856,
#  b'truth': 857,
#  b'average': 858,
#  b'emotional': 859,
#  b'poorly': 860,
#  b'shame': 861,
#  b'lame': 862,
#  b'situation': 863,
#  b'follow': 864,
#  b'whatever': 865,
#  b'forced': 866,
#  b'meet': 867,
#  b'dance': 868,
#  b'stand': 869,
#  b'needed': 870,
#  b'footage': 871,
#  b'note': 872,
#  b'unless': 873,
#  b'season': 874,
#  b'begin': 875,
#  b'memorable': 876,
#  b'open': 877,
#  b'third': 878,
#  b'crew': 879,
#  b'reading': 880,
#  b'scifi': 881,
#  b'oscar': 882,
#  b'minute': 883,
#  b'sexual': 884,
#  b'otherwise': 885,
#  b'features': 886,
#  b'meets': 887,
#  b'writers': 888,
#  b'write': 889,
#  b'doctor': 890,
#  b'previous': 891,
#  b'filmmakers': 892,
#  b'question': 893,
#  b'interested': 894,
#  b'whom': 895,
#  b'romance': 896,
#  b'beauty': 897,
#  b'nor': 898,
#  b'cheesy': 899,
#  b'credits': 900,
#  b'gay': 901,
#  b'imdb': 902,
#  b'personal': 903,
#  b'hot': 904,
#  b'total': 905,
#  b'keeps': 906,
#  b'superb': 907,
#  b'towards': 908,
#  b'western': 909,
#  b'inside': 910,
#  b'sounds': 911,
#  b'nature': 912,
#  b'hands': 913,
#  b'plus': 914,
#  b'male': 915,
#  b'society': 916,
#  b'incredibly': 917,
#  b'perfectly': 918,
#  b'screenplay': 919,
#  b'de': 920,
#  b'japanese': 921,
#  b'comment': 922,
#  b'20': 923,
#  b'quickly': 924,
#  b'box': 925,
#  b'weird': 926,
#  b'result': 927,
#  b'effect': 928,
#  b'realize': 929,
#  b'battle': 930,
#  b'island': 931,
#  b'street': 932,
#  b'masterpiece': 933,
#  b'badly': 934,
#  b'worked': 935,
#  b'laughs': 936,
#  b'earlier': 937,
#  b'various': 938,
#  b'unique': 939,
#  b'copy': 940,
#  b'older': 941,
#  b'crazy': 942,
#  b'america': 943,
#  b'brings': 944,
#  b'air': 945,
#  b'background': 946,
#  b'plenty': 947,
#  b'stage': 948,
#  b'setting': 949,
#  b'appear': 950,
#  b'b': 951,
#  b'free': 952,
#  b'admit': 953,
#  b'ask': 954,
#  b'fairly': 955,
#  b'following': 956,
#  b'lee': 957,
#  b'powerful': 958,
#  b'joe': 959,
#  b'mark': 960,
#  b'spent': 961,
#  b'leading': 962,
#  b'portrayed': 963,
#  b'directing': 964,
#  b'front': 965,
#  b'business': 966,
#  b'creepy': 967,
#  b'dramatic': 968,
#  b'acted': 969,
#  b'forward': 970,
#  b'apart': 971,
#  b'rich': 972,
#  b'baby': 973,
#  b'outside': 974,
#  b'pay': 975,
#  b'remake': 976,
#  b'bill': 977,
#  b'development': 978,
#  b'mess': 979,
#  b'dumb': 980,
#  b'meant': 981,
#  b'deserves': 982,
#  b'attempts': 983,
#  b'manages': 984,
#  b'fire': 985,
#  b'political': 986,
#  b'la': 987,
#  b'expecting': 988,
#  b'fails': 989,
#  b'william': 990,
#  b'water': 991,
#  b'wasted': 992,
#  b'70s': 993,
#  b'create': 994,
#  b'joke': 995,
#  b'ideas': 996,
#  b'return': 997,
#  b'reasons': 998,
#  b'cover': 999,
#  ...}

# %%
exe = fluid.Executor(place)
prediction = inference_program(word_dict)
[avg_cost, accuracy] = train_program(prediction)#training program
sgd_optimizer = optimizer_func()# training optimization function
sgd_optimizer.minimize(avg_cost)
# Out:
# ([inputs {
#     parameter: "Grad"
#     arguments: "embedding_0.w_0@GRAD"
#   }
#   inputs {
#     parameter: "LearningRate"
#     arguments: "learning_rate_0"
#   }
#   inputs {
#     parameter: "Moment"
#     arguments: "embedding_0.w_0_moment_0"
#   }
#   inputs {
#     parameter: "Param"
#     arguments: "embedding_0.w_0"
#   }
#   outputs {
#     parameter: "MomentOut"
#     arguments: "embedding_0.w_0_moment_0"
#   }
#   outputs {
#     parameter: "ParamOut"
#     arguments: "embedding_0.w_0"
#   }
#   type: "adagrad"
#   attrs {
#     name: "op_callstack"
#     type: STRINGS
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/framework.py\", line 1748, in append_op\n    attrs=kwargs.get(\"attrs\", None))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 1228, in _append_optimize_op\n    stop_gradient=True)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 386, in _create_optimization_pass\n    param_and_grad)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 531, in apply_gradients\n    optimize_ops = self._create_optimization_pass(params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 561, in apply_optimize\n    optimize_ops = self.apply_gradients(params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 600, in minimize\n    loss, startup_program=startup_program, params_grads=params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/dygraph/base.py\", line 88, in __impl__\n    return func(*args, **kwargs)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/wrapped_decorator.py\", line 25, in __impl__\n    return wrapped_func(*args, **kwargs)\n"
#     strings: "  File \"</usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-145>\", line 2, in minimize\n"
#     strings: "  File \"<ipython-input-9-8a35697e7cc6>\", line 5, in <module>\n    sgd_optimizer.minimize(avg_cost)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3296, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3220, in run_ast_nodes\n    if (yield from self.run_code(code, result)):\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3049, in run_cell_async\n    interactivity=interactivity, compiler=compiler, result=result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/async_helpers.py\", line 67, in _pseudo_sync_runner\n    coro.send(None)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 2874, in _run_cell\n    return runner(coro)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 2848, in run_cell\n    raw_cell, store_history, silent, shell_futures)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py\", line 536, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py\", line 294, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 542, in execute_request\n    user_expressions, allow_stdin,\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 272, in dispatch_shell\n    yield gen.maybe_future(handler(stream, idents, msg))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 365, in process_one\n    yield gen.maybe_future(dispatch(*args))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 742, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 708, in __init__\n    self.run()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 225, in wrapper\n    runner = Runner(result, future, yielded)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 378, in dispatch_queue\n    yield self.process_one()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 742, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 781, in inner\n    self.run()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py\", line 743, in _run_callback\n    ret = callback()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py\", line 690, in <lambda>\n    lambda f: self._run_callback(functools.partial(callback, future))\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/events.py\", line 145, in _run\n    self._callback(*self._args)\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/base_events.py\", line 1451, in _run_once\n    handle._run()\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/base_events.py\", line 438, in run_forever\n    self._run_once()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/platform/asyncio.py\", line 148, in start\n    self.asyncio_loop.run_forever()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py\", line 505, in start\n    self.io_loop.start()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py\", line 658, in launch_instance\n    app.start()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py\", line 16, in <module>\n    app.launch_new_instance()\n"
#     strings: "  File \"/usr/lib/python3.6/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n"
#     strings: "  File \"/usr/lib/python3.6/runpy.py\", line 193, in _run_module_as_main\n    \"__main__\", mod_spec)\n"
#   }
#   attrs {
#     name: "op_namescope"
#     type: STRING
#     s: "/optimizer/"
#   }
#   attrs {
#     name: "op_role_var"
#     type: STRINGS
#     strings: "embedding_0.w_0"
#     strings: "embedding_0.w_0@GRAD"
#   }
#   attrs {
#     name: "op_role"
#     type: INT
#     i: 2
#   }
#   attrs {
#     name: "epsilon"
#     type: FLOAT
#     f: 9.999999974752427e-07
#   }, inputs {
#     parameter: "Grad"
#     arguments: "fc_0.b_0@GRAD"
#   }
#   inputs {
#     parameter: "LearningRate"
#     arguments: "learning_rate_0"
#   }
#   inputs {
#     parameter: "Moment"
#     arguments: "fc_0.b_0_moment_0"
#   }
#   inputs {
#     parameter: "Param"
#     arguments: "fc_0.b_0"
#   }
#   outputs {
#     parameter: "MomentOut"
#     arguments: "fc_0.b_0_moment_0"
#   }
#   outputs {
#     parameter: "ParamOut"
#     arguments: "fc_0.b_0"
#   }
#   type: "adagrad"
#   attrs {
#     name: "op_callstack"
#     type: STRINGS
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/framework.py\", line 1748, in append_op\n    attrs=kwargs.get(\"attrs\", None))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 1228, in _append_optimize_op\n    stop_gradient=True)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 386, in _create_optimization_pass\n    param_and_grad)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 531, in apply_gradients\n    optimize_ops = self._create_optimization_pass(params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 561, in apply_optimize\n    optimize_ops = self.apply_gradients(params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 600, in minimize\n    loss, startup_program=startup_program, params_grads=params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/dygraph/base.py\", line 88, in __impl__\n    return func(*args, **kwargs)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/wrapped_decorator.py\", line 25, in __impl__\n    return wrapped_func(*args, **kwargs)\n"
#     strings: "  File \"</usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-145>\", line 2, in minimize\n"
#     strings: "  File \"<ipython-input-9-8a35697e7cc6>\", line 5, in <module>\n    sgd_optimizer.minimize(avg_cost)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3296, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3220, in run_ast_nodes\n    if (yield from self.run_code(code, result)):\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3049, in run_cell_async\n    interactivity=interactivity, compiler=compiler, result=result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/async_helpers.py\", line 67, in _pseudo_sync_runner\n    coro.send(None)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 2874, in _run_cell\n    return runner(coro)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 2848, in run_cell\n    raw_cell, store_history, silent, shell_futures)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py\", line 536, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py\", line 294, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 542, in execute_request\n    user_expressions, allow_stdin,\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 272, in dispatch_shell\n    yield gen.maybe_future(handler(stream, idents, msg))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 365, in process_one\n    yield gen.maybe_future(dispatch(*args))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 742, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 708, in __init__\n    self.run()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 225, in wrapper\n    runner = Runner(result, future, yielded)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 378, in dispatch_queue\n    yield self.process_one()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 742, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 781, in inner\n    self.run()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py\", line 743, in _run_callback\n    ret = callback()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py\", line 690, in <lambda>\n    lambda f: self._run_callback(functools.partial(callback, future))\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/events.py\", line 145, in _run\n    self._callback(*self._args)\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/base_events.py\", line 1451, in _run_once\n    handle._run()\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/base_events.py\", line 438, in run_forever\n    self._run_once()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/platform/asyncio.py\", line 148, in start\n    self.asyncio_loop.run_forever()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py\", line 505, in start\n    self.io_loop.start()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py\", line 658, in launch_instance\n    app.start()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py\", line 16, in <module>\n    app.launch_new_instance()\n"
#     strings: "  File \"/usr/lib/python3.6/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n"
#     strings: "  File \"/usr/lib/python3.6/runpy.py\", line 193, in _run_module_as_main\n    \"__main__\", mod_spec)\n"
#   }
#   attrs {
#     name: "op_namescope"
#     type: STRING
#     s: "/optimizer_1/"
#   }
#   attrs {
#     name: "op_role_var"
#     type: STRINGS
#     strings: "fc_0.b_0"
#     strings: "fc_0.b_0@GRAD"
#   }
#   attrs {
#     name: "op_role"
#     type: INT
#     i: 2
#   }
#   attrs {
#     name: "epsilon"
#     type: FLOAT
#     f: 9.999999974752427e-07
#   }, inputs {
#     parameter: "Grad"
#     arguments: "fc_0.w_0@GRAD"
#   }
#   inputs {
#     parameter: "LearningRate"
#     arguments: "learning_rate_0"
#   }
#   inputs {
#     parameter: "Moment"
#     arguments: "fc_0.w_0_moment_0"
#   }
#   inputs {
#     parameter: "Param"
#     arguments: "fc_0.w_0"
#   }
#   outputs {
#     parameter: "MomentOut"
#     arguments: "fc_0.w_0_moment_0"
#   }
#   outputs {
#     parameter: "ParamOut"
#     arguments: "fc_0.w_0"
#   }
#   type: "adagrad"
#   attrs {
#     name: "op_callstack"
#     type: STRINGS
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/framework.py\", line 1748, in append_op\n    attrs=kwargs.get(\"attrs\", None))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 1228, in _append_optimize_op\n    stop_gradient=True)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 386, in _create_optimization_pass\n    param_and_grad)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 531, in apply_gradients\n    optimize_ops = self._create_optimization_pass(params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 561, in apply_optimize\n    optimize_ops = self.apply_gradients(params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 600, in minimize\n    loss, startup_program=startup_program, params_grads=params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/dygraph/base.py\", line 88, in __impl__\n    return func(*args, **kwargs)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/wrapped_decorator.py\", line 25, in __impl__\n    return wrapped_func(*args, **kwargs)\n"
#     strings: "  File \"</usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-145>\", line 2, in minimize\n"
#     strings: "  File \"<ipython-input-9-8a35697e7cc6>\", line 5, in <module>\n    sgd_optimizer.minimize(avg_cost)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3296, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3220, in run_ast_nodes\n    if (yield from self.run_code(code, result)):\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3049, in run_cell_async\n    interactivity=interactivity, compiler=compiler, result=result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/async_helpers.py\", line 67, in _pseudo_sync_runner\n    coro.send(None)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 2874, in _run_cell\n    return runner(coro)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 2848, in run_cell\n    raw_cell, store_history, silent, shell_futures)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py\", line 536, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py\", line 294, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 542, in execute_request\n    user_expressions, allow_stdin,\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 272, in dispatch_shell\n    yield gen.maybe_future(handler(stream, idents, msg))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 365, in process_one\n    yield gen.maybe_future(dispatch(*args))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 742, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 708, in __init__\n    self.run()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 225, in wrapper\n    runner = Runner(result, future, yielded)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 378, in dispatch_queue\n    yield self.process_one()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 742, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 781, in inner\n    self.run()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py\", line 743, in _run_callback\n    ret = callback()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py\", line 690, in <lambda>\n    lambda f: self._run_callback(functools.partial(callback, future))\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/events.py\", line 145, in _run\n    self._callback(*self._args)\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/base_events.py\", line 1451, in _run_once\n    handle._run()\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/base_events.py\", line 438, in run_forever\n    self._run_once()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/platform/asyncio.py\", line 148, in start\n    self.asyncio_loop.run_forever()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py\", line 505, in start\n    self.io_loop.start()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py\", line 658, in launch_instance\n    app.start()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py\", line 16, in <module>\n    app.launch_new_instance()\n"
#     strings: "  File \"/usr/lib/python3.6/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n"
#     strings: "  File \"/usr/lib/python3.6/runpy.py\", line 193, in _run_module_as_main\n    \"__main__\", mod_spec)\n"
#   }
#   attrs {
#     name: "op_namescope"
#     type: STRING
#     s: "/optimizer_2/"
#   }
#   attrs {
#     name: "op_role_var"
#     type: STRINGS
#     strings: "fc_0.w_0"
#     strings: "fc_0.w_0@GRAD"
#   }
#   attrs {
#     name: "op_role"
#     type: INT
#     i: 2
#   }
#   attrs {
#     name: "epsilon"
#     type: FLOAT
#     f: 9.999999974752427e-07
#   }, inputs {
#     parameter: "Grad"
#     arguments: "fc_0.w_1@GRAD"
#   }
#   inputs {
#     parameter: "LearningRate"
#     arguments: "learning_rate_0"
#   }
#   inputs {
#     parameter: "Moment"
#     arguments: "fc_0.w_1_moment_0"
#   }
#   inputs {
#     parameter: "Param"
#     arguments: "fc_0.w_1"
#   }
#   outputs {
#     parameter: "MomentOut"
#     arguments: "fc_0.w_1_moment_0"
#   }
#   outputs {
#     parameter: "ParamOut"
#     arguments: "fc_0.w_1"
#   }
#   type: "adagrad"
#   attrs {
#     name: "op_callstack"
#     type: STRINGS
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/framework.py\", line 1748, in append_op\n    attrs=kwargs.get(\"attrs\", None))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 1228, in _append_optimize_op\n    stop_gradient=True)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 386, in _create_optimization_pass\n    param_and_grad)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 531, in apply_gradients\n    optimize_ops = self._create_optimization_pass(params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 561, in apply_optimize\n    optimize_ops = self.apply_gradients(params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 600, in minimize\n    loss, startup_program=startup_program, params_grads=params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/dygraph/base.py\", line 88, in __impl__\n    return func(*args, **kwargs)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/wrapped_decorator.py\", line 25, in __impl__\n    return wrapped_func(*args, **kwargs)\n"
#     strings: "  File \"</usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-145>\", line 2, in minimize\n"
#     strings: "  File \"<ipython-input-9-8a35697e7cc6>\", line 5, in <module>\n    sgd_optimizer.minimize(avg_cost)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3296, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3220, in run_ast_nodes\n    if (yield from self.run_code(code, result)):\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3049, in run_cell_async\n    interactivity=interactivity, compiler=compiler, result=result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/async_helpers.py\", line 67, in _pseudo_sync_runner\n    coro.send(None)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 2874, in _run_cell\n    return runner(coro)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 2848, in run_cell\n    raw_cell, store_history, silent, shell_futures)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py\", line 536, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py\", line 294, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 542, in execute_request\n    user_expressions, allow_stdin,\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 272, in dispatch_shell\n    yield gen.maybe_future(handler(stream, idents, msg))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 365, in process_one\n    yield gen.maybe_future(dispatch(*args))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 742, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 708, in __init__\n    self.run()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 225, in wrapper\n    runner = Runner(result, future, yielded)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 378, in dispatch_queue\n    yield self.process_one()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 742, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 781, in inner\n    self.run()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py\", line 743, in _run_callback\n    ret = callback()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py\", line 690, in <lambda>\n    lambda f: self._run_callback(functools.partial(callback, future))\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/events.py\", line 145, in _run\n    self._callback(*self._args)\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/base_events.py\", line 1451, in _run_once\n    handle._run()\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/base_events.py\", line 438, in run_forever\n    self._run_once()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/platform/asyncio.py\", line 148, in start\n    self.asyncio_loop.run_forever()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py\", line 505, in start\n    self.io_loop.start()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py\", line 658, in launch_instance\n    app.start()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py\", line 16, in <module>\n    app.launch_new_instance()\n"
#     strings: "  File \"/usr/lib/python3.6/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n"
#     strings: "  File \"/usr/lib/python3.6/runpy.py\", line 193, in _run_module_as_main\n    \"__main__\", mod_spec)\n"
#   }
#   attrs {
#     name: "op_namescope"
#     type: STRING
#     s: "/optimizer_3/"
#   }
#   attrs {
#     name: "op_role_var"
#     type: STRINGS
#     strings: "fc_0.w_1"
#     strings: "fc_0.w_1@GRAD"
#   }
#   attrs {
#     name: "op_role"
#     type: INT
#     i: 2
#   }
#   attrs {
#     name: "epsilon"
#     type: FLOAT
#     f: 9.999999974752427e-07
#   }, inputs {
#     parameter: "Grad"
#     arguments: "sequence_conv_0.b_0@GRAD"
#   }
#   inputs {
#     parameter: "LearningRate"
#     arguments: "learning_rate_0"
#   }
#   inputs {
#     parameter: "Moment"
#     arguments: "sequence_conv_0.b_0_moment_0"
#   }
#   inputs {
#     parameter: "Param"
#     arguments: "sequence_conv_0.b_0"
#   }
#   outputs {
#     parameter: "MomentOut"
#     arguments: "sequence_conv_0.b_0_moment_0"
#   }
#   outputs {
#     parameter: "ParamOut"
#     arguments: "sequence_conv_0.b_0"
#   }
#   type: "adagrad"
#   attrs {
#     name: "op_callstack"
#     type: STRINGS
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/framework.py\", line 1748, in append_op\n    attrs=kwargs.get(\"attrs\", None))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 1228, in _append_optimize_op\n    stop_gradient=True)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 386, in _create_optimization_pass\n    param_and_grad)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 531, in apply_gradients\n    optimize_ops = self._create_optimization_pass(params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 561, in apply_optimize\n    optimize_ops = self.apply_gradients(params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 600, in minimize\n    loss, startup_program=startup_program, params_grads=params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/dygraph/base.py\", line 88, in __impl__\n    return func(*args, **kwargs)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/wrapped_decorator.py\", line 25, in __impl__\n    return wrapped_func(*args, **kwargs)\n"
#     strings: "  File \"</usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-145>\", line 2, in minimize\n"
#     strings: "  File \"<ipython-input-9-8a35697e7cc6>\", line 5, in <module>\n    sgd_optimizer.minimize(avg_cost)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3296, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3220, in run_ast_nodes\n    if (yield from self.run_code(code, result)):\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3049, in run_cell_async\n    interactivity=interactivity, compiler=compiler, result=result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/async_helpers.py\", line 67, in _pseudo_sync_runner\n    coro.send(None)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 2874, in _run_cell\n    return runner(coro)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 2848, in run_cell\n    raw_cell, store_history, silent, shell_futures)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py\", line 536, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py\", line 294, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 542, in execute_request\n    user_expressions, allow_stdin,\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 272, in dispatch_shell\n    yield gen.maybe_future(handler(stream, idents, msg))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 365, in process_one\n    yield gen.maybe_future(dispatch(*args))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 742, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 708, in __init__\n    self.run()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 225, in wrapper\n    runner = Runner(result, future, yielded)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 378, in dispatch_queue\n    yield self.process_one()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 742, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 781, in inner\n    self.run()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py\", line 743, in _run_callback\n    ret = callback()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py\", line 690, in <lambda>\n    lambda f: self._run_callback(functools.partial(callback, future))\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/events.py\", line 145, in _run\n    self._callback(*self._args)\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/base_events.py\", line 1451, in _run_once\n    handle._run()\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/base_events.py\", line 438, in run_forever\n    self._run_once()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/platform/asyncio.py\", line 148, in start\n    self.asyncio_loop.run_forever()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py\", line 505, in start\n    self.io_loop.start()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py\", line 658, in launch_instance\n    app.start()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py\", line 16, in <module>\n    app.launch_new_instance()\n"
#     strings: "  File \"/usr/lib/python3.6/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n"
#     strings: "  File \"/usr/lib/python3.6/runpy.py\", line 193, in _run_module_as_main\n    \"__main__\", mod_spec)\n"
#   }
#   attrs {
#     name: "op_namescope"
#     type: STRING
#     s: "/optimizer_4/"
#   }
#   attrs {
#     name: "op_role_var"
#     type: STRINGS
#     strings: "sequence_conv_0.b_0"
#     strings: "sequence_conv_0.b_0@GRAD"
#   }
#   attrs {
#     name: "op_role"
#     type: INT
#     i: 2
#   }
#   attrs {
#     name: "epsilon"
#     type: FLOAT
#     f: 9.999999974752427e-07
#   }, inputs {
#     parameter: "Grad"
#     arguments: "sequence_conv_0.w_0@GRAD"
#   }
#   inputs {
#     parameter: "LearningRate"
#     arguments: "learning_rate_0"
#   }
#   inputs {
#     parameter: "Moment"
#     arguments: "sequence_conv_0.w_0_moment_0"
#   }
#   inputs {
#     parameter: "Param"
#     arguments: "sequence_conv_0.w_0"
#   }
#   outputs {
#     parameter: "MomentOut"
#     arguments: "sequence_conv_0.w_0_moment_0"
#   }
#   outputs {
#     parameter: "ParamOut"
#     arguments: "sequence_conv_0.w_0"
#   }
#   type: "adagrad"
#   attrs {
#     name: "op_callstack"
#     type: STRINGS
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/framework.py\", line 1748, in append_op\n    attrs=kwargs.get(\"attrs\", None))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 1228, in _append_optimize_op\n    stop_gradient=True)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 386, in _create_optimization_pass\n    param_and_grad)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 531, in apply_gradients\n    optimize_ops = self._create_optimization_pass(params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 561, in apply_optimize\n    optimize_ops = self.apply_gradients(params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 600, in minimize\n    loss, startup_program=startup_program, params_grads=params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/dygraph/base.py\", line 88, in __impl__\n    return func(*args, **kwargs)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/wrapped_decorator.py\", line 25, in __impl__\n    return wrapped_func(*args, **kwargs)\n"
#     strings: "  File \"</usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-145>\", line 2, in minimize\n"
#     strings: "  File \"<ipython-input-9-8a35697e7cc6>\", line 5, in <module>\n    sgd_optimizer.minimize(avg_cost)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3296, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3220, in run_ast_nodes\n    if (yield from self.run_code(code, result)):\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3049, in run_cell_async\n    interactivity=interactivity, compiler=compiler, result=result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/async_helpers.py\", line 67, in _pseudo_sync_runner\n    coro.send(None)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 2874, in _run_cell\n    return runner(coro)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 2848, in run_cell\n    raw_cell, store_history, silent, shell_futures)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py\", line 536, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py\", line 294, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 542, in execute_request\n    user_expressions, allow_stdin,\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 272, in dispatch_shell\n    yield gen.maybe_future(handler(stream, idents, msg))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 365, in process_one\n    yield gen.maybe_future(dispatch(*args))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 742, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 708, in __init__\n    self.run()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 225, in wrapper\n    runner = Runner(result, future, yielded)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 378, in dispatch_queue\n    yield self.process_one()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 742, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 781, in inner\n    self.run()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py\", line 743, in _run_callback\n    ret = callback()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py\", line 690, in <lambda>\n    lambda f: self._run_callback(functools.partial(callback, future))\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/events.py\", line 145, in _run\n    self._callback(*self._args)\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/base_events.py\", line 1451, in _run_once\n    handle._run()\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/base_events.py\", line 438, in run_forever\n    self._run_once()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/platform/asyncio.py\", line 148, in start\n    self.asyncio_loop.run_forever()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py\", line 505, in start\n    self.io_loop.start()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py\", line 658, in launch_instance\n    app.start()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py\", line 16, in <module>\n    app.launch_new_instance()\n"
#     strings: "  File \"/usr/lib/python3.6/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n"
#     strings: "  File \"/usr/lib/python3.6/runpy.py\", line 193, in _run_module_as_main\n    \"__main__\", mod_spec)\n"
#   }
#   attrs {
#     name: "op_namescope"
#     type: STRING
#     s: "/optimizer_5/"
#   }
#   attrs {
#     name: "op_role_var"
#     type: STRINGS
#     strings: "sequence_conv_0.w_0"
#     strings: "sequence_conv_0.w_0@GRAD"
#   }
#   attrs {
#     name: "op_role"
#     type: INT
#     i: 2
#   }
#   attrs {
#     name: "epsilon"
#     type: FLOAT
#     f: 9.999999974752427e-07
#   }, inputs {
#     parameter: "Grad"
#     arguments: "sequence_conv_1.b_0@GRAD"
#   }
#   inputs {
#     parameter: "LearningRate"
#     arguments: "learning_rate_0"
#   }
#   inputs {
#     parameter: "Moment"
#     arguments: "sequence_conv_1.b_0_moment_0"
#   }
#   inputs {
#     parameter: "Param"
#     arguments: "sequence_conv_1.b_0"
#   }
#   outputs {
#     parameter: "MomentOut"
#     arguments: "sequence_conv_1.b_0_moment_0"
#   }
#   outputs {
#     parameter: "ParamOut"
#     arguments: "sequence_conv_1.b_0"
#   }
#   type: "adagrad"
#   attrs {
#     name: "op_callstack"
#     type: STRINGS
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/framework.py\", line 1748, in append_op\n    attrs=kwargs.get(\"attrs\", None))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 1228, in _append_optimize_op\n    stop_gradient=True)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 386, in _create_optimization_pass\n    param_and_grad)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 531, in apply_gradients\n    optimize_ops = self._create_optimization_pass(params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 561, in apply_optimize\n    optimize_ops = self.apply_gradients(params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 600, in minimize\n    loss, startup_program=startup_program, params_grads=params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/dygraph/base.py\", line 88, in __impl__\n    return func(*args, **kwargs)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/wrapped_decorator.py\", line 25, in __impl__\n    return wrapped_func(*args, **kwargs)\n"
#     strings: "  File \"</usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-145>\", line 2, in minimize\n"
#     strings: "  File \"<ipython-input-9-8a35697e7cc6>\", line 5, in <module>\n    sgd_optimizer.minimize(avg_cost)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3296, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3220, in run_ast_nodes\n    if (yield from self.run_code(code, result)):\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3049, in run_cell_async\n    interactivity=interactivity, compiler=compiler, result=result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/async_helpers.py\", line 67, in _pseudo_sync_runner\n    coro.send(None)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 2874, in _run_cell\n    return runner(coro)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 2848, in run_cell\n    raw_cell, store_history, silent, shell_futures)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py\", line 536, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py\", line 294, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 542, in execute_request\n    user_expressions, allow_stdin,\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 272, in dispatch_shell\n    yield gen.maybe_future(handler(stream, idents, msg))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 365, in process_one\n    yield gen.maybe_future(dispatch(*args))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 742, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 708, in __init__\n    self.run()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 225, in wrapper\n    runner = Runner(result, future, yielded)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 378, in dispatch_queue\n    yield self.process_one()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 742, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 781, in inner\n    self.run()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py\", line 743, in _run_callback\n    ret = callback()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py\", line 690, in <lambda>\n    lambda f: self._run_callback(functools.partial(callback, future))\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/events.py\", line 145, in _run\n    self._callback(*self._args)\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/base_events.py\", line 1451, in _run_once\n    handle._run()\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/base_events.py\", line 438, in run_forever\n    self._run_once()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/platform/asyncio.py\", line 148, in start\n    self.asyncio_loop.run_forever()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py\", line 505, in start\n    self.io_loop.start()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py\", line 658, in launch_instance\n    app.start()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py\", line 16, in <module>\n    app.launch_new_instance()\n"
#     strings: "  File \"/usr/lib/python3.6/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n"
#     strings: "  File \"/usr/lib/python3.6/runpy.py\", line 193, in _run_module_as_main\n    \"__main__\", mod_spec)\n"
#   }
#   attrs {
#     name: "op_namescope"
#     type: STRING
#     s: "/optimizer_6/"
#   }
#   attrs {
#     name: "op_role_var"
#     type: STRINGS
#     strings: "sequence_conv_1.b_0"
#     strings: "sequence_conv_1.b_0@GRAD"
#   }
#   attrs {
#     name: "op_role"
#     type: INT
#     i: 2
#   }
#   attrs {
#     name: "epsilon"
#     type: FLOAT
#     f: 9.999999974752427e-07
#   }, inputs {
#     parameter: "Grad"
#     arguments: "sequence_conv_1.w_0@GRAD"
#   }
#   inputs {
#     parameter: "LearningRate"
#     arguments: "learning_rate_0"
#   }
#   inputs {
#     parameter: "Moment"
#     arguments: "sequence_conv_1.w_0_moment_0"
#   }
#   inputs {
#     parameter: "Param"
#     arguments: "sequence_conv_1.w_0"
#   }
#   outputs {
#     parameter: "MomentOut"
#     arguments: "sequence_conv_1.w_0_moment_0"
#   }
#   outputs {
#     parameter: "ParamOut"
#     arguments: "sequence_conv_1.w_0"
#   }
#   type: "adagrad"
#   attrs {
#     name: "op_callstack"
#     type: STRINGS
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/framework.py\", line 1748, in append_op\n    attrs=kwargs.get(\"attrs\", None))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 1228, in _append_optimize_op\n    stop_gradient=True)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 386, in _create_optimization_pass\n    param_and_grad)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 531, in apply_gradients\n    optimize_ops = self._create_optimization_pass(params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 561, in apply_optimize\n    optimize_ops = self.apply_gradients(params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py\", line 600, in minimize\n    loss, startup_program=startup_program, params_grads=params_grads)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/dygraph/base.py\", line 88, in __impl__\n    return func(*args, **kwargs)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/paddle/fluid/wrapped_decorator.py\", line 25, in __impl__\n    return wrapped_func(*args, **kwargs)\n"
#     strings: "  File \"</usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-145>\", line 2, in minimize\n"
#     strings: "  File \"<ipython-input-9-8a35697e7cc6>\", line 5, in <module>\n    sgd_optimizer.minimize(avg_cost)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3296, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3220, in run_ast_nodes\n    if (yield from self.run_code(code, result)):\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 3049, in run_cell_async\n    interactivity=interactivity, compiler=compiler, result=result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/async_helpers.py\", line 67, in _pseudo_sync_runner\n    coro.send(None)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 2874, in _run_cell\n    return runner(coro)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py\", line 2848, in run_cell\n    raw_cell, store_history, silent, shell_futures)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py\", line 536, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py\", line 294, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 542, in execute_request\n    user_expressions, allow_stdin,\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 272, in dispatch_shell\n    yield gen.maybe_future(handler(stream, idents, msg))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 209, in wrapper\n    yielded = next(result)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 365, in process_one\n    yield gen.maybe_future(dispatch(*args))\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 742, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 708, in __init__\n    self.run()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 225, in wrapper\n    runner = Runner(result, future, yielded)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py\", line 378, in dispatch_queue\n    yield self.process_one()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 742, in run\n    yielded = self.gen.send(value)\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/gen.py\", line 781, in inner\n    self.run()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py\", line 743, in _run_callback\n    ret = callback()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py\", line 690, in <lambda>\n    lambda f: self._run_callback(functools.partial(callback, future))\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/events.py\", line 145, in _run\n    self._callback(*self._args)\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/base_events.py\", line 1451, in _run_once\n    handle._run()\n"
#     strings: "  File \"/usr/lib/python3.6/asyncio/base_events.py\", line 438, in run_forever\n    self._run_once()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/tornado/platform/asyncio.py\", line 148, in start\n    self.asyncio_loop.run_forever()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py\", line 505, in start\n    self.io_loop.start()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py\", line 658, in launch_instance\n    app.start()\n"
#     strings: "  File \"/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py\", line 16, in <module>\n    app.launch_new_instance()\n"
#     strings: "  File \"/usr/lib/python3.6/runpy.py\", line 85, in _run_code\n    exec(code, run_globals)\n"
#     strings: "  File \"/usr/lib/python3.6/runpy.py\", line 193, in _run_module_as_main\n    \"__main__\", mod_spec)\n"
#   }
#   attrs {
#     name: "op_namescope"
#     type: STRING
#     s: "/optimizer_7/"
#   }
#   attrs {
#     name: "op_role_var"
#     type: STRINGS
#     strings: "sequence_conv_1.w_0"
#     strings: "sequence_conv_1.w_0@GRAD"
#   }
#   attrs {
#     name: "op_role"
#     type: INT
#     i: 2
#   }
#   attrs {
#     name: "epsilon"
#     type: FLOAT
#     f: 9.999999974752427e-07
#   }], [(name: "embedding_0.w_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 5147
#          dims: 64
#        }
#      }
#    }
#    persistable: true, name: "embedding_0.w_0@GRAD"
#    type {
#      type: SELECTED_ROWS
#      selected_rows {
#        data_type: FP32
#        dims: 5147
#        dims: 64
#      }
#    }), (name: "sequence_conv_0.w_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 192
#          dims: 64
#        }
#      }
#    }
#    persistable: true, name: "sequence_conv_0.w_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 192
#          dims: 64
#        }
#      }
#    }), (name: "sequence_conv_0.b_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 64
#        }
#      }
#    }
#    persistable: true, name: "sequence_conv_0.b_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 64
#        }
#        lod_level: 0
#      }
#    }), (name: "sequence_conv_1.w_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 256
#          dims: 64
#        }
#      }
#    }
#    persistable: true, name: "sequence_conv_1.w_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 256
#          dims: 64
#        }
#      }
#    }), (name: "sequence_conv_1.b_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 64
#        }
#      }
#    }
#    persistable: true, name: "sequence_conv_1.b_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 64
#        }
#        lod_level: 0
#      }
#    }), (name: "fc_0.w_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 64
#          dims: 2
#        }
#      }
#    }
#    persistable: true, name: "fc_0.w_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 64
#          dims: 2
#        }
#      }
#    }), (name: "fc_0.w_1"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 64
#          dims: 2
#        }
#      }
#    }
#    persistable: true, name: "fc_0.w_1@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 64
#          dims: 2
#        }
#      }
#    }), (name: "fc_0.b_0"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 2
#        }
#      }
#    }
#    persistable: true, name: "fc_0.b_0@GRAD"
#    type {
#      type: LOD_TENSOR
#      lod_tensor {
#        tensor {
#          data_type: FP32
#          dims: 2
#        }
#        lod_level: 0
#      }
#    })])

# %%
def train_test(program, reader):
    count = 0
    feed_var_list = [
        program.global_block().var(var_name) for var_name in feed_order
    ]
    feeder_test = fluid.DataFeeder(feed_list=feed_var_list, place=place)
    test_exe = fluid.Executor(place)
    accumulated = len([avg_cost, accuracy]) * [0]
    for test_data in reader():
        avg_cost_np = test_exe.run(
            program=program,
            feed=feeder_test.feed(test_data),
            fetch_list=[avg_cost, accuracy])
        accumulated = [
            x[0] + x[1][0] for x in zip(accumulated, avg_cost_np)
        ]
        count += 1
    return [x / count for x in accumulated]

# %%
# Specify the directory path to save the parameters
params_dirname = "../model/understand_sentiment_conv.inference.model"

feed_order = ['words', 'label']
pass_num = 20  #Number rounds of the training loop

# Main loop part of the program
def train_loop(main_program):
    # Start the trainer built above
    exe.run(fluid.default_startup_program())

    feed_var_list_loop = [
        main_program.global_block().var(var_name) for var_name in feed_order
    ]
    feeder = fluid.DataFeeder(
        feed_list=feed_var_list_loop, place=place)

    test_program = fluid.default_main_program().clone(for_test=True)

    # Training loop
    for epoch_id in range(pass_num):
        for step_id, data in enumerate(train_reader()):
            # Running trainer
            metrics = exe.run(main_program,
                              feed=feeder.feed(data),
                              fetch_list=[avg_cost, accuracy])

            # Testing Results
            avg_cost_test, acc_test = train_test(test_program, test_reader)
            print('Step {0}, Test Loss {1:0.2}, Acc {2:0.2}'.format(
                step_id, avg_cost_test, acc_test))

            print("Step {0}, Epoch {1} Metrics {2}".format(
                step_id, epoch_id, list(map(np.array,
                                            metrics))))

            if step_id == 30:
                if params_dirname is not None:
                    fluid.io.save_inference_model(params_dirname, ["words"],
                                                  prediction, exe)# Save model
                return

# %%
train_loop(fluid.default_main_program())
# Out:
# EnforceNotMetTraceback (most recent call last)
# <ipython-input-13-0e2be7494fe1> in <module>
# ----> 1 train_loop(fluid.default_main_program())
#
# <ipython-input-12-60e2dae206bf> in train_loop(main_program)
#       8 def train_loop(main_program):
#       9     # Start the trainer built above
# ---> 10     exe.run(fluid.default_startup_program())
#      11
#      12     feed_var_list_loop = [
#
# /usr/local/lib/python3.6/dist-packages/paddle/fluid/executor.py in run(self, program, feed, fetch_list, feed_var_name, fetch_var_name, scope, return_numpy, use_program_cache)
#     648                 scope=scope,
#     649                 return_numpy=return_numpy,
# --> 650                 use_program_cache=use_program_cache)
#     651         else:
#     652             if fetch_list and program._is_data_parallel and program._program and (
#
# /usr/local/lib/python3.6/dist-packages/paddle/fluid/executor.py in _run(self, program, exe, feed, fetch_list, feed_var_name, fetch_var_name, scope, return_numpy, use_program_cache)
#     746         self._feed_data(program, feed, feed_var_name, scope)
#     747         if not use_program_cache:
# --> 748             exe.run(program.desc, scope, 0, True, True, fetch_var_name)
#     749         else:
#     750             exe.run_cached_prepared_ctx(ctx, scope, False, False, False)
#
# EnforceNotMet: Invoke operator fill_constant error.
# Python Callstacks:
#   File "/usr/local/lib/python3.6/dist-packages/paddle/fluid/framework.py", line 1819, in _prepend_op
#     attrs=kwargs.get("attrs", None))
#   File "/usr/local/lib/python3.6/dist-packages/paddle/fluid/initializer.py", line 186, in __call__
#     stop_gradient=True)
#   File "/usr/local/lib/python3.6/dist-packages/paddle/fluid/framework.py", line 1602, in create_var
#     kwargs['initializer'](var, self)
#   File "/usr/local/lib/python3.6/dist-packages/paddle/fluid/layer_helper_base.py", line 383, in set_variable_initializer
#     initializer=initializer)
#   File "/usr/local/lib/python3.6/dist-packages/paddle/fluid/layers/tensor.py", line 139, in create_global_var
#     value=float(value), force_cpu=force_cpu))
#   File "/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py", line 226, in _create_global_learning_rate
#     persistable=True)
#   File "/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py", line 365, in _create_optimization_pass
#     self._create_global_learning_rate()
#   File "/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py", line 531, in apply_gradients
#     optimize_ops = self._create_optimization_pass(params_grads)
#   File "/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py", line 561, in apply_optimize
#     optimize_ops = self.apply_gradients(params_grads)
#   File "/usr/local/lib/python3.6/dist-packages/paddle/fluid/optimizer.py", line 600, in minimize
#     loss, startup_program=startup_program, params_grads=params_grads)
#   File "/usr/local/lib/python3.6/dist-packages/paddle/fluid/dygraph/base.py", line 88, in __impl__
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/paddle/fluid/wrapped_decorator.py", line 25, in __impl__
#     return wrapped_func(*args, **kwargs)
#   File "</usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-145>", line 2, in minimize
#   File "<ipython-input-9-8a35697e7cc6>", line 5, in <module>
#     sgd_optimizer.minimize(avg_cost)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 3220, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 3049, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 708, in __init__
#     self.run()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 225, in wrapper
#     runner = Runner(result, future, yielded)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 378, in dispatch_queue
#     yield self.process_one()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1451, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 438, in run_forever
#     self._run_once()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
# C++ Callstacks:
# Failed to find dynamic library: libcublas.so ( libcublas.so: cannot open shared object file: No such file or directory )
#  Please specify its path correctly using following ways:
#  Method. set environment variable LD_LIBRARY_PATH on Linux or DYLD_LIBRARY_PATH on Mac OS.
#  For instance, issue command: export LD_LIBRARY_PATH=...
#  Note: After Mac OS 10.11, using the DYLD_LIBRARY_PATH is impossible unless System Integrity Protection (SIP) is disabled. at [/paddle/paddle/fluid/platform/dynload/dynamic_loader.cc:166]
# PaddlePaddle Call Stacks:
# 0       0x7fbc60f18420p void paddle::platform::EnforceNotMet::Init<char const*>(char const*, char const*, int) + 352
# 1       0x7fbc60f18799p paddle::platform::EnforceNotMet::EnforceNotMet(std::__exception_ptr::exception_ptr, char const*, int) + 137
# 2       0x7fbc63040d25p paddle::platform::dynload::GetCublasDsoHandle() + 1813
# 3       0x7fbc6301e319p void std::__once_call_impl<std::_Bind_simple<paddle::platform::dynload::DynLoad__cublasCreate_v2::operator()<cublasContext**>(cublasContext**)::{lambda()#1} ()> >() + 9
# 4       0x7fbccab18827p
# 5       0x7fbc6301f4b9p paddle::platform::CublasHandleHolder::CublasHandleHolder(CUstream_st*, cublasMath_t) + 153
# 6       0x7fbc6301afe7p paddle::platform::CUDADeviceContext::CUDADeviceContext(paddle::platform::CUDAPlace) + 567
# 7       0x7fbc6301fe58p std::_Function_handler<std::unique_ptr<paddle::platform::DeviceContext, std::default_delete<paddle::platform::DeviceContext> > (), std::reference_wrapper<std::_Bind_simple<paddle::platform::EmplaceDeviceContext<paddle::platform::CUDADeviceContext, paddle::platform::CUDAPlace>(std::map<boost::variant<paddle::platform::CUDAPlace, paddle::platform::CPUPlace, paddle::platform::CUDAPinnedPlace, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_>, std::shared_future<std::unique_ptr<paddle::platform::DeviceContext, std::default_delete<paddle::platform::DeviceContext> > >, std::less<boost::variant<paddle::platform::CUDAPlace, paddle::platform::CPUPlace, paddle::platform::CUDAPinnedPlace, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_> >, std::allocator<std::pair<boost::variant<paddle::platform::CUDAPlace, paddle::platform::CPUPlace, paddle::platform::CUDAPinnedPlace, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_> const, std::shared_future<std::unique_ptr<paddle::platform::DeviceContext, std::default_delete<paddle::platform::DeviceContext> > > > > >*, boost::variant<paddle::platform::CUDAPlace, paddle::platform::CPUPlace, paddle::platform::CUDAPinnedPlace, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_>)::{lambda()#1} ()> > >::_M_invoke(std::_Any_data const&) + 104
# 8       0x7fbc6301e40ap std::_Function_handler<std::unique_ptr<std::__future_base::_Result_base, std::__future_base::_Result_base::_Deleter> (), std::__future_base::_Task_setter<std::unique_ptr<std::__future_base::_Result<std::unique_ptr<paddle::platform::DeviceContext, std::default_delete<paddle::platform::DeviceContext> > >, std::__future_base::_Result_base::_Deleter>, std::unique_ptr<paddle::platform::DeviceContext, std::default_delete<paddle::platform::DeviceContext> > > >::_M_invoke(std::_Any_data const&) + 42
# 9       0x7fbc60fe21e7p std::__future_base::_State_base::_M_do_set(std::function<std::unique_ptr<std::__future_base::_Result_base, std::__future_base::_Result_base::_Deleter> ()>&, bool&) + 39
# 10      0x7fbccab18827p
# 11      0x7fbc6302174cp std::__future_base::_Deferred_state<std::_Bind_simple<paddle::platform::EmplaceDeviceContext<paddle::platform::CUDADeviceContext, paddle::platform::CUDAPlace>(std::map<boost::variant<paddle::platform::CUDAPlace, paddle::platform::CPUPlace, paddle::platform::CUDAPinnedPlace, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_>, std::shared_future<std::unique_ptr<paddle::platform::DeviceContext, std::default_delete<paddle::platform::DeviceContext> > >, std::less<boost::variant<paddle::platform::CUDAPlace, paddle::platform::CPUPlace, paddle::platform::CUDAPinnedPlace, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_> >, std::allocator<std::pair<boost::variant<paddle::platform::CUDAPlace, paddle::platform::CPUPlace, paddle::platform::CUDAPinnedPlace, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_> const, std::shared_future<std::unique_ptr<paddle::platform::DeviceContext, std::default_delete<paddle::platform::DeviceContext> > > > > >*, boost::variant<paddle::platform::CUDAPlace, paddle::platform::CPUPlace, paddle::platform::CUDAPinnedPlace, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_>)::{lambda()#1} ()>, std::unique_ptr<paddle::platform::DeviceContext, std::default_delete<paddle::platform::DeviceContext> > >::_M_run_deferred() + 220
# 12      0x7fbc6301bbc9p paddle::platform::DeviceContextPool::Get(boost::variant<paddle::platform::CUDAPlace, paddle::platform::CPUPlace, paddle::platform::CUDAPinnedPlace, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_> const&) + 137
# 13      0x7fbc62f9b52ap paddle::framework::OperatorWithKernel::RunImpl(paddle::framework::Scope const&, boost::variant<paddle::platform::CUDAPlace, paddle::platform::CPUPlace, paddle::platform::CUDAPinnedPlace, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_> const&, paddle::framework::RuntimeContext*) const + 58
# 14      0x7fbc62f9ba41p paddle::framework::OperatorWithKernel::RunImpl(paddle::framework::Scope const&, boost::variant<paddle::platform::CUDAPlace, paddle::platform::CPUPlace, paddle::platform::CUDAPinnedPlace, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_> const&) const + 529
# 15      0x7fbc62f9903cp paddle::framework::OperatorBase::Run(paddle::framework::Scope const&, boost::variant<paddle::platform::CUDAPlace, paddle::platform::CPUPlace, paddle::platform::CUDAPinnedPlace, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_, boost::detail::variant::void_> const&) + 332
# 16      0x7fbc610a25bep paddle::framework::Executor::RunPreparedContext(paddle::framework::ExecutorPrepareContext*, paddle::framework::Scope*, bool, bool, bool) + 382
# 17      0x7fbc610a565fp paddle::framework::Executor::Run(paddle::framework::ProgramDesc const&, paddle::framework::Scope*, int, bool, bool, std::vector<std::string, std::allocator<std::string> > const&, bool) + 143
# 18      0x7fbc60f09aadp
# 19      0x7fbc60f4ade6p
# 20            0x56204cp _PyCFunction_FastCallDict + 860
# 21            0x4f88bap
# 22            0x4f98c7p _PyEval_EvalFrameDefault + 1127
# 23            0x4f6128p
# 24            0x4f7d60p
# 25            0x4f876dp
# 26            0x4fa6c0p _PyEval_EvalFrameDefault + 4704
# 27            0x4f6128p
# 28            0x4f7d60p
# 29            0x4f876dp
# 30            0x4f98c7p _PyEval_EvalFrameDefault + 1127
# 31            0x4f6128p
# 32            0x4f7d60p
# 33            0x4f876dp
# 34            0x4f98c7p _PyEval_EvalFrameDefault + 1127
# 35            0x4f6128p
# 36            0x517a9ap
# 37            0x4f858dp
# 38            0x4f98c7p _PyEval_EvalFrameDefault + 1127
# 39            0x59bf6ap
# 40            0x4faeb1p _PyEval_EvalFrameDefault + 6737
# 41            0x59bf6ap
# 42            0x4faeb1p _PyEval_EvalFrameDefault + 6737
# 43            0x59bf6ap
# 44            0x4f862cp
# 45            0x4f98c7p _PyEval_EvalFrameDefault + 1127
# 46            0x4f7a28p
# 47            0x4f876dp
# 48            0x4f98c7p _PyEval_EvalFrameDefault + 1127
# 49            0x4f7a28p
# 50            0x4f876dp
# 51            0x4f98c7p _PyEval_EvalFrameDefault + 1127
# 52            0x4f6128p
# 53            0x4f426ep _PyFunction_FastCallDict + 766
# 54            0x5a1481p
# 55            0x57c2fep PyObject_Call + 62
# 56            0x4facb1p _PyEval_EvalFrameDefault + 6225
# 57            0x4f6128p
# 58            0x4f7d60p
# 59            0x4f876dp
# 60            0x4fa6c0p _PyEval_EvalFrameDefault + 4704
# 61            0x59c3a9p
# 62            0x5017cfp
# 63            0x4f858dp
# 64            0x4f98c7p _PyEval_EvalFrameDefault + 1127
# 65            0x4f6128p
# 66            0x4f7d60p
# 67            0x4f876dp
# 68            0x4f98c7p _PyEval_EvalFrameDefault + 1127
# 69            0x59c3a9p
# 70            0x5017cfp
# 71            0x4f858dp
# 72            0x4f98c7p _PyEval_EvalFrameDefault + 1127
# 73            0x4f6128p
# 74            0x4f7d60p
# 75            0x4f876dp
# 76            0x4f98c7p _PyEval_EvalFrameDefault + 1127
# 77            0x59c3a9p
# 78            0x5017cfp
# 79            0x4f858dp
# 80            0x4f98c7p _PyEval_EvalFrameDefault + 1127
# 81            0x4f6128p
# 82            0x4f426ep _PyFunction_FastCallDict + 766
# 83            0x5a1481p
# 84            0x57c2fep PyObject_Call + 62
# 85            0x4facb1p _PyEval_EvalFrameDefault + 6225
# 86            0x59bef8p
# 87            0x4f862cp
# 88            0x4f98c7p _PyEval_EvalFrameDefault + 1127
# 89            0x4f7a28p
# 90            0x4f876dp
# 91            0x4f98c7p _PyEval_EvalFrameDefault + 1127
# 92            0x4f6128p
# 93            0x4f426ep _PyFunction_FastCallDict + 766
# 94            0x57c8f1p _PyObject_FastCallDict + 1265
# 95            0x5d72ccp
# 96            0x57ec0cp _PyObject_FastCallKeywords + 412
# 97            0x4f88bap
# 98            0x4f98c7p _PyEval_EvalFrameDefault + 1127
# 99            0x4f7a28p
