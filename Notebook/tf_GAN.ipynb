# %%
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import pickle as pkl
import time

tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
def leaky_relu(x, alpha=0.0001):
    return tf.maximum(alpha * x, x)

# %%
########################
### DATASET
########################

mnist = input_data.read_data_sets('./dataset/MNIST_data')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0628 01:45:00.755923 139803829532480 deprecation.py:323] From <ipython-input-3-f648c7179838>:5: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# W0628 01:45:00.756844 139803829532480 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# W0628 01:45:00.757553 139803829532480 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./dataset/MNIST_data/train-images-idx3-ubyte.gz
# W0628 01:45:00.962716 139803829532480 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# W0628 01:45:00.999754 139803829532480 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# Extracting ./dataset/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ./dataset/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ./dataset/MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
#########################
### SETTINGS
#########################

# Hyperparameters
learning_rate = 0.001
training_epochs = 300
batch_size = 64
dropout_rate = 0.5

# Other settings
print_interval = 200

# Architecture
dis_input_size = 784
gen_input_size = 100

dis_hidden_size = 128
gen_hidden_size = 128


#########################
### GRAPH DEFINITION
#########################

g = tf.Graph()
with g.as_default():
    
    # Placeholders for settings
    dropout = tf.placeholder(tf.float32, shape=None, name='dropout')
    is_training = tf.placeholder(tf.bool, shape=None, name='is_training')
    
    # Input data
    dis_x = tf.placeholder(tf.float32, shape=[None, dis_input_size], name='discriminator_input') 
    gen_x = tf.placeholder(tf.float32, [None, gen_input_size], name='generator_input')


    ##################
    # Generator Model
    ##################

    with tf.variable_scope('generator'):
        # linear -> ~~batch norm~~ -> leaky relu -> dropout -> tanh output
        gen_hidden = tf.layers.dense(inputs=gen_x, units=gen_hidden_size,
                                      activation=None)
        #gen_hidden = tf.layers.batch_normalization(gen_hidden, training=is_training)
        gen_hidden = leaky_relu(gen_hidden)
        gen_hidden = tf.layers.dropout(gen_hidden, rate=dropout_rate)
        gen_logits = tf.layers.dense(inputs=gen_hidden, units=dis_input_size, 
                                     activation=None)
        gen_out = tf.tanh(gen_logits, 'generator_output')


    ######################
    # Discriminator Model
    ######################
    
    def build_discriminator_graph(input_x, reuse=None):
        # linear -> ~~batch norm~~ -> leaky relu -> dropout -> sigmoid output
        with tf.variable_scope('discriminator', reuse=reuse):
            hidden = tf.layers.dense(inputs=input_x, units=dis_hidden_size, 
                                     activation=None)
            #hidden = tf.layers.batch_normalization(hidden, training=is_training)
            hidden = leaky_relu(hidden)
            hidden = tf.layers.dropout(hidden, rate=dropout_rate)
            logits = tf.layers.dense(inputs=hidden, units=1, activation=None)
            out = tf.sigmoid(logits)
        return logits, out    

    # Create a discriminator for real data and a discriminator for fake data
    dis_real_logits, dis_real_out = build_discriminator_graph(dis_x, reuse=False)
    dis_fake_logits, dis_fake_out = build_discriminator_graph(gen_out, reuse=True)


    #####################################
    # Generator and Discriminator Losses
    #####################################
    
    # Two discriminator cost components: loss on real data + loss on fake data
    # Real data has class label 0, fake data has class label 1
    dis_real_loss = tf.nn.sigmoid_cross_entropy_with_logits(logits=dis_real_logits, 
                                                            labels=tf.zeros_like(dis_real_logits))
    dis_fake_loss = tf.nn.sigmoid_cross_entropy_with_logits(logits=dis_fake_logits, 
                                                            labels=tf.ones_like(dis_fake_logits))
    dis_cost = tf.add(tf.reduce_mean(dis_fake_loss), 
                      tf.reduce_mean(dis_real_loss), 
                      name='discriminator_cost')
 
    # Generator cost: difference between dis. prediction and label "0" for real images
    gen_loss = tf.nn.sigmoid_cross_entropy_with_logits(logits=dis_fake_logits,
                                                       labels=tf.zeros_like(dis_fake_logits))
    gen_cost = tf.reduce_mean(gen_loss, name='generator_cost')
    
    
    #########################################
    # Generator and Discriminator Optimizers
    #########################################
      
    dis_optimizer = tf.train.AdamOptimizer(learning_rate)
    dis_train_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='discriminator')
    dis_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS, scope='discriminator')
    
    with tf.control_dependencies(dis_update_ops): # required to upd. batch_norm params
        dis_train = dis_optimizer.minimize(dis_cost, var_list=dis_train_vars,
                                           name='train_discriminator')
    
    gen_optimizer = tf.train.AdamOptimizer(learning_rate)
    gen_train_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='generator')
    gen_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS, scope='generator')
    
    with tf.control_dependencies(gen_update_ops): # required to upd. batch_norm params
        gen_train = gen_optimizer.minimize(gen_cost, var_list=gen_train_vars,
                                           name='train_generator')
    
    # Saver to save session for reuse
    saver = tf.train.Saver()
# Out:
# W0628 01:45:01.181890 139803829532480 deprecation.py:323] From <ipython-input-4-1df12a20b3c7>:46: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0628 01:45:01.186197 139803829532480 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0628 01:45:01.585431 139803829532480 deprecation.py:323] From <ipython-input-4-1df12a20b3c7>:49: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# W0628 01:45:01.697233 139803829532480 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
##########################
### TRAINING & EVALUATION
##########################

with tf.Session(graph=g) as sess:
    sess.run(tf.global_variables_initializer())
    
    avg_costs = {'discriminator': [], 'generator': []}
    start_time = time.time()
    
    for epoch in range(training_epochs):
        dis_avg_cost, gen_avg_cost = 0., 0.
        total_batch = mnist.train.num_examples // batch_size

        for i in range(total_batch):
            
            batch_x, batch_y = mnist.train.next_batch(batch_size)
            batch_x = batch_x*2 - 1 # normalize
            batch_randsample = np.random.uniform(-1, 1, size=(batch_size, gen_input_size))
            
            # Train
            _, dc = sess.run(['train_discriminator', 'discriminator_cost:0'],
                             feed_dict={'discriminator_input:0': batch_x, 
                                        'generator_input:0': batch_randsample,
                                        'dropout:0': dropout_rate,
                                        'is_training:0': True})
            _, gc = sess.run(['train_generator', 'generator_cost:0'],
                             feed_dict={'generator_input:0': batch_randsample,
                                        'dropout:0': dropout_rate,
                                        'is_training:0': True})
            
            dis_avg_cost += dc
            gen_avg_cost += gc

            if not i % print_interval:
                print("Minibatch: %03d | Dis/Gen Cost:    %.3f/%.3f" % (i + 1, dc, gc))
                

        print("Epoch:     %03d | Dis/Gen AvgCost: %.3f/%.3f" % 
              (epoch + 1, dis_avg_cost / total_batch, gen_avg_cost / total_batch))
        print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))
        
        avg_costs['discriminator'].append(dis_avg_cost / total_batch)
        avg_costs['generator'].append(gen_avg_cost / total_batch)
    
    print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
    saver.save(sess, save_path='./model/gan.ckpt')
# Out:
# Minibatch: 001 | Dis/Gen Cost:    2.111/0.722
# Minibatch: 201 | Dis/Gen Cost:    0.067/3.332
# Minibatch: 401 | Dis/Gen Cost:    0.099/2.563
# Minibatch: 601 | Dis/Gen Cost:    0.041/4.557
# Minibatch: 801 | Dis/Gen Cost:    0.094/4.085
# Epoch:     001 | Dis/Gen AvgCost: 0.151/3.493
# Time elapsed: 0.04 min
# Minibatch: 001 | Dis/Gen Cost:    0.100/3.316
# Minibatch: 201 | Dis/Gen Cost:    0.111/5.834
# Minibatch: 401 | Dis/Gen Cost:    0.476/6.220
# Minibatch: 601 | Dis/Gen Cost:    0.263/5.272
# Minibatch: 801 | Dis/Gen Cost:    1.587/4.108
# Epoch:     002 | Dis/Gen AvgCost: 0.525/4.596
# Time elapsed: 0.08 min
# Minibatch: 001 | Dis/Gen Cost:    0.547/2.945
# Minibatch: 201 | Dis/Gen Cost:    1.233/1.222
# Minibatch: 401 | Dis/Gen Cost:    1.251/1.283
# Minibatch: 601 | Dis/Gen Cost:    1.407/1.694
# Minibatch: 801 | Dis/Gen Cost:    1.233/1.818
# Epoch:     003 | Dis/Gen AvgCost: 1.148/2.940
# Time elapsed: 0.11 min
# Minibatch: 001 | Dis/Gen Cost:    1.319/1.594
# Minibatch: 201 | Dis/Gen Cost:    1.553/0.956
# Minibatch: 401 | Dis/Gen Cost:    0.429/3.134
# Minibatch: 601 | Dis/Gen Cost:    2.127/1.676
# Minibatch: 801 | Dis/Gen Cost:    0.581/3.190
# Epoch:     004 | Dis/Gen AvgCost: 1.251/2.804
# Time elapsed: 0.15 min
# Minibatch: 001 | Dis/Gen Cost:    0.517/3.415
# Minibatch: 201 | Dis/Gen Cost:    1.555/2.126
# Minibatch: 401 | Dis/Gen Cost:    2.428/1.769
# Minibatch: 601 | Dis/Gen Cost:    2.127/1.755
# Minibatch: 801 | Dis/Gen Cost:    1.474/3.988
# Epoch:     005 | Dis/Gen AvgCost: 1.226/2.784
# Time elapsed: 0.19 min
# Minibatch: 001 | Dis/Gen Cost:    0.715/2.037
# Minibatch: 201 | Dis/Gen Cost:    0.491/3.679
# Minibatch: 401 | Dis/Gen Cost:    1.155/2.219
# Minibatch: 601 | Dis/Gen Cost:    0.297/2.789
# Minibatch: 801 | Dis/Gen Cost:    0.833/1.576
# Epoch:     006 | Dis/Gen AvgCost: 1.308/1.941
# Time elapsed: 0.22 min
# Minibatch: 001 | Dis/Gen Cost:    2.035/0.910
# Minibatch: 201 | Dis/Gen Cost:    2.654/1.911
# Minibatch: 401 | Dis/Gen Cost:    1.832/1.935
# Minibatch: 601 | Dis/Gen Cost:    2.354/0.893
# Minibatch: 801 | Dis/Gen Cost:    1.277/1.891
# Epoch:     007 | Dis/Gen AvgCost: 1.474/1.594
# Time elapsed: 0.26 min
# Minibatch: 001 | Dis/Gen Cost:    1.283/1.776
# Minibatch: 201 | Dis/Gen Cost:    1.508/1.661
# Minibatch: 401 | Dis/Gen Cost:    1.156/1.542
# Minibatch: 601 | Dis/Gen Cost:    1.823/1.636
# Minibatch: 801 | Dis/Gen Cost:    1.210/1.745
# Epoch:     008 | Dis/Gen AvgCost: 1.524/1.584
# Time elapsed: 0.29 min
# Minibatch: 001 | Dis/Gen Cost:    1.834/1.257
# Minibatch: 201 | Dis/Gen Cost:    1.664/1.150
# Minibatch: 401 | Dis/Gen Cost:    0.898/1.927
# Minibatch: 601 | Dis/Gen Cost:    0.379/3.018
# Minibatch: 801 | Dis/Gen Cost:    1.900/2.131
# Epoch:     009 | Dis/Gen AvgCost: 1.439/1.718
# Time elapsed: 0.33 min
# Minibatch: 001 | Dis/Gen Cost:    2.180/1.401
# Minibatch: 201 | Dis/Gen Cost:    1.393/1.927
# Minibatch: 401 | Dis/Gen Cost:    3.016/1.302
# Minibatch: 601 | Dis/Gen Cost:    1.247/1.367
# Minibatch: 801 | Dis/Gen Cost:    0.967/1.398
# Epoch:     010 | Dis/Gen AvgCost: 1.531/1.519
# Time elapsed: 0.37 min
# Minibatch: 001 | Dis/Gen Cost:    1.773/1.070
# Minibatch: 201 | Dis/Gen Cost:    1.057/2.182
# Minibatch: 401 | Dis/Gen Cost:    0.668/1.744
# Minibatch: 601 | Dis/Gen Cost:    0.685/2.166
# Minibatch: 801 | Dis/Gen Cost:    1.065/1.754
# Epoch:     011 | Dis/Gen AvgCost: 1.464/1.237
# Time elapsed: 0.40 min
# Minibatch: 001 | Dis/Gen Cost:    1.094/2.152
# Minibatch: 201 | Dis/Gen Cost:    1.535/1.419
# Minibatch: 401 | Dis/Gen Cost:    0.805/2.942
# Minibatch: 601 | Dis/Gen Cost:    0.616/2.563
# Minibatch: 801 | Dis/Gen Cost:    1.017/2.669
# Epoch:     012 | Dis/Gen AvgCost: 1.366/1.824
# Time elapsed: 0.44 min
# Minibatch: 001 | Dis/Gen Cost:    1.221/1.448
# Minibatch: 201 | Dis/Gen Cost:    2.177/0.802
# Minibatch: 401 | Dis/Gen Cost:    0.996/1.511
# Minibatch: 601 | Dis/Gen Cost:    1.306/0.763
# Minibatch: 801 | Dis/Gen Cost:    1.744/0.890
# Epoch:     013 | Dis/Gen AvgCost: 1.435/1.506
# Time elapsed: 0.48 min
# Minibatch: 001 | Dis/Gen Cost:    1.630/0.843
# Minibatch: 201 | Dis/Gen Cost:    1.865/0.690
# Minibatch: 401 | Dis/Gen Cost:    1.379/1.130
# Minibatch: 601 | Dis/Gen Cost:    1.289/1.414
# Minibatch: 801 | Dis/Gen Cost:    2.034/0.909
# Epoch:     014 | Dis/Gen AvgCost: 1.452/1.186
# Time elapsed: 0.51 min
# Minibatch: 001 | Dis/Gen Cost:    2.104/0.975
# Minibatch: 201 | Dis/Gen Cost:    1.437/0.804
# Minibatch: 401 | Dis/Gen Cost:    1.043/1.289
# Minibatch: 601 | Dis/Gen Cost:    1.483/1.397
# Minibatch: 801 | Dis/Gen Cost:    1.503/1.031
# Epoch:     015 | Dis/Gen AvgCost: 1.438/1.209
# Time elapsed: 0.55 min
# Minibatch: 001 | Dis/Gen Cost:    1.855/0.749
# Minibatch: 201 | Dis/Gen Cost:    1.108/1.633
# Minibatch: 401 | Dis/Gen Cost:    1.758/1.017
# Minibatch: 601 | Dis/Gen Cost:    1.199/1.573
# Minibatch: 801 | Dis/Gen Cost:    1.093/1.764
# Epoch:     016 | Dis/Gen AvgCost: 1.282/1.437
# Time elapsed: 0.58 min
# Minibatch: 001 | Dis/Gen Cost:    0.974/2.450
# Minibatch: 201 | Dis/Gen Cost:    1.221/1.731
# Minibatch: 401 | Dis/Gen Cost:    1.024/1.346
# Minibatch: 601 | Dis/Gen Cost:    0.961/1.925
# Minibatch: 801 | Dis/Gen Cost:    1.601/1.405
# Epoch:     017 | Dis/Gen AvgCost: 1.124/1.859
# Time elapsed: 0.62 min
# Minibatch: 001 | Dis/Gen Cost:    1.070/2.348
# Minibatch: 201 | Dis/Gen Cost:    0.763/2.203
# Minibatch: 401 | Dis/Gen Cost:    0.738/1.928
# Minibatch: 601 | Dis/Gen Cost:    1.945/1.774
# Minibatch: 801 | Dis/Gen Cost:    1.740/1.820
# Epoch:     018 | Dis/Gen AvgCost: 1.033/2.260
# Time elapsed: 0.66 min
# Minibatch: 001 | Dis/Gen Cost:    1.497/1.635
# Minibatch: 201 | Dis/Gen Cost:    0.987/1.990
# Minibatch: 401 | Dis/Gen Cost:    1.154/2.393
# Minibatch: 601 | Dis/Gen Cost:    1.345/1.679
# Minibatch: 801 | Dis/Gen Cost:    1.253/2.342
# Epoch:     019 | Dis/Gen AvgCost: 0.993/2.414
# Time elapsed: 0.69 min
# Minibatch: 001 | Dis/Gen Cost:    0.903/3.119
# Minibatch: 201 | Dis/Gen Cost:    0.917/3.445
# Minibatch: 401 | Dis/Gen Cost:    1.182/1.435
# Minibatch: 601 | Dis/Gen Cost:    2.253/1.392
# Minibatch: 801 | Dis/Gen Cost:    1.284/2.099
# Epoch:     020 | Dis/Gen AvgCost: 1.113/2.349
# Time elapsed: 0.73 min
# Minibatch: 001 | Dis/Gen Cost:    0.747/3.267
# Minibatch: 201 | Dis/Gen Cost:    1.858/2.160
# Minibatch: 401 | Dis/Gen Cost:    2.638/3.036
# Minibatch: 601 | Dis/Gen Cost:    1.499/1.820
# Minibatch: 801 | Dis/Gen Cost:    0.728/3.955
# Epoch:     021 | Dis/Gen AvgCost: 1.206/2.366
# Time elapsed: 0.76 min
# Minibatch: 001 | Dis/Gen Cost:    0.818/2.956
# Minibatch: 201 | Dis/Gen Cost:    0.718/2.367
# Minibatch: 401 | Dis/Gen Cost:    1.345/1.490
# Minibatch: 601 | Dis/Gen Cost:    1.146/1.886
# Minibatch: 801 | Dis/Gen Cost:    0.981/2.243
# Epoch:     022 | Dis/Gen AvgCost: 1.263/2.006
# Time elapsed: 0.80 min
# Minibatch: 001 | Dis/Gen Cost:    1.645/1.795
# Minibatch: 201 | Dis/Gen Cost:    1.097/2.570
# Minibatch: 401 | Dis/Gen Cost:    1.413/1.103
# Minibatch: 601 | Dis/Gen Cost:    1.144/1.541
# Minibatch: 801 | Dis/Gen Cost:    1.160/1.745
# Epoch:     023 | Dis/Gen AvgCost: 1.200/1.857
# Time elapsed: 0.84 min
# Minibatch: 001 | Dis/Gen Cost:    0.863/2.028
# Minibatch: 201 | Dis/Gen Cost:    1.243/1.613
# Minibatch: 401 | Dis/Gen Cost:    1.718/1.414
# Minibatch: 601 | Dis/Gen Cost:    1.339/0.989
# Minibatch: 801 | Dis/Gen Cost:    0.825/1.962
# Epoch:     024 | Dis/Gen AvgCost: 1.160/1.705
# Time elapsed: 0.87 min
# Minibatch: 001 | Dis/Gen Cost:    1.658/1.795
# Minibatch: 201 | Dis/Gen Cost:    1.221/1.764
# Minibatch: 401 | Dis/Gen Cost:    1.366/1.709
# Minibatch: 601 | Dis/Gen Cost:    0.891/1.860
# Minibatch: 801 | Dis/Gen Cost:    1.380/1.514
# Epoch:     025 | Dis/Gen AvgCost: 1.118/1.810
# Time elapsed: 0.91 min
# Minibatch: 001 | Dis/Gen Cost:    1.055/2.297
# Minibatch: 201 | Dis/Gen Cost:    0.959/2.200
# Minibatch: 401 | Dis/Gen Cost:    0.856/2.606
# Minibatch: 601 | Dis/Gen Cost:    1.179/1.803
# Minibatch: 801 | Dis/Gen Cost:    0.999/1.942
# Epoch:     026 | Dis/Gen AvgCost: 1.056/2.131
# Time elapsed: 0.94 min
# Minibatch: 001 | Dis/Gen Cost:    0.719/2.447
# Minibatch: 201 | Dis/Gen Cost:    1.861/1.653
# Minibatch: 401 | Dis/Gen Cost:    0.903/2.802
# Minibatch: 601 | Dis/Gen Cost:    2.076/1.199
# Minibatch: 801 | Dis/Gen Cost:    0.885/1.829
# Epoch:     027 | Dis/Gen AvgCost: 1.158/2.057
# Time elapsed: 0.98 min
# Minibatch: 001 | Dis/Gen Cost:    0.995/1.918
# Minibatch: 201 | Dis/Gen Cost:    0.994/2.334
# Minibatch: 401 | Dis/Gen Cost:    1.338/1.309
# Minibatch: 601 | Dis/Gen Cost:    0.716/2.843
# Minibatch: 801 | Dis/Gen Cost:    0.942/1.355
# Epoch:     028 | Dis/Gen AvgCost: 1.143/1.838
# Time elapsed: 1.02 min
# Minibatch: 001 | Dis/Gen Cost:    1.071/1.866
# Minibatch: 201 | Dis/Gen Cost:    0.821/2.029
# Minibatch: 401 | Dis/Gen Cost:    1.284/2.301
# Minibatch: 601 | Dis/Gen Cost:    0.864/1.892
# Minibatch: 801 | Dis/Gen Cost:    1.003/2.116
# Epoch:     029 | Dis/Gen AvgCost: 1.200/1.670
# Time elapsed: 1.05 min
# Minibatch: 001 | Dis/Gen Cost:    1.905/0.998
# Minibatch: 201 | Dis/Gen Cost:    1.172/1.717
# Minibatch: 401 | Dis/Gen Cost:    0.995/2.085
# Minibatch: 601 | Dis/Gen Cost:    1.250/2.014
# Minibatch: 801 | Dis/Gen Cost:    0.881/1.877
# Epoch:     030 | Dis/Gen AvgCost: 1.167/1.692
# Time elapsed: 1.09 min
# Minibatch: 001 | Dis/Gen Cost:    1.285/1.810
# Minibatch: 201 | Dis/Gen Cost:    0.943/1.581
# Minibatch: 401 | Dis/Gen Cost:    1.359/1.902
# Minibatch: 601 | Dis/Gen Cost:    0.759/1.855
# Minibatch: 801 | Dis/Gen Cost:    1.227/1.267
# Epoch:     031 | Dis/Gen AvgCost: 1.144/1.716
# Time elapsed: 1.13 min
# Minibatch: 001 | Dis/Gen Cost:    1.135/1.787
# Minibatch: 201 | Dis/Gen Cost:    0.816/2.231
# Minibatch: 401 | Dis/Gen Cost:    0.963/1.918
# Minibatch: 601 | Dis/Gen Cost:    1.360/1.335
# Minibatch: 801 | Dis/Gen Cost:    1.297/2.321
# Epoch:     032 | Dis/Gen AvgCost: 1.069/1.851
# Time elapsed: 1.16 min
# Minibatch: 001 | Dis/Gen Cost:    0.911/1.824
# Minibatch: 201 | Dis/Gen Cost:    1.346/1.822
# Minibatch: 401 | Dis/Gen Cost:    1.276/1.547
# Minibatch: 601 | Dis/Gen Cost:    1.233/2.000
# Minibatch: 801 | Dis/Gen Cost:    1.113/1.672
# Epoch:     033 | Dis/Gen AvgCost: 1.062/1.958
# Time elapsed: 1.20 min
# Minibatch: 001 | Dis/Gen Cost:    0.713/2.874
# Minibatch: 201 | Dis/Gen Cost:    0.969/1.773
# Minibatch: 401 | Dis/Gen Cost:    0.850/2.363
# Minibatch: 601 | Dis/Gen Cost:    0.952/2.461
# Minibatch: 801 | Dis/Gen Cost:    1.213/1.902
# Epoch:     034 | Dis/Gen AvgCost: 1.071/2.025
# Time elapsed: 1.23 min
# Minibatch: 001 | Dis/Gen Cost:    1.137/2.189
# Minibatch: 201 | Dis/Gen Cost:    1.106/2.029
# Minibatch: 401 | Dis/Gen Cost:    1.535/1.213
# Minibatch: 601 | Dis/Gen Cost:    0.969/2.046
# Minibatch: 801 | Dis/Gen Cost:    0.812/2.108
# Epoch:     035 | Dis/Gen AvgCost: 1.105/1.824
# Time elapsed: 1.27 min
# Minibatch: 001 | Dis/Gen Cost:    0.784/1.992
# Minibatch: 201 | Dis/Gen Cost:    1.005/1.558
# Minibatch: 401 | Dis/Gen Cost:    1.114/1.404
# Minibatch: 601 | Dis/Gen Cost:    0.668/1.975
# Minibatch: 801 | Dis/Gen Cost:    1.072/1.614
# Epoch:     036 | Dis/Gen AvgCost: 1.056/1.774
# Time elapsed: 1.31 min
# Minibatch: 001 | Dis/Gen Cost:    0.949/1.535
# Minibatch: 201 | Dis/Gen Cost:    0.712/2.281
# Minibatch: 401 | Dis/Gen Cost:    0.874/2.028
# Minibatch: 601 | Dis/Gen Cost:    0.881/2.074
# Minibatch: 801 | Dis/Gen Cost:    0.890/1.922
# Epoch:     037 | Dis/Gen AvgCost: 1.009/1.853
# Time elapsed: 1.34 min
# Minibatch: 001 | Dis/Gen Cost:    1.175/1.544
# Minibatch: 201 | Dis/Gen Cost:    1.117/1.451
# Minibatch: 401 | Dis/Gen Cost:    1.235/1.477
# Minibatch: 601 | Dis/Gen Cost:    1.183/1.421
# Minibatch: 801 | Dis/Gen Cost:    0.744/2.265
# Epoch:     038 | Dis/Gen AvgCost: 1.047/1.952
# Time elapsed: 1.38 min
# Minibatch: 001 | Dis/Gen Cost:    0.931/1.799
# Minibatch: 201 | Dis/Gen Cost:    0.897/2.028
# Minibatch: 401 | Dis/Gen Cost:    1.252/1.961
# Minibatch: 601 | Dis/Gen Cost:    0.840/2.265
# Minibatch: 801 | Dis/Gen Cost:    1.071/1.708
# Epoch:     039 | Dis/Gen AvgCost: 1.011/1.848
# Time elapsed: 1.41 min
# Minibatch: 001 | Dis/Gen Cost:    0.870/2.146
# Minibatch: 201 | Dis/Gen Cost:    1.106/2.067
# Minibatch: 401 | Dis/Gen Cost:    1.431/1.888
# Minibatch: 601 | Dis/Gen Cost:    0.760/2.011
# Minibatch: 801 | Dis/Gen Cost:    1.115/1.680
# Epoch:     040 | Dis/Gen AvgCost: 1.090/1.825
# Time elapsed: 1.45 min
# Minibatch: 001 | Dis/Gen Cost:    0.875/1.933
# Minibatch: 201 | Dis/Gen Cost:    1.057/1.972
# Minibatch: 401 | Dis/Gen Cost:    0.854/2.602
# Minibatch: 601 | Dis/Gen Cost:    1.266/2.068
# Minibatch: 801 | Dis/Gen Cost:    0.753/2.133
# Epoch:     041 | Dis/Gen AvgCost: 1.072/1.806
# Time elapsed: 1.49 min
# Minibatch: 001 | Dis/Gen Cost:    0.912/2.140
# Minibatch: 201 | Dis/Gen Cost:    0.912/1.599
# Minibatch: 401 | Dis/Gen Cost:    0.780/1.801
# Minibatch: 601 | Dis/Gen Cost:    1.400/1.524
# Minibatch: 801 | Dis/Gen Cost:    1.438/1.499
# Epoch:     042 | Dis/Gen AvgCost: 1.077/1.720
# Time elapsed: 1.52 min
# Minibatch: 001 | Dis/Gen Cost:    1.549/1.308
# Minibatch: 201 | Dis/Gen Cost:    1.136/1.383
# Minibatch: 401 | Dis/Gen Cost:    1.329/1.245
# Minibatch: 601 | Dis/Gen Cost:    1.192/1.636
# Minibatch: 801 | Dis/Gen Cost:    1.031/1.836
# Epoch:     043 | Dis/Gen AvgCost: 1.024/1.800
# Time elapsed: 1.56 min
# Minibatch: 001 | Dis/Gen Cost:    0.902/1.919
# Minibatch: 201 | Dis/Gen Cost:    1.141/1.612
# Minibatch: 401 | Dis/Gen Cost:    0.991/1.825
# Minibatch: 601 | Dis/Gen Cost:    0.948/1.931
# Minibatch: 801 | Dis/Gen Cost:    0.940/1.774
# Epoch:     044 | Dis/Gen AvgCost: 0.965/1.900
# Time elapsed: 1.60 min
# Minibatch: 001 | Dis/Gen Cost:    0.820/2.194
# Minibatch: 201 | Dis/Gen Cost:    0.823/2.055
# Minibatch: 401 | Dis/Gen Cost:    1.361/1.361
# Minibatch: 601 | Dis/Gen Cost:    1.150/2.056
# Minibatch: 801 | Dis/Gen Cost:    1.116/1.664
# Epoch:     045 | Dis/Gen AvgCost: 0.970/1.855
# Time elapsed: 1.63 min
# Minibatch: 001 | Dis/Gen Cost:    1.243/1.884
# Minibatch: 201 | Dis/Gen Cost:    0.853/1.642
# Minibatch: 401 | Dis/Gen Cost:    1.651/1.081
# Minibatch: 601 | Dis/Gen Cost:    1.064/1.833
# Minibatch: 801 | Dis/Gen Cost:    1.135/1.630
# Epoch:     046 | Dis/Gen AvgCost: 1.012/1.971
# Time elapsed: 1.67 min
# Minibatch: 001 | Dis/Gen Cost:    0.954/1.988
# Minibatch: 201 | Dis/Gen Cost:    1.182/1.714
# Minibatch: 401 | Dis/Gen Cost:    1.225/2.277
# Minibatch: 601 | Dis/Gen Cost:    1.211/2.007
# Minibatch: 801 | Dis/Gen Cost:    1.136/2.204
# Epoch:     047 | Dis/Gen AvgCost: 0.975/2.041
# Time elapsed: 1.71 min
# Minibatch: 001 | Dis/Gen Cost:    1.021/1.270
# Minibatch: 201 | Dis/Gen Cost:    1.174/1.733
# Minibatch: 401 | Dis/Gen Cost:    0.994/2.261
# Minibatch: 601 | Dis/Gen Cost:    1.098/1.551
# Minibatch: 801 | Dis/Gen Cost:    1.038/1.687
# Epoch:     048 | Dis/Gen AvgCost: 0.969/1.971
# Time elapsed: 1.74 min
# Minibatch: 001 | Dis/Gen Cost:    0.574/2.583
# Minibatch: 201 | Dis/Gen Cost:    1.285/2.080
# Minibatch: 401 | Dis/Gen Cost:    0.956/2.095
# Minibatch: 601 | Dis/Gen Cost:    1.246/1.574
# Minibatch: 801 | Dis/Gen Cost:    0.814/2.108
# Epoch:     049 | Dis/Gen AvgCost: 1.036/1.865
# Time elapsed: 1.78 min
# Minibatch: 001 | Dis/Gen Cost:    1.226/1.672
# Minibatch: 201 | Dis/Gen Cost:    1.229/1.527
# Minibatch: 401 | Dis/Gen Cost:    1.315/1.582
# Minibatch: 601 | Dis/Gen Cost:    0.840/1.702
# Minibatch: 801 | Dis/Gen Cost:    1.126/1.598
# Epoch:     050 | Dis/Gen AvgCost: 1.029/1.761
# Time elapsed: 1.81 min
# Minibatch: 001 | Dis/Gen Cost:    0.856/2.303
# Minibatch: 201 | Dis/Gen Cost:    0.816/2.232
# Minibatch: 401 | Dis/Gen Cost:    1.254/1.808
# Minibatch: 601 | Dis/Gen Cost:    1.090/1.655
# Minibatch: 801 | Dis/Gen Cost:    0.975/2.160
# Epoch:     051 | Dis/Gen AvgCost: 1.040/1.794
# Time elapsed: 1.85 min
# Minibatch: 001 | Dis/Gen Cost:    1.320/1.321
# Minibatch: 201 | Dis/Gen Cost:    1.232/1.468
# Minibatch: 401 | Dis/Gen Cost:    0.874/2.208
# Minibatch: 601 | Dis/Gen Cost:    0.887/1.874
# Minibatch: 801 | Dis/Gen Cost:    0.769/2.202
# Epoch:     052 | Dis/Gen AvgCost: 1.004/1.841
# Time elapsed: 1.89 min
# Minibatch: 001 | Dis/Gen Cost:    1.097/1.584
# Minibatch: 201 | Dis/Gen Cost:    1.034/2.041
# Minibatch: 401 | Dis/Gen Cost:    0.620/2.479
# Minibatch: 601 | Dis/Gen Cost:    0.532/3.203
# Minibatch: 801 | Dis/Gen Cost:    0.771/2.295
# Epoch:     053 | Dis/Gen AvgCost: 0.982/2.016
# Time elapsed: 1.92 min
# Minibatch: 001 | Dis/Gen Cost:    1.123/2.131
# Minibatch: 201 | Dis/Gen Cost:    0.906/1.767
# Minibatch: 401 | Dis/Gen Cost:    0.773/1.716
# Minibatch: 601 | Dis/Gen Cost:    0.851/2.137
# Minibatch: 801 | Dis/Gen Cost:    0.783/2.264
# Epoch:     054 | Dis/Gen AvgCost: 0.974/1.886
# Time elapsed: 1.96 min
# Minibatch: 001 | Dis/Gen Cost:    0.714/2.458
# Minibatch: 201 | Dis/Gen Cost:    0.956/1.869
# Minibatch: 401 | Dis/Gen Cost:    0.963/1.600
# Minibatch: 601 | Dis/Gen Cost:    0.947/2.048
# Minibatch: 801 | Dis/Gen Cost:    0.903/1.883
# Epoch:     055 | Dis/Gen AvgCost: 0.917/1.890
# Time elapsed: 1.99 min
# Minibatch: 001 | Dis/Gen Cost:    1.027/2.149
# Minibatch: 201 | Dis/Gen Cost:    0.672/2.153
# Minibatch: 401 | Dis/Gen Cost:    0.790/2.169
# Minibatch: 601 | Dis/Gen Cost:    1.023/1.684
# Minibatch: 801 | Dis/Gen Cost:    0.812/2.415
# Epoch:     056 | Dis/Gen AvgCost: 0.922/2.025
# Time elapsed: 2.03 min
# Minibatch: 001 | Dis/Gen Cost:    1.065/2.085
# Minibatch: 201 | Dis/Gen Cost:    0.963/1.867
# Minibatch: 401 | Dis/Gen Cost:    0.951/1.999
# Minibatch: 601 | Dis/Gen Cost:    1.299/1.550
# Minibatch: 801 | Dis/Gen Cost:    0.832/1.644
# Epoch:     057 | Dis/Gen AvgCost: 0.923/1.925
# Time elapsed: 2.07 min
# Minibatch: 001 | Dis/Gen Cost:    0.826/1.734
# Minibatch: 201 | Dis/Gen Cost:    0.761/1.810
# Minibatch: 401 | Dis/Gen Cost:    0.785/2.108
# Minibatch: 601 | Dis/Gen Cost:    0.784/1.998
# Minibatch: 801 | Dis/Gen Cost:    0.950/1.901
# Epoch:     058 | Dis/Gen AvgCost: 0.965/1.864
# Time elapsed: 2.10 min
# Minibatch: 001 | Dis/Gen Cost:    0.786/2.033
# Minibatch: 201 | Dis/Gen Cost:    1.116/1.690
# Minibatch: 401 | Dis/Gen Cost:    0.995/1.890
# Minibatch: 601 | Dis/Gen Cost:    1.263/1.418
# Minibatch: 801 | Dis/Gen Cost:    0.963/1.765
# Epoch:     059 | Dis/Gen AvgCost: 0.974/1.881
# Time elapsed: 2.14 min
# Minibatch: 001 | Dis/Gen Cost:    0.612/2.106
# Minibatch: 201 | Dis/Gen Cost:    1.384/1.392
# Minibatch: 401 | Dis/Gen Cost:    0.871/2.268
# Minibatch: 601 | Dis/Gen Cost:    0.981/2.280
# Minibatch: 801 | Dis/Gen Cost:    1.094/1.968
# Epoch:     060 | Dis/Gen AvgCost: 1.010/1.788
# Time elapsed: 2.17 min
# Minibatch: 001 | Dis/Gen Cost:    0.923/1.954
# Minibatch: 201 | Dis/Gen Cost:    1.355/1.361
# Minibatch: 401 | Dis/Gen Cost:    0.685/2.333
# Minibatch: 601 | Dis/Gen Cost:    1.454/1.230
# Minibatch: 801 | Dis/Gen Cost:    0.887/1.573
# Epoch:     061 | Dis/Gen AvgCost: 0.989/1.792
# Time elapsed: 2.21 min
# Minibatch: 001 | Dis/Gen Cost:    0.949/1.830
# Minibatch: 201 | Dis/Gen Cost:    1.123/1.460
# Minibatch: 401 | Dis/Gen Cost:    0.809/1.735
# Minibatch: 601 | Dis/Gen Cost:    0.883/1.973
# Minibatch: 801 | Dis/Gen Cost:    1.128/1.432
# Epoch:     062 | Dis/Gen AvgCost: 1.016/1.790
# Time elapsed: 2.25 min
# Minibatch: 001 | Dis/Gen Cost:    1.182/2.289
# Minibatch: 201 | Dis/Gen Cost:    0.964/1.946
# Minibatch: 401 | Dis/Gen Cost:    1.364/1.378
# Minibatch: 601 | Dis/Gen Cost:    1.009/1.884
# Minibatch: 801 | Dis/Gen Cost:    1.132/2.267
# Epoch:     063 | Dis/Gen AvgCost: 1.026/1.726
# Time elapsed: 2.28 min
# Minibatch: 001 | Dis/Gen Cost:    0.960/1.524
# Minibatch: 201 | Dis/Gen Cost:    0.945/1.671
# Minibatch: 401 | Dis/Gen Cost:    0.976/2.238
# Minibatch: 601 | Dis/Gen Cost:    0.863/1.545
# Minibatch: 801 | Dis/Gen Cost:    0.915/1.919
# Epoch:     064 | Dis/Gen AvgCost: 1.017/1.809
# Time elapsed: 2.32 min
# Minibatch: 001 | Dis/Gen Cost:    1.640/1.558
# Minibatch: 201 | Dis/Gen Cost:    0.979/1.698
# Minibatch: 401 | Dis/Gen Cost:    0.800/1.557
# Minibatch: 601 | Dis/Gen Cost:    0.888/2.122
# Minibatch: 801 | Dis/Gen Cost:    0.976/1.723
# Epoch:     065 | Dis/Gen AvgCost: 1.020/1.730
# Time elapsed: 2.36 min
# Minibatch: 001 | Dis/Gen Cost:    1.089/1.628
# Minibatch: 201 | Dis/Gen Cost:    0.662/2.238
# Minibatch: 401 | Dis/Gen Cost:    1.342/1.329
# Minibatch: 601 | Dis/Gen Cost:    0.992/1.529
# Minibatch: 801 | Dis/Gen Cost:    1.166/1.635
# Epoch:     066 | Dis/Gen AvgCost: 1.047/1.673
# Time elapsed: 2.39 min
# Minibatch: 001 | Dis/Gen Cost:    1.045/1.653
# Minibatch: 201 | Dis/Gen Cost:    0.899/1.610
# Minibatch: 401 | Dis/Gen Cost:    1.143/1.555
# Minibatch: 601 | Dis/Gen Cost:    0.927/1.578
# Minibatch: 801 | Dis/Gen Cost:    1.052/2.163
# Epoch:     067 | Dis/Gen AvgCost: 1.055/1.674
# Time elapsed: 2.43 min
# Minibatch: 001 | Dis/Gen Cost:    0.833/1.729
# Minibatch: 201 | Dis/Gen Cost:    1.638/1.325
# Minibatch: 401 | Dis/Gen Cost:    1.202/1.708
# Minibatch: 601 | Dis/Gen Cost:    1.206/1.388
# Minibatch: 801 | Dis/Gen Cost:    1.370/1.315
# Epoch:     068 | Dis/Gen AvgCost: 1.027/1.687
# Time elapsed: 2.46 min
# Minibatch: 001 | Dis/Gen Cost:    0.768/1.956
# Minibatch: 201 | Dis/Gen Cost:    1.046/1.739
# Minibatch: 401 | Dis/Gen Cost:    1.396/1.354
# Minibatch: 601 | Dis/Gen Cost:    0.870/2.233
# Minibatch: 801 | Dis/Gen Cost:    1.336/1.601
# Epoch:     069 | Dis/Gen AvgCost: 1.034/1.698
# Time elapsed: 2.50 min
# Minibatch: 001 | Dis/Gen Cost:    1.084/1.744
# Minibatch: 201 | Dis/Gen Cost:    1.220/1.489
# Minibatch: 401 | Dis/Gen Cost:    0.958/1.560
# Minibatch: 601 | Dis/Gen Cost:    1.149/1.523
# Minibatch: 801 | Dis/Gen Cost:    1.246/1.466
# Epoch:     070 | Dis/Gen AvgCost: 1.035/1.705
# Time elapsed: 2.54 min
# Minibatch: 001 | Dis/Gen Cost:    1.218/1.761
# Minibatch: 201 | Dis/Gen Cost:    1.289/1.620
# Minibatch: 401 | Dis/Gen Cost:    0.907/1.851
# Minibatch: 601 | Dis/Gen Cost:    0.852/1.464
# Minibatch: 801 | Dis/Gen Cost:    0.857/1.919
# Epoch:     071 | Dis/Gen AvgCost: 1.038/1.615
# Time elapsed: 2.57 min
# Minibatch: 001 | Dis/Gen Cost:    0.725/1.919
# Minibatch: 201 | Dis/Gen Cost:    1.125/1.466
# Minibatch: 401 | Dis/Gen Cost:    1.105/1.142
# Minibatch: 601 | Dis/Gen Cost:    0.813/2.338
# Minibatch: 801 | Dis/Gen Cost:    1.025/1.532
# Epoch:     072 | Dis/Gen AvgCost: 1.009/1.735
# Time elapsed: 2.61 min
# Minibatch: 001 | Dis/Gen Cost:    0.715/1.911
# Minibatch: 201 | Dis/Gen Cost:    1.026/1.626
# Minibatch: 401 | Dis/Gen Cost:    1.256/1.514
# Minibatch: 601 | Dis/Gen Cost:    1.410/1.107
# Minibatch: 801 | Dis/Gen Cost:    1.060/1.375
# Epoch:     073 | Dis/Gen AvgCost: 1.020/1.685
# Time elapsed: 2.64 min
# Minibatch: 001 | Dis/Gen Cost:    1.149/1.888
# Minibatch: 201 | Dis/Gen Cost:    0.907/1.888
# Minibatch: 401 | Dis/Gen Cost:    1.069/1.372
# Minibatch: 601 | Dis/Gen Cost:    1.014/1.864
# Minibatch: 801 | Dis/Gen Cost:    1.235/1.327
# Epoch:     074 | Dis/Gen AvgCost: 1.007/1.683
# Time elapsed: 2.68 min
# Minibatch: 001 | Dis/Gen Cost:    1.144/1.844
# Minibatch: 201 | Dis/Gen Cost:    1.198/1.434
# Minibatch: 401 | Dis/Gen Cost:    1.003/1.560
# Minibatch: 601 | Dis/Gen Cost:    0.968/1.540
# Minibatch: 801 | Dis/Gen Cost:    0.910/1.879
# Epoch:     075 | Dis/Gen AvgCost: 1.038/1.688
# Time elapsed: 2.72 min
# Minibatch: 001 | Dis/Gen Cost:    1.135/1.604
# Minibatch: 201 | Dis/Gen Cost:    1.171/1.883
# Minibatch: 401 | Dis/Gen Cost:    0.880/1.873
# Minibatch: 601 | Dis/Gen Cost:    0.863/1.542
# Minibatch: 801 | Dis/Gen Cost:    0.996/1.396
# Epoch:     076 | Dis/Gen AvgCost: 1.031/1.657
# Time elapsed: 2.75 min
# Minibatch: 001 | Dis/Gen Cost:    1.019/1.236
# Minibatch: 201 | Dis/Gen Cost:    0.907/1.596
# Minibatch: 401 | Dis/Gen Cost:    1.329/1.350
# Minibatch: 601 | Dis/Gen Cost:    1.007/1.542
# Minibatch: 801 | Dis/Gen Cost:    1.151/1.396
# Epoch:     077 | Dis/Gen AvgCost: 1.042/1.654
# Time elapsed: 2.79 min
# Minibatch: 001 | Dis/Gen Cost:    1.097/1.785
# Minibatch: 201 | Dis/Gen Cost:    0.768/2.163
# Minibatch: 401 | Dis/Gen Cost:    1.153/1.571
# Minibatch: 601 | Dis/Gen Cost:    1.031/1.799
# Minibatch: 801 | Dis/Gen Cost:    1.206/1.126
# Epoch:     078 | Dis/Gen AvgCost: 1.014/1.664
# Time elapsed: 2.83 min
# Minibatch: 001 | Dis/Gen Cost:    1.059/1.586
# Minibatch: 201 | Dis/Gen Cost:    0.940/2.420
# Minibatch: 401 | Dis/Gen Cost:    1.185/1.371
# Minibatch: 601 | Dis/Gen Cost:    0.768/2.458
# Minibatch: 801 | Dis/Gen Cost:    1.042/2.056
# Epoch:     079 | Dis/Gen AvgCost: 1.014/1.693
# Time elapsed: 2.86 min
# Minibatch: 001 | Dis/Gen Cost:    0.795/2.306
# Minibatch: 201 | Dis/Gen Cost:    0.842/1.510
# Minibatch: 401 | Dis/Gen Cost:    1.131/1.549
# Minibatch: 601 | Dis/Gen Cost:    0.796/2.202
# Minibatch: 801 | Dis/Gen Cost:    1.233/1.621
# Epoch:     080 | Dis/Gen AvgCost: 1.012/1.691
# Time elapsed: 2.90 min
# Minibatch: 001 | Dis/Gen Cost:    0.660/2.069
# Minibatch: 201 | Dis/Gen Cost:    0.936/1.808
# Minibatch: 401 | Dis/Gen Cost:    1.150/1.477
# Minibatch: 601 | Dis/Gen Cost:    1.053/1.705
# Minibatch: 801 | Dis/Gen Cost:    1.089/1.262
# Epoch:     081 | Dis/Gen AvgCost: 1.015/1.649
# Time elapsed: 2.93 min
# Minibatch: 001 | Dis/Gen Cost:    1.360/1.275
# Minibatch: 201 | Dis/Gen Cost:    0.911/1.838
# Minibatch: 401 | Dis/Gen Cost:    1.163/1.453
# Minibatch: 601 | Dis/Gen Cost:    0.749/2.020
# Minibatch: 801 | Dis/Gen Cost:    0.972/1.286
# Epoch:     082 | Dis/Gen AvgCost: 1.019/1.606
# Time elapsed: 2.97 min
# Minibatch: 001 | Dis/Gen Cost:    1.174/1.578
# Minibatch: 201 | Dis/Gen Cost:    0.907/1.597
# Minibatch: 401 | Dis/Gen Cost:    1.336/1.425
# Minibatch: 601 | Dis/Gen Cost:    0.875/1.758
# Minibatch: 801 | Dis/Gen Cost:    1.033/1.699
# Epoch:     083 | Dis/Gen AvgCost: 1.022/1.624
# Time elapsed: 3.01 min
# Minibatch: 001 | Dis/Gen Cost:    1.303/1.242
# Minibatch: 201 | Dis/Gen Cost:    0.865/1.921
# Minibatch: 401 | Dis/Gen Cost:    0.946/1.956
# Minibatch: 601 | Dis/Gen Cost:    0.756/1.754
# Minibatch: 801 | Dis/Gen Cost:    1.179/1.532
# Epoch:     084 | Dis/Gen AvgCost: 1.016/1.643
# Time elapsed: 3.04 min
# Minibatch: 001 | Dis/Gen Cost:    1.544/1.526
# Minibatch: 201 | Dis/Gen Cost:    0.867/1.443
# Minibatch: 401 | Dis/Gen Cost:    1.001/1.559
# Minibatch: 601 | Dis/Gen Cost:    0.973/1.867
# Minibatch: 801 | Dis/Gen Cost:    0.852/1.762
# Epoch:     085 | Dis/Gen AvgCost: 1.022/1.615
# Time elapsed: 3.08 min
# Minibatch: 001 | Dis/Gen Cost:    1.288/1.558
# Minibatch: 201 | Dis/Gen Cost:    0.879/1.642
# Minibatch: 401 | Dis/Gen Cost:    0.889/1.829
# Minibatch: 601 | Dis/Gen Cost:    1.279/1.383
# Minibatch: 801 | Dis/Gen Cost:    1.047/1.945
# Epoch:     086 | Dis/Gen AvgCost: 1.005/1.664
# Time elapsed: 3.12 min
# Minibatch: 001 | Dis/Gen Cost:    0.913/2.029
# Minibatch: 201 | Dis/Gen Cost:    1.102/1.485
# Minibatch: 401 | Dis/Gen Cost:    0.893/1.551
# Minibatch: 601 | Dis/Gen Cost:    1.012/1.562
# Minibatch: 801 | Dis/Gen Cost:    1.001/1.791
# Epoch:     087 | Dis/Gen AvgCost: 0.990/1.684
# Time elapsed: 3.15 min
# Minibatch: 001 | Dis/Gen Cost:    0.967/1.441
# Minibatch: 201 | Dis/Gen Cost:    1.100/1.810
# Minibatch: 401 | Dis/Gen Cost:    1.059/1.993
# Minibatch: 601 | Dis/Gen Cost:    1.186/1.593
# Minibatch: 801 | Dis/Gen Cost:    1.003/1.697
# Epoch:     088 | Dis/Gen AvgCost: 0.983/1.689
# Time elapsed: 3.19 min
# Minibatch: 001 | Dis/Gen Cost:    0.693/2.465
# Minibatch: 201 | Dis/Gen Cost:    1.122/1.459
# Minibatch: 401 | Dis/Gen Cost:    1.103/1.780
# Minibatch: 601 | Dis/Gen Cost:    0.890/2.128
# Minibatch: 801 | Dis/Gen Cost:    1.153/1.905
# Epoch:     089 | Dis/Gen AvgCost: 1.019/1.649
# Time elapsed: 3.22 min
# Minibatch: 001 | Dis/Gen Cost:    1.110/2.076
# Minibatch: 201 | Dis/Gen Cost:    0.835/2.258
# Minibatch: 401 | Dis/Gen Cost:    0.882/1.861
# Minibatch: 601 | Dis/Gen Cost:    0.970/2.016
# Minibatch: 801 | Dis/Gen Cost:    1.078/1.951
# Epoch:     090 | Dis/Gen AvgCost: 0.999/1.694
# Time elapsed: 3.26 min
# Minibatch: 001 | Dis/Gen Cost:    0.762/1.709
# Minibatch: 201 | Dis/Gen Cost:    1.077/1.560
# Minibatch: 401 | Dis/Gen Cost:    1.027/1.257
# Minibatch: 601 | Dis/Gen Cost:    1.013/1.719
# Minibatch: 801 | Dis/Gen Cost:    0.827/2.128
# Epoch:     091 | Dis/Gen AvgCost: 0.997/1.669
# Time elapsed: 3.30 min
# Minibatch: 001 | Dis/Gen Cost:    0.977/1.352
# Minibatch: 201 | Dis/Gen Cost:    1.122/1.224
# Minibatch: 401 | Dis/Gen Cost:    0.866/1.813
# Minibatch: 601 | Dis/Gen Cost:    0.951/1.349
# Minibatch: 801 | Dis/Gen Cost:    1.089/1.796
# Epoch:     092 | Dis/Gen AvgCost: 0.981/1.654
# Time elapsed: 3.33 min
# Minibatch: 001 | Dis/Gen Cost:    0.962/1.507
# Minibatch: 201 | Dis/Gen Cost:    0.780/1.730
# Minibatch: 401 | Dis/Gen Cost:    0.968/1.604
# Minibatch: 601 | Dis/Gen Cost:    0.903/1.799
# Minibatch: 801 | Dis/Gen Cost:    0.977/2.030
# Epoch:     093 | Dis/Gen AvgCost: 0.991/1.658
# Time elapsed: 3.37 min
# Minibatch: 001 | Dis/Gen Cost:    0.899/2.145
# Minibatch: 201 | Dis/Gen Cost:    0.945/1.674
# Minibatch: 401 | Dis/Gen Cost:    1.017/2.031
# Minibatch: 601 | Dis/Gen Cost:    1.203/1.459
# Minibatch: 801 | Dis/Gen Cost:    0.876/1.756
# Epoch:     094 | Dis/Gen AvgCost: 0.972/1.676
# Time elapsed: 3.41 min
# Minibatch: 001 | Dis/Gen Cost:    1.015/1.808
# Minibatch: 201 | Dis/Gen Cost:    0.924/1.550
# Minibatch: 401 | Dis/Gen Cost:    0.749/2.087
# Minibatch: 601 | Dis/Gen Cost:    1.251/1.128
# Minibatch: 801 | Dis/Gen Cost:    1.007/1.525
# Epoch:     095 | Dis/Gen AvgCost: 0.975/1.714
# Time elapsed: 3.44 min
# Minibatch: 001 | Dis/Gen Cost:    0.925/1.782
# Minibatch: 201 | Dis/Gen Cost:    0.910/1.532
# Minibatch: 401 | Dis/Gen Cost:    0.840/2.154
# Minibatch: 601 | Dis/Gen Cost:    0.896/1.737
# Minibatch: 801 | Dis/Gen Cost:    1.118/1.847
# Epoch:     096 | Dis/Gen AvgCost: 0.975/1.673
# Time elapsed: 3.48 min
# Minibatch: 001 | Dis/Gen Cost:    1.160/1.808
# Minibatch: 201 | Dis/Gen Cost:    0.967/1.639
# Minibatch: 401 | Dis/Gen Cost:    1.214/1.340
# Minibatch: 601 | Dis/Gen Cost:    0.964/1.510
# Minibatch: 801 | Dis/Gen Cost:    0.819/1.913
# Epoch:     097 | Dis/Gen AvgCost: 0.965/1.745
# Time elapsed: 3.51 min
# Minibatch: 001 | Dis/Gen Cost:    0.904/1.483
# Minibatch: 201 | Dis/Gen Cost:    0.720/1.893
# Minibatch: 401 | Dis/Gen Cost:    0.777/1.719
# Minibatch: 601 | Dis/Gen Cost:    1.139/1.319
# Minibatch: 801 | Dis/Gen Cost:    1.081/1.478
# Epoch:     098 | Dis/Gen AvgCost: 0.992/1.710
# Time elapsed: 3.55 min
# Minibatch: 001 | Dis/Gen Cost:    1.207/1.616
# Minibatch: 201 | Dis/Gen Cost:    0.918/1.792
# Minibatch: 401 | Dis/Gen Cost:    0.776/2.159
# Minibatch: 601 | Dis/Gen Cost:    1.058/1.498
# Minibatch: 801 | Dis/Gen Cost:    0.824/1.830
# Epoch:     099 | Dis/Gen AvgCost: 0.992/1.659
# Time elapsed: 3.59 min
# Minibatch: 001 | Dis/Gen Cost:    1.120/1.738
# Minibatch: 201 | Dis/Gen Cost:    0.929/1.793
# Minibatch: 401 | Dis/Gen Cost:    1.094/1.723
# Minibatch: 601 | Dis/Gen Cost:    1.254/1.256
# Minibatch: 801 | Dis/Gen Cost:    1.146/1.497
# Epoch:     100 | Dis/Gen AvgCost: 0.985/1.680
# Time elapsed: 3.62 min
# Minibatch: 001 | Dis/Gen Cost:    0.930/1.507
# Minibatch: 201 | Dis/Gen Cost:    1.154/1.641
# Minibatch: 401 | Dis/Gen Cost:    0.997/1.660
# Minibatch: 601 | Dis/Gen Cost:    1.059/1.471
# Minibatch: 801 | Dis/Gen Cost:    0.774/1.871
# Epoch:     101 | Dis/Gen AvgCost: 0.994/1.686
# Time elapsed: 3.66 min
# Minibatch: 001 | Dis/Gen Cost:    1.430/1.349
# Minibatch: 201 | Dis/Gen Cost:    1.176/1.584
# Minibatch: 401 | Dis/Gen Cost:    0.993/1.739
# Minibatch: 601 | Dis/Gen Cost:    1.075/1.347
# Minibatch: 801 | Dis/Gen Cost:    1.027/1.666
# Epoch:     102 | Dis/Gen AvgCost: 0.986/1.656
# Time elapsed: 3.69 min
# Minibatch: 001 | Dis/Gen Cost:    1.289/1.304
# Minibatch: 201 | Dis/Gen Cost:    0.659/2.139
# Minibatch: 401 | Dis/Gen Cost:    0.922/1.897
# Minibatch: 601 | Dis/Gen Cost:    0.810/1.682
# Minibatch: 801 | Dis/Gen Cost:    0.823/1.879
# Epoch:     103 | Dis/Gen AvgCost: 0.984/1.667
# Time elapsed: 3.73 min
# Minibatch: 001 | Dis/Gen Cost:    0.867/1.834
# Minibatch: 201 | Dis/Gen Cost:    1.295/1.430
# Minibatch: 401 | Dis/Gen Cost:    0.810/1.934
# Minibatch: 601 | Dis/Gen Cost:    1.099/1.684
# Minibatch: 801 | Dis/Gen Cost:    0.943/1.632
# Epoch:     104 | Dis/Gen AvgCost: 0.984/1.715
# Time elapsed: 3.77 min
# Minibatch: 001 | Dis/Gen Cost:    0.899/1.701
# Minibatch: 201 | Dis/Gen Cost:    0.991/1.693
# Minibatch: 401 | Dis/Gen Cost:    0.959/1.664
# Minibatch: 601 | Dis/Gen Cost:    1.122/1.612
# Minibatch: 801 | Dis/Gen Cost:    0.946/1.881
# Epoch:     105 | Dis/Gen AvgCost: 1.001/1.654
# Time elapsed: 3.80 min
# Minibatch: 001 | Dis/Gen Cost:    0.855/1.630
# Minibatch: 201 | Dis/Gen Cost:    1.177/1.495
# Minibatch: 401 | Dis/Gen Cost:    1.068/1.470
# Minibatch: 601 | Dis/Gen Cost:    1.007/1.716
# Minibatch: 801 | Dis/Gen Cost:    1.045/1.772
# Epoch:     106 | Dis/Gen AvgCost: 1.009/1.622
# Time elapsed: 3.84 min
# Minibatch: 001 | Dis/Gen Cost:    1.109/1.247
# Minibatch: 201 | Dis/Gen Cost:    1.145/1.137
# Minibatch: 401 | Dis/Gen Cost:    0.917/1.814
# Minibatch: 601 | Dis/Gen Cost:    1.065/1.291
# Minibatch: 801 | Dis/Gen Cost:    0.942/1.650
# Epoch:     107 | Dis/Gen AvgCost: 0.997/1.626
# Time elapsed: 3.87 min
# Minibatch: 001 | Dis/Gen Cost:    1.063/1.443
# Minibatch: 201 | Dis/Gen Cost:    0.743/1.842
# Minibatch: 401 | Dis/Gen Cost:    1.055/1.943
# Minibatch: 601 | Dis/Gen Cost:    0.858/1.596
# Minibatch: 801 | Dis/Gen Cost:    0.961/1.454
# Epoch:     108 | Dis/Gen AvgCost: 1.005/1.576
# Time elapsed: 3.91 min
# Minibatch: 001 | Dis/Gen Cost:    1.061/1.632
# Minibatch: 201 | Dis/Gen Cost:    0.863/2.113
# Minibatch: 401 | Dis/Gen Cost:    1.036/1.491
# Minibatch: 601 | Dis/Gen Cost:    1.081/1.636
# Minibatch: 801 | Dis/Gen Cost:    1.206/1.316
# Epoch:     109 | Dis/Gen AvgCost: 1.005/1.619
# Time elapsed: 3.95 min
# Minibatch: 001 | Dis/Gen Cost:    1.233/1.126
# Minibatch: 201 | Dis/Gen Cost:    1.136/1.222
# Minibatch: 401 | Dis/Gen Cost:    1.163/1.467
# Minibatch: 601 | Dis/Gen Cost:    1.066/1.464
# Minibatch: 801 | Dis/Gen Cost:    0.988/1.552
# Epoch:     110 | Dis/Gen AvgCost: 1.001/1.641
# Time elapsed: 3.98 min
# Minibatch: 001 | Dis/Gen Cost:    0.944/1.414
# Minibatch: 201 | Dis/Gen Cost:    1.012/1.276
# Minibatch: 401 | Dis/Gen Cost:    1.018/1.395
# Minibatch: 601 | Dis/Gen Cost:    0.898/1.546
# Minibatch: 801 | Dis/Gen Cost:    1.089/1.787
# Epoch:     111 | Dis/Gen AvgCost: 0.990/1.603
# Time elapsed: 4.02 min
# Minibatch: 001 | Dis/Gen Cost:    0.819/1.917
# Minibatch: 201 | Dis/Gen Cost:    0.936/1.619
# Minibatch: 401 | Dis/Gen Cost:    0.862/1.933
# Minibatch: 601 | Dis/Gen Cost:    0.981/1.387
# Minibatch: 801 | Dis/Gen Cost:    0.948/1.298
# Epoch:     112 | Dis/Gen AvgCost: 1.000/1.620
# Time elapsed: 4.06 min
# Minibatch: 001 | Dis/Gen Cost:    1.122/1.785
# Minibatch: 201 | Dis/Gen Cost:    1.002/1.431
# Minibatch: 401 | Dis/Gen Cost:    1.027/2.054
# Minibatch: 601 | Dis/Gen Cost:    0.761/1.860
# Minibatch: 801 | Dis/Gen Cost:    1.042/1.970
# Epoch:     113 | Dis/Gen AvgCost: 0.988/1.624
# Time elapsed: 4.09 min
# Minibatch: 001 | Dis/Gen Cost:    1.093/1.576
# Minibatch: 201 | Dis/Gen Cost:    1.177/1.448
# Minibatch: 401 | Dis/Gen Cost:    1.019/1.515
# Minibatch: 601 | Dis/Gen Cost:    1.051/1.527
# Minibatch: 801 | Dis/Gen Cost:    1.099/1.584
# Epoch:     114 | Dis/Gen AvgCost: 0.991/1.645
# Time elapsed: 4.13 min
# Minibatch: 001 | Dis/Gen Cost:    1.353/1.301
# Minibatch: 201 | Dis/Gen Cost:    0.992/1.543
# Minibatch: 401 | Dis/Gen Cost:    0.959/1.694
# Minibatch: 601 | Dis/Gen Cost:    0.937/1.448
# Minibatch: 801 | Dis/Gen Cost:    1.031/1.580
# Epoch:     115 | Dis/Gen AvgCost: 0.993/1.611
# Time elapsed: 4.16 min
# Minibatch: 001 | Dis/Gen Cost:    1.003/1.806
# Minibatch: 201 | Dis/Gen Cost:    1.134/1.766
# Minibatch: 401 | Dis/Gen Cost:    1.090/1.636
# Minibatch: 601 | Dis/Gen Cost:    0.821/1.774
# Minibatch: 801 | Dis/Gen Cost:    1.077/1.524
# Epoch:     116 | Dis/Gen AvgCost: 0.981/1.591
# Time elapsed: 4.20 min
# Minibatch: 001 | Dis/Gen Cost:    0.936/1.598
# Minibatch: 201 | Dis/Gen Cost:    1.026/1.788
# Minibatch: 401 | Dis/Gen Cost:    0.995/1.896
# Minibatch: 601 | Dis/Gen Cost:    0.763/1.791
# Minibatch: 801 | Dis/Gen Cost:    1.029/1.292
# Epoch:     117 | Dis/Gen AvgCost: 0.979/1.640
# Time elapsed: 4.24 min
# Minibatch: 001 | Dis/Gen Cost:    1.021/1.634
# Minibatch: 201 | Dis/Gen Cost:    1.134/1.331
# Minibatch: 401 | Dis/Gen Cost:    0.970/1.336
# Minibatch: 601 | Dis/Gen Cost:    0.881/1.805
# Minibatch: 801 | Dis/Gen Cost:    0.967/2.010
# Epoch:     118 | Dis/Gen AvgCost: 0.988/1.604
# Time elapsed: 4.27 min
# Minibatch: 001 | Dis/Gen Cost:    0.914/2.038
# Minibatch: 201 | Dis/Gen Cost:    0.704/1.753
# Minibatch: 401 | Dis/Gen Cost:    1.135/1.464
# Minibatch: 601 | Dis/Gen Cost:    0.861/1.717
# Minibatch: 801 | Dis/Gen Cost:    0.695/1.647
# Epoch:     119 | Dis/Gen AvgCost: 0.983/1.643
# Time elapsed: 4.31 min
# Minibatch: 001 | Dis/Gen Cost:    1.044/1.495
# Minibatch: 201 | Dis/Gen Cost:    0.919/1.900
# Minibatch: 401 | Dis/Gen Cost:    0.910/1.993
# Minibatch: 601 | Dis/Gen Cost:    0.851/1.808
# Minibatch: 801 | Dis/Gen Cost:    0.879/1.648
# Epoch:     120 | Dis/Gen AvgCost: 0.969/1.661
# Time elapsed: 4.34 min
# Minibatch: 001 | Dis/Gen Cost:    0.909/1.576
# Minibatch: 201 | Dis/Gen Cost:    0.789/1.568
# Minibatch: 401 | Dis/Gen Cost:    1.195/1.410
# Minibatch: 601 | Dis/Gen Cost:    0.989/1.642
# Minibatch: 801 | Dis/Gen Cost:    1.087/1.502
# Epoch:     121 | Dis/Gen AvgCost: 0.983/1.605
# Time elapsed: 4.38 min
# Minibatch: 001 | Dis/Gen Cost:    1.161/1.174
# Minibatch: 201 | Dis/Gen Cost:    0.877/1.861
# Minibatch: 401 | Dis/Gen Cost:    1.212/1.439
# Minibatch: 601 | Dis/Gen Cost:    1.031/1.691
# Minibatch: 801 | Dis/Gen Cost:    0.941/1.791
# Epoch:     122 | Dis/Gen AvgCost: 0.981/1.586
# Time elapsed: 4.42 min
# Minibatch: 001 | Dis/Gen Cost:    1.119/1.157
# Minibatch: 201 | Dis/Gen Cost:    0.816/1.759
# Minibatch: 401 | Dis/Gen Cost:    0.841/1.899
# Minibatch: 601 | Dis/Gen Cost:    1.108/1.205
# Minibatch: 801 | Dis/Gen Cost:    0.892/1.577
# Epoch:     123 | Dis/Gen AvgCost: 0.979/1.617
# Time elapsed: 4.45 min
# Minibatch: 001 | Dis/Gen Cost:    1.031/1.258
# Minibatch: 201 | Dis/Gen Cost:    0.911/1.522
# Minibatch: 401 | Dis/Gen Cost:    1.061/1.430
# Minibatch: 601 | Dis/Gen Cost:    0.991/1.638
# Minibatch: 801 | Dis/Gen Cost:    1.237/1.462
# Epoch:     124 | Dis/Gen AvgCost: 0.984/1.596
# Time elapsed: 4.49 min
# Minibatch: 001 | Dis/Gen Cost:    0.759/1.803
# Minibatch: 201 | Dis/Gen Cost:    1.036/1.949
# Minibatch: 401 | Dis/Gen Cost:    1.120/1.769
# Minibatch: 601 | Dis/Gen Cost:    0.925/1.615
# Minibatch: 801 | Dis/Gen Cost:    1.223/1.490
# Epoch:     125 | Dis/Gen AvgCost: 0.988/1.631
# Time elapsed: 4.53 min
# Minibatch: 001 | Dis/Gen Cost:    1.096/1.853
# Minibatch: 201 | Dis/Gen Cost:    1.043/1.339
# Minibatch: 401 | Dis/Gen Cost:    0.772/2.075
# Minibatch: 601 | Dis/Gen Cost:    0.778/1.941
# Minibatch: 801 | Dis/Gen Cost:    1.142/1.734
# Epoch:     126 | Dis/Gen AvgCost: 0.981/1.611
# Time elapsed: 4.56 min
# Minibatch: 001 | Dis/Gen Cost:    0.943/1.491
# Minibatch: 201 | Dis/Gen Cost:    1.064/1.433
# Minibatch: 401 | Dis/Gen Cost:    0.913/1.591
# Minibatch: 601 | Dis/Gen Cost:    0.984/1.523
# Minibatch: 801 | Dis/Gen Cost:    1.141/1.394
# Epoch:     127 | Dis/Gen AvgCost: 0.992/1.613
# Time elapsed: 4.60 min
# Minibatch: 001 | Dis/Gen Cost:    0.799/1.633
# Minibatch: 201 | Dis/Gen Cost:    1.001/1.872
# Minibatch: 401 | Dis/Gen Cost:    0.961/1.496
# Minibatch: 601 | Dis/Gen Cost:    1.101/1.610
# Minibatch: 801 | Dis/Gen Cost:    0.841/1.923
# Epoch:     128 | Dis/Gen AvgCost: 0.992/1.612
# Time elapsed: 4.64 min
# Minibatch: 001 | Dis/Gen Cost:    1.143/1.205
# Minibatch: 201 | Dis/Gen Cost:    1.118/1.698
# Minibatch: 401 | Dis/Gen Cost:    1.022/1.412
# Minibatch: 601 | Dis/Gen Cost:    1.023/1.558
# Minibatch: 801 | Dis/Gen Cost:    1.061/1.411
# Epoch:     129 | Dis/Gen AvgCost: 0.992/1.585
# Time elapsed: 4.67 min
# Minibatch: 001 | Dis/Gen Cost:    0.958/1.253
# Minibatch: 201 | Dis/Gen Cost:    0.985/1.752
# Minibatch: 401 | Dis/Gen Cost:    0.875/1.705
# Minibatch: 601 | Dis/Gen Cost:    0.950/1.611
# Minibatch: 801 | Dis/Gen Cost:    0.972/1.891
# Epoch:     130 | Dis/Gen AvgCost: 1.005/1.563
# Time elapsed: 4.71 min
# Minibatch: 001 | Dis/Gen Cost:    1.046/1.628
# Minibatch: 201 | Dis/Gen Cost:    0.959/1.588
# Minibatch: 401 | Dis/Gen Cost:    1.138/1.334
# Minibatch: 601 | Dis/Gen Cost:    1.063/1.498
# Minibatch: 801 | Dis/Gen Cost:    0.963/1.460
# Epoch:     131 | Dis/Gen AvgCost: 0.995/1.579
# Time elapsed: 4.74 min
# Minibatch: 001 | Dis/Gen Cost:    1.190/1.274
# Minibatch: 201 | Dis/Gen Cost:    0.894/1.696
# Minibatch: 401 | Dis/Gen Cost:    1.032/1.633
# Minibatch: 601 | Dis/Gen Cost:    1.058/1.498
# Minibatch: 801 | Dis/Gen Cost:    0.795/1.833
# Epoch:     132 | Dis/Gen AvgCost: 0.994/1.587
# Time elapsed: 4.78 min
# Minibatch: 001 | Dis/Gen Cost:    1.060/1.128
# Minibatch: 201 | Dis/Gen Cost:    1.110/1.320
# Minibatch: 401 | Dis/Gen Cost:    0.801/1.786
# Minibatch: 601 | Dis/Gen Cost:    1.152/1.691
# Minibatch: 801 | Dis/Gen Cost:    0.937/1.669
# Epoch:     133 | Dis/Gen AvgCost: 1.000/1.574
# Time elapsed: 4.82 min
# Minibatch: 001 | Dis/Gen Cost:    1.142/1.299
# Minibatch: 201 | Dis/Gen Cost:    0.917/1.674
# Minibatch: 401 | Dis/Gen Cost:    0.987/1.919
# Minibatch: 601 | Dis/Gen Cost:    1.069/1.447
# Minibatch: 801 | Dis/Gen Cost:    1.249/1.403
# Epoch:     134 | Dis/Gen AvgCost: 0.987/1.597
# Time elapsed: 4.85 min
# Minibatch: 001 | Dis/Gen Cost:    0.947/1.828
# Minibatch: 201 | Dis/Gen Cost:    1.202/1.676
# Minibatch: 401 | Dis/Gen Cost:    1.008/1.578
# Minibatch: 601 | Dis/Gen Cost:    1.017/1.375
# Minibatch: 801 | Dis/Gen Cost:    0.972/1.721
# Epoch:     135 | Dis/Gen AvgCost: 0.991/1.562
# Time elapsed: 4.89 min
# Minibatch: 001 | Dis/Gen Cost:    0.977/1.936
# Minibatch: 201 | Dis/Gen Cost:    0.810/1.852
# Minibatch: 401 | Dis/Gen Cost:    1.074/1.721
# Minibatch: 601 | Dis/Gen Cost:    0.786/1.857
# Minibatch: 801 | Dis/Gen Cost:    0.854/1.582
# Epoch:     136 | Dis/Gen AvgCost: 0.993/1.586
# Time elapsed: 4.93 min
# Minibatch: 001 | Dis/Gen Cost:    0.931/1.431
# Minibatch: 201 | Dis/Gen Cost:    0.941/1.675
# Minibatch: 401 | Dis/Gen Cost:    0.954/1.349
# Minibatch: 601 | Dis/Gen Cost:    0.985/1.561
# Minibatch: 801 | Dis/Gen Cost:    0.880/1.687
# Epoch:     137 | Dis/Gen AvgCost: 0.986/1.587
# Time elapsed: 4.96 min
# Minibatch: 001 | Dis/Gen Cost:    0.947/1.458
# Minibatch: 201 | Dis/Gen Cost:    1.200/1.284
# Minibatch: 401 | Dis/Gen Cost:    0.958/1.796
# Minibatch: 601 | Dis/Gen Cost:    1.166/1.514
# Minibatch: 801 | Dis/Gen Cost:    0.956/1.882
# Epoch:     138 | Dis/Gen AvgCost: 0.994/1.608
# Time elapsed: 5.00 min
# Minibatch: 001 | Dis/Gen Cost:    0.794/1.685
# Minibatch: 201 | Dis/Gen Cost:    0.851/1.788
# Minibatch: 401 | Dis/Gen Cost:    0.916/1.673
# Minibatch: 601 | Dis/Gen Cost:    0.934/2.116
# Minibatch: 801 | Dis/Gen Cost:    1.138/1.377
# Epoch:     139 | Dis/Gen AvgCost: 0.984/1.604
# Time elapsed: 5.03 min
# Minibatch: 001 | Dis/Gen Cost:    1.137/1.398
# Minibatch: 201 | Dis/Gen Cost:    0.927/1.597
# Minibatch: 401 | Dis/Gen Cost:    0.965/1.412
# Minibatch: 601 | Dis/Gen Cost:    1.040/1.476
# Minibatch: 801 | Dis/Gen Cost:    1.206/1.365
# Epoch:     140 | Dis/Gen AvgCost: 0.984/1.571
# Time elapsed: 5.07 min
# Minibatch: 001 | Dis/Gen Cost:    0.917/2.086
# Minibatch: 201 | Dis/Gen Cost:    1.075/1.911
# Minibatch: 401 | Dis/Gen Cost:    1.142/1.416
# Minibatch: 601 | Dis/Gen Cost:    0.904/1.706
# Minibatch: 801 | Dis/Gen Cost:    0.822/1.780
# Epoch:     141 | Dis/Gen AvgCost: 0.981/1.591
# Time elapsed: 5.11 min
# Minibatch: 001 | Dis/Gen Cost:    0.967/1.420
# Minibatch: 201 | Dis/Gen Cost:    0.805/1.933
# Minibatch: 401 | Dis/Gen Cost:    1.164/1.691
# Minibatch: 601 | Dis/Gen Cost:    1.029/1.538
# Minibatch: 801 | Dis/Gen Cost:    1.048/1.614
# Epoch:     142 | Dis/Gen AvgCost: 0.975/1.631
# Time elapsed: 5.14 min
# Minibatch: 001 | Dis/Gen Cost:    1.084/2.132
# Minibatch: 201 | Dis/Gen Cost:    1.028/1.795
# Minibatch: 401 | Dis/Gen Cost:    1.124/1.306
# Minibatch: 601 | Dis/Gen Cost:    0.800/1.930
# Minibatch: 801 | Dis/Gen Cost:    0.928/1.521
# Epoch:     143 | Dis/Gen AvgCost: 0.983/1.602
# Time elapsed: 5.18 min
# Minibatch: 001 | Dis/Gen Cost:    1.199/1.430
# Minibatch: 201 | Dis/Gen Cost:    1.008/1.413
# Minibatch: 401 | Dis/Gen Cost:    1.041/1.552
# Minibatch: 601 | Dis/Gen Cost:    0.820/1.926
# Minibatch: 801 | Dis/Gen Cost:    0.958/1.550
# Epoch:     144 | Dis/Gen AvgCost: 0.983/1.597
# Time elapsed: 5.22 min
# Minibatch: 001 | Dis/Gen Cost:    0.989/2.031
# Minibatch: 201 | Dis/Gen Cost:    0.844/1.410
# Minibatch: 401 | Dis/Gen Cost:    0.987/1.250
# Minibatch: 601 | Dis/Gen Cost:    0.975/1.373
# Minibatch: 801 | Dis/Gen Cost:    1.175/1.256
# Epoch:     145 | Dis/Gen AvgCost: 0.973/1.610
# Time elapsed: 5.25 min
# Minibatch: 001 | Dis/Gen Cost:    1.188/1.452
# Minibatch: 201 | Dis/Gen Cost:    0.827/1.667
# Minibatch: 401 | Dis/Gen Cost:    0.932/1.920
# Minibatch: 601 | Dis/Gen Cost:    0.870/1.904
# Minibatch: 801 | Dis/Gen Cost:    0.984/1.400
# Epoch:     146 | Dis/Gen AvgCost: 0.972/1.596
# Time elapsed: 5.29 min
# Minibatch: 001 | Dis/Gen Cost:    1.014/1.545
# Minibatch: 201 | Dis/Gen Cost:    1.009/1.595
# Minibatch: 401 | Dis/Gen Cost:    0.944/1.541
# Minibatch: 601 | Dis/Gen Cost:    1.181/0.987
# Minibatch: 801 | Dis/Gen Cost:    0.948/1.176
# Epoch:     147 | Dis/Gen AvgCost: 0.976/1.595
# Time elapsed: 5.32 min
# Minibatch: 001 | Dis/Gen Cost:    0.955/1.815
# Minibatch: 201 | Dis/Gen Cost:    0.945/1.626
# Minibatch: 401 | Dis/Gen Cost:    1.058/1.411
# Minibatch: 601 | Dis/Gen Cost:    1.065/1.468
# Minibatch: 801 | Dis/Gen Cost:    0.887/1.782
# Epoch:     148 | Dis/Gen AvgCost: 0.975/1.594
# Time elapsed: 5.36 min
# Minibatch: 001 | Dis/Gen Cost:    0.916/1.845
# Minibatch: 201 | Dis/Gen Cost:    1.138/1.503
# Minibatch: 401 | Dis/Gen Cost:    0.816/1.860
# Minibatch: 601 | Dis/Gen Cost:    1.044/1.426
# Minibatch: 801 | Dis/Gen Cost:    0.905/1.924
# Epoch:     149 | Dis/Gen AvgCost: 0.974/1.618
# Time elapsed: 5.40 min
# Minibatch: 001 | Dis/Gen Cost:    1.062/1.271
# Minibatch: 201 | Dis/Gen Cost:    0.833/1.531
# Minibatch: 401 | Dis/Gen Cost:    1.039/1.368
# Minibatch: 601 | Dis/Gen Cost:    1.040/1.394
# Minibatch: 801 | Dis/Gen Cost:    0.932/1.610
# Epoch:     150 | Dis/Gen AvgCost: 0.975/1.608
# Time elapsed: 5.43 min
# Minibatch: 001 | Dis/Gen Cost:    0.808/1.880
# Minibatch: 201 | Dis/Gen Cost:    0.887/1.839
# Minibatch: 401 | Dis/Gen Cost:    1.020/1.715
# Minibatch: 601 | Dis/Gen Cost:    1.307/1.590
# Minibatch: 801 | Dis/Gen Cost:    0.805/1.876
# Epoch:     151 | Dis/Gen AvgCost: 0.976/1.595
# Time elapsed: 5.47 min
# Minibatch: 001 | Dis/Gen Cost:    1.019/1.513
# Minibatch: 201 | Dis/Gen Cost:    0.800/1.860
# Minibatch: 401 | Dis/Gen Cost:    0.923/2.257
# Minibatch: 601 | Dis/Gen Cost:    1.037/1.172
# Minibatch: 801 | Dis/Gen Cost:    1.069/2.036
# Epoch:     152 | Dis/Gen AvgCost: 0.967/1.650
# Time elapsed: 5.51 min
# Minibatch: 001 | Dis/Gen Cost:    0.769/1.987
# Minibatch: 201 | Dis/Gen Cost:    0.851/1.710
# Minibatch: 401 | Dis/Gen Cost:    1.018/1.319
# Minibatch: 601 | Dis/Gen Cost:    0.830/1.660
# Minibatch: 801 | Dis/Gen Cost:    0.876/1.496
# Epoch:     153 | Dis/Gen AvgCost: 0.972/1.619
# Time elapsed: 5.54 min
# Minibatch: 001 | Dis/Gen Cost:    0.969/1.544
# Minibatch: 201 | Dis/Gen Cost:    0.954/1.639
# Minibatch: 401 | Dis/Gen Cost:    0.945/1.602
# Minibatch: 601 | Dis/Gen Cost:    1.154/1.356
# Minibatch: 801 | Dis/Gen Cost:    1.061/1.764
# Epoch:     154 | Dis/Gen AvgCost: 0.969/1.586
# Time elapsed: 5.58 min
# Minibatch: 001 | Dis/Gen Cost:    0.819/1.784
# Minibatch: 201 | Dis/Gen Cost:    0.997/1.722
# Minibatch: 401 | Dis/Gen Cost:    0.891/1.719
# Minibatch: 601 | Dis/Gen Cost:    1.053/1.365
# Minibatch: 801 | Dis/Gen Cost:    0.952/1.481
# Epoch:     155 | Dis/Gen AvgCost: 0.965/1.613
# Time elapsed: 5.61 min
# Minibatch: 001 | Dis/Gen Cost:    0.894/1.558
# Minibatch: 201 | Dis/Gen Cost:    1.011/1.588
# Minibatch: 401 | Dis/Gen Cost:    0.967/1.439
# Minibatch: 601 | Dis/Gen Cost:    0.980/1.459
# Minibatch: 801 | Dis/Gen Cost:    0.877/1.833
# Epoch:     156 | Dis/Gen AvgCost: 0.973/1.604
# Time elapsed: 5.65 min
# Minibatch: 001 | Dis/Gen Cost:    0.941/1.870
# Minibatch: 201 | Dis/Gen Cost:    0.972/1.548
# Minibatch: 401 | Dis/Gen Cost:    1.086/2.038
# Minibatch: 601 | Dis/Gen Cost:    1.013/1.713
# Minibatch: 801 | Dis/Gen Cost:    0.904/1.569
# Epoch:     157 | Dis/Gen AvgCost: 0.970/1.627
# Time elapsed: 5.69 min
# Minibatch: 001 | Dis/Gen Cost:    1.078/1.276
# Minibatch: 201 | Dis/Gen Cost:    0.873/1.881
# Minibatch: 401 | Dis/Gen Cost:    1.177/1.425
# Minibatch: 601 | Dis/Gen Cost:    0.760/1.756
# Minibatch: 801 | Dis/Gen Cost:    1.002/1.171
# Epoch:     158 | Dis/Gen AvgCost: 0.969/1.595
# Time elapsed: 5.72 min
# Minibatch: 001 | Dis/Gen Cost:    0.975/1.616
# Minibatch: 201 | Dis/Gen Cost:    0.974/1.471
# Minibatch: 401 | Dis/Gen Cost:    0.950/1.411
# Minibatch: 601 | Dis/Gen Cost:    0.973/1.649
# Minibatch: 801 | Dis/Gen Cost:    1.077/1.407
# Epoch:     159 | Dis/Gen AvgCost: 0.967/1.607
# Time elapsed: 5.76 min
# Minibatch: 001 | Dis/Gen Cost:    1.154/1.568
# Minibatch: 201 | Dis/Gen Cost:    0.947/1.557
# Minibatch: 401 | Dis/Gen Cost:    0.770/2.044
# Minibatch: 601 | Dis/Gen Cost:    1.193/1.496
# Minibatch: 801 | Dis/Gen Cost:    1.169/1.520
# Epoch:     160 | Dis/Gen AvgCost: 0.973/1.633
# Time elapsed: 5.80 min
# Minibatch: 001 | Dis/Gen Cost:    1.050/1.396
# Minibatch: 201 | Dis/Gen Cost:    0.779/1.403
# Minibatch: 401 | Dis/Gen Cost:    0.933/1.710
# ...
# Epoch:     247 | Dis/Gen AvgCost: 0.925/1.725
# Time elapsed: 8.95 min
# Minibatch: 001 | Dis/Gen Cost:    0.973/1.636
# Minibatch: 201 | Dis/Gen Cost:    0.974/1.427
# Minibatch: 401 | Dis/Gen Cost:    0.861/1.544
# Minibatch: 601 | Dis/Gen Cost:    0.854/1.974
# Minibatch: 801 | Dis/Gen Cost:    0.934/1.794
# Epoch:     248 | Dis/Gen AvgCost: 0.918/1.698
# Time elapsed: 8.98 min
# Minibatch: 001 | Dis/Gen Cost:    0.874/1.664
# Minibatch: 201 | Dis/Gen Cost:    0.805/1.317
# Minibatch: 401 | Dis/Gen Cost:    0.891/1.763
# Minibatch: 601 | Dis/Gen Cost:    0.798/1.955
# Minibatch: 801 | Dis/Gen Cost:    0.855/1.760
# Epoch:     249 | Dis/Gen AvgCost: 0.925/1.694
# Time elapsed: 9.02 min
# Minibatch: 001 | Dis/Gen Cost:    0.838/1.565
# Minibatch: 201 | Dis/Gen Cost:    0.933/1.549
# Minibatch: 401 | Dis/Gen Cost:    0.875/1.732
# Minibatch: 601 | Dis/Gen Cost:    0.885/1.687
# Minibatch: 801 | Dis/Gen Cost:    0.916/1.756
# Epoch:     250 | Dis/Gen AvgCost: 0.923/1.722
# Time elapsed: 9.06 min
# Minibatch: 001 | Dis/Gen Cost:    0.995/1.402
# Minibatch: 201 | Dis/Gen Cost:    1.028/1.736
# Minibatch: 401 | Dis/Gen Cost:    0.980/1.412
# Minibatch: 601 | Dis/Gen Cost:    0.897/1.753
# Minibatch: 801 | Dis/Gen Cost:    1.096/1.514
# Epoch:     251 | Dis/Gen AvgCost: 0.925/1.716
# Time elapsed: 9.09 min
# Minibatch: 001 | Dis/Gen Cost:    0.907/1.727
# Minibatch: 201 | Dis/Gen Cost:    1.005/1.440
# Minibatch: 401 | Dis/Gen Cost:    0.838/2.001
# Minibatch: 601 | Dis/Gen Cost:    0.861/1.805
# Minibatch: 801 | Dis/Gen Cost:    0.958/1.371
# Epoch:     252 | Dis/Gen AvgCost: 0.921/1.694
# Time elapsed: 9.13 min
# Minibatch: 001 | Dis/Gen Cost:    1.034/1.658
# Minibatch: 201 | Dis/Gen Cost:    0.956/1.755
# Minibatch: 401 | Dis/Gen Cost:    0.936/1.741
# Minibatch: 601 | Dis/Gen Cost:    0.879/1.705
# Minibatch: 801 | Dis/Gen Cost:    1.048/1.745
# Epoch:     253 | Dis/Gen AvgCost: 0.920/1.730
# Time elapsed: 9.16 min
# Minibatch: 001 | Dis/Gen Cost:    1.005/1.675
# Minibatch: 201 | Dis/Gen Cost:    0.965/1.620
# Minibatch: 401 | Dis/Gen Cost:    0.822/1.664
# Minibatch: 601 | Dis/Gen Cost:    0.953/1.836
# Minibatch: 801 | Dis/Gen Cost:    0.845/1.749
# Epoch:     254 | Dis/Gen AvgCost: 0.924/1.723
# Time elapsed: 9.20 min
# Minibatch: 001 | Dis/Gen Cost:    0.988/1.761
# Minibatch: 201 | Dis/Gen Cost:    1.020/1.886
# Minibatch: 401 | Dis/Gen Cost:    0.867/1.890
# Minibatch: 601 | Dis/Gen Cost:    0.873/1.422
# Minibatch: 801 | Dis/Gen Cost:    0.880/1.699
# Epoch:     255 | Dis/Gen AvgCost: 0.926/1.710
# Time elapsed: 9.24 min
# Minibatch: 001 | Dis/Gen Cost:    0.959/1.421
# Minibatch: 201 | Dis/Gen Cost:    0.810/1.871
# Minibatch: 401 | Dis/Gen Cost:    0.930/1.500
# Minibatch: 601 | Dis/Gen Cost:    0.793/1.815
# Minibatch: 801 | Dis/Gen Cost:    0.903/2.026
# Epoch:     256 | Dis/Gen AvgCost: 0.927/1.709
# Time elapsed: 9.27 min
# Minibatch: 001 | Dis/Gen Cost:    0.875/1.579
# Minibatch: 201 | Dis/Gen Cost:    0.909/1.676
# Minibatch: 401 | Dis/Gen Cost:    1.010/1.501
# Minibatch: 601 | Dis/Gen Cost:    0.882/2.124
# Minibatch: 801 | Dis/Gen Cost:    0.929/1.917
# Epoch:     257 | Dis/Gen AvgCost: 0.922/1.717
# Time elapsed: 9.31 min
# Minibatch: 001 | Dis/Gen Cost:    0.963/1.979
# Minibatch: 201 | Dis/Gen Cost:    0.936/2.058
# Minibatch: 401 | Dis/Gen Cost:    0.807/1.852
# Minibatch: 601 | Dis/Gen Cost:    1.018/1.899
# Minibatch: 801 | Dis/Gen Cost:    0.961/1.415
# Epoch:     258 | Dis/Gen AvgCost: 0.921/1.709
# Time elapsed: 9.35 min
# Minibatch: 001 | Dis/Gen Cost:    0.895/1.761
# Minibatch: 201 | Dis/Gen Cost:    1.020/1.589
# Minibatch: 401 | Dis/Gen Cost:    0.906/2.029
# Minibatch: 601 | Dis/Gen Cost:    0.992/1.427
# Minibatch: 801 | Dis/Gen Cost:    0.978/1.762
# Epoch:     259 | Dis/Gen AvgCost: 0.927/1.736
# Time elapsed: 9.38 min
# Minibatch: 001 | Dis/Gen Cost:    0.957/1.526
# Minibatch: 201 | Dis/Gen Cost:    0.823/2.112
# Minibatch: 401 | Dis/Gen Cost:    0.742/1.543
# Minibatch: 601 | Dis/Gen Cost:    0.847/1.886
# Minibatch: 801 | Dis/Gen Cost:    0.925/1.514
# Epoch:     260 | Dis/Gen AvgCost: 0.913/1.714
# Time elapsed: 9.42 min
# Minibatch: 001 | Dis/Gen Cost:    1.047/1.659
# Minibatch: 201 | Dis/Gen Cost:    0.911/1.687
# Minibatch: 401 | Dis/Gen Cost:    0.984/1.512
# Minibatch: 601 | Dis/Gen Cost:    0.968/1.360
# Minibatch: 801 | Dis/Gen Cost:    0.970/1.990
# Epoch:     261 | Dis/Gen AvgCost: 0.917/1.717
# Time elapsed: 9.45 min
# Minibatch: 001 | Dis/Gen Cost:    0.850/1.849
# Minibatch: 201 | Dis/Gen Cost:    0.910/1.880
# Minibatch: 401 | Dis/Gen Cost:    0.883/1.662
# Minibatch: 601 | Dis/Gen Cost:    0.999/1.884
# Minibatch: 801 | Dis/Gen Cost:    0.936/1.766
# Epoch:     262 | Dis/Gen AvgCost: 0.919/1.721
# Time elapsed: 9.49 min
# Minibatch: 001 | Dis/Gen Cost:    0.893/1.847
# Minibatch: 201 | Dis/Gen Cost:    1.057/1.683
# Minibatch: 401 | Dis/Gen Cost:    0.956/1.474
# Minibatch: 601 | Dis/Gen Cost:    1.043/1.285
# Minibatch: 801 | Dis/Gen Cost:    0.871/1.720
# Epoch:     263 | Dis/Gen AvgCost: 0.909/1.738
# Time elapsed: 9.53 min
# Minibatch: 001 | Dis/Gen Cost:    0.995/1.859
# Minibatch: 201 | Dis/Gen Cost:    1.114/1.856
# Minibatch: 401 | Dis/Gen Cost:    0.905/1.832
# Minibatch: 601 | Dis/Gen Cost:    0.929/2.099
# Minibatch: 801 | Dis/Gen Cost:    0.807/1.902
# Epoch:     264 | Dis/Gen AvgCost: 0.911/1.752
# Time elapsed: 9.56 min
# Minibatch: 001 | Dis/Gen Cost:    0.935/1.889
# Minibatch: 201 | Dis/Gen Cost:    1.070/1.584
# Minibatch: 401 | Dis/Gen Cost:    0.821/1.752
# Minibatch: 601 | Dis/Gen Cost:    0.914/1.671
# Minibatch: 801 | Dis/Gen Cost:    0.945/1.859
# Epoch:     265 | Dis/Gen AvgCost: 0.913/1.737
# Time elapsed: 9.60 min
# Minibatch: 001 | Dis/Gen Cost:    1.082/1.787
# Minibatch: 201 | Dis/Gen Cost:    0.993/2.125
# Minibatch: 401 | Dis/Gen Cost:    0.840/1.876
# Minibatch: 601 | Dis/Gen Cost:    0.860/1.672
# Minibatch: 801 | Dis/Gen Cost:    0.861/1.680
# Epoch:     266 | Dis/Gen AvgCost: 0.916/1.724
# Time elapsed: 9.64 min
# Minibatch: 001 | Dis/Gen Cost:    0.924/1.539
# Minibatch: 201 | Dis/Gen Cost:    1.034/1.724
# Minibatch: 401 | Dis/Gen Cost:    0.909/1.572
# Minibatch: 601 | Dis/Gen Cost:    1.055/1.777
# Minibatch: 801 | Dis/Gen Cost:    0.878/1.981
# Epoch:     267 | Dis/Gen AvgCost: 0.919/1.751
# Time elapsed: 9.67 min
# Minibatch: 001 | Dis/Gen Cost:    0.808/1.836
# Minibatch: 201 | Dis/Gen Cost:    0.911/1.699
# Minibatch: 401 | Dis/Gen Cost:    0.844/1.963
# Minibatch: 601 | Dis/Gen Cost:    0.971/1.698
# Minibatch: 801 | Dis/Gen Cost:    0.992/1.784
# Epoch:     268 | Dis/Gen AvgCost: 0.914/1.730
# Time elapsed: 9.71 min
# Minibatch: 001 | Dis/Gen Cost:    1.082/2.141
# Minibatch: 201 | Dis/Gen Cost:    0.828/1.970
# Minibatch: 401 | Dis/Gen Cost:    0.929/1.449
# Minibatch: 601 | Dis/Gen Cost:    0.755/1.721
# Minibatch: 801 | Dis/Gen Cost:    1.147/1.474
# Epoch:     269 | Dis/Gen AvgCost: 0.917/1.741
# Time elapsed: 9.74 min
# Minibatch: 001 | Dis/Gen Cost:    1.046/1.365
# Minibatch: 201 | Dis/Gen Cost:    0.860/2.304
# Minibatch: 401 | Dis/Gen Cost:    0.959/1.479
# Minibatch: 601 | Dis/Gen Cost:    0.831/1.710
# Minibatch: 801 | Dis/Gen Cost:    0.764/1.987
# Epoch:     270 | Dis/Gen AvgCost: 0.908/1.758
# Time elapsed: 9.78 min
# Minibatch: 001 | Dis/Gen Cost:    0.910/1.826
# Minibatch: 201 | Dis/Gen Cost:    0.980/1.710
# Minibatch: 401 | Dis/Gen Cost:    0.994/1.998
# Minibatch: 601 | Dis/Gen Cost:    0.915/1.695
# Minibatch: 801 | Dis/Gen Cost:    0.733/2.222
# Epoch:     271 | Dis/Gen AvgCost: 0.909/1.757
# Time elapsed: 9.82 min
# Minibatch: 001 | Dis/Gen Cost:    0.841/1.895
# Minibatch: 201 | Dis/Gen Cost:    0.923/1.461
# Minibatch: 401 | Dis/Gen Cost:    1.134/1.761
# Minibatch: 601 | Dis/Gen Cost:    0.970/1.738
# Minibatch: 801 | Dis/Gen Cost:    0.782/1.871
# Epoch:     272 | Dis/Gen AvgCost: 0.904/1.738
# Time elapsed: 9.85 min
# Minibatch: 001 | Dis/Gen Cost:    0.796/1.397
# Minibatch: 201 | Dis/Gen Cost:    1.136/1.585
# Minibatch: 401 | Dis/Gen Cost:    0.879/1.275
# Minibatch: 601 | Dis/Gen Cost:    0.883/1.697
# Minibatch: 801 | Dis/Gen Cost:    1.009/1.802
# Epoch:     273 | Dis/Gen AvgCost: 0.917/1.753
# Time elapsed: 9.89 min
# Minibatch: 001 | Dis/Gen Cost:    0.957/1.599
# Minibatch: 201 | Dis/Gen Cost:    0.783/1.964
# Minibatch: 401 | Dis/Gen Cost:    0.903/1.755
# Minibatch: 601 | Dis/Gen Cost:    0.843/2.048
# Minibatch: 801 | Dis/Gen Cost:    1.058/1.777
# Epoch:     274 | Dis/Gen AvgCost: 0.908/1.767
# Time elapsed: 9.93 min
# Minibatch: 001 | Dis/Gen Cost:    0.816/2.008
# Minibatch: 201 | Dis/Gen Cost:    0.832/1.734
# Minibatch: 401 | Dis/Gen Cost:    0.995/1.799
# Minibatch: 601 | Dis/Gen Cost:    0.821/2.164
# Minibatch: 801 | Dis/Gen Cost:    0.914/1.850
# Epoch:     275 | Dis/Gen AvgCost: 0.910/1.774
# Time elapsed: 9.96 min
# Minibatch: 001 | Dis/Gen Cost:    0.860/1.668
# Minibatch: 201 | Dis/Gen Cost:    0.930/1.651
# Minibatch: 401 | Dis/Gen Cost:    1.076/1.732
# Minibatch: 601 | Dis/Gen Cost:    0.774/1.536
# Minibatch: 801 | Dis/Gen Cost:    0.885/1.660
# Epoch:     276 | Dis/Gen AvgCost: 0.904/1.739
# Time elapsed: 10.00 min
# Minibatch: 001 | Dis/Gen Cost:    0.927/1.661
# Minibatch: 201 | Dis/Gen Cost:    0.917/2.132
# Minibatch: 401 | Dis/Gen Cost:    1.029/1.619
# Minibatch: 601 | Dis/Gen Cost:    0.744/1.824
# Minibatch: 801 | Dis/Gen Cost:    0.759/2.175
# Epoch:     277 | Dis/Gen AvgCost: 0.901/1.794
# Time elapsed: 10.03 min
# Minibatch: 001 | Dis/Gen Cost:    0.823/1.659
# Minibatch: 201 | Dis/Gen Cost:    0.916/1.598
# Minibatch: 401 | Dis/Gen Cost:    0.803/1.834
# Minibatch: 601 | Dis/Gen Cost:    0.899/1.749
# Minibatch: 801 | Dis/Gen Cost:    0.920/1.920
# Epoch:     278 | Dis/Gen AvgCost: 0.896/1.779
# Time elapsed: 10.07 min
# Minibatch: 001 | Dis/Gen Cost:    0.872/1.933
# Minibatch: 201 | Dis/Gen Cost:    0.998/1.673
# Minibatch: 401 | Dis/Gen Cost:    0.845/1.665
# Minibatch: 601 | Dis/Gen Cost:    0.907/1.798
# Minibatch: 801 | Dis/Gen Cost:    1.111/1.712
# Epoch:     279 | Dis/Gen AvgCost: 0.900/1.762
# Time elapsed: 10.11 min
# Minibatch: 001 | Dis/Gen Cost:    1.055/1.674
# Minibatch: 201 | Dis/Gen Cost:    0.840/1.928
# Minibatch: 401 | Dis/Gen Cost:    0.988/1.664
# Minibatch: 601 | Dis/Gen Cost:    0.951/2.082
# Minibatch: 801 | Dis/Gen Cost:    0.786/2.095
# Epoch:     280 | Dis/Gen AvgCost: 0.901/1.785
# Time elapsed: 10.14 min
# Minibatch: 001 | Dis/Gen Cost:    0.811/1.996
# Minibatch: 201 | Dis/Gen Cost:    0.845/1.592
# Minibatch: 401 | Dis/Gen Cost:    0.956/1.627
# Minibatch: 601 | Dis/Gen Cost:    0.829/2.142
# Minibatch: 801 | Dis/Gen Cost:    0.825/1.699
# Epoch:     281 | Dis/Gen AvgCost: 0.897/1.798
# Time elapsed: 10.18 min
# Minibatch: 001 | Dis/Gen Cost:    0.801/1.966
# Minibatch: 201 | Dis/Gen Cost:    0.725/1.771
# Minibatch: 401 | Dis/Gen Cost:    0.958/1.578
# Minibatch: 601 | Dis/Gen Cost:    0.890/1.510
# Minibatch: 801 | Dis/Gen Cost:    0.988/1.505
# Epoch:     282 | Dis/Gen AvgCost: 0.904/1.787
# Time elapsed: 10.21 min
# Minibatch: 001 | Dis/Gen Cost:    0.936/1.878
# Minibatch: 201 | Dis/Gen Cost:    0.925/1.589
# Minibatch: 401 | Dis/Gen Cost:    0.953/1.581
# Minibatch: 601 | Dis/Gen Cost:    0.749/1.615
# Minibatch: 801 | Dis/Gen Cost:    0.902/1.739
# Epoch:     283 | Dis/Gen AvgCost: 0.900/1.787
# Time elapsed: 10.25 min
# Minibatch: 001 | Dis/Gen Cost:    0.940/1.790
# Minibatch: 201 | Dis/Gen Cost:    0.720/1.817
# Minibatch: 401 | Dis/Gen Cost:    0.772/1.733
# Minibatch: 601 | Dis/Gen Cost:    0.955/2.462
# Minibatch: 801 | Dis/Gen Cost:    0.883/1.672
# Epoch:     284 | Dis/Gen AvgCost: 0.895/1.806
# Time elapsed: 10.29 min
# Minibatch: 001 | Dis/Gen Cost:    1.005/1.497
# Minibatch: 201 | Dis/Gen Cost:    0.861/1.950
# Minibatch: 401 | Dis/Gen Cost:    0.833/1.700
# Minibatch: 601 | Dis/Gen Cost:    0.926/1.523
# Minibatch: 801 | Dis/Gen Cost:    0.872/1.657
# Epoch:     285 | Dis/Gen AvgCost: 0.896/1.777
# Time elapsed: 10.32 min
# Minibatch: 001 | Dis/Gen Cost:    0.867/2.002
# Minibatch: 201 | Dis/Gen Cost:    0.837/2.172
# Minibatch: 401 | Dis/Gen Cost:    0.964/1.676
# Minibatch: 601 | Dis/Gen Cost:    0.833/1.610
# Minibatch: 801 | Dis/Gen Cost:    0.927/1.884
# Epoch:     286 | Dis/Gen AvgCost: 0.900/1.782
# Time elapsed: 10.36 min
# Minibatch: 001 | Dis/Gen Cost:    0.968/1.933
# Minibatch: 201 | Dis/Gen Cost:    0.858/1.697
# Minibatch: 401 | Dis/Gen Cost:    0.875/1.739
# Minibatch: 601 | Dis/Gen Cost:    0.929/1.431
# Minibatch: 801 | Dis/Gen Cost:    0.723/1.442
# Epoch:     287 | Dis/Gen AvgCost: 0.897/1.808
# Time elapsed: 10.40 min
# Minibatch: 001 | Dis/Gen Cost:    0.949/1.732
# Minibatch: 201 | Dis/Gen Cost:    0.928/1.690
# Minibatch: 401 | Dis/Gen Cost:    0.905/1.921
# Minibatch: 601 | Dis/Gen Cost:    0.877/1.769
# Minibatch: 801 | Dis/Gen Cost:    0.807/2.000
# Epoch:     288 | Dis/Gen AvgCost: 0.894/1.790
# Time elapsed: 10.43 min
# Minibatch: 001 | Dis/Gen Cost:    0.912/1.832
# Minibatch: 201 | Dis/Gen Cost:    0.971/1.799
# Minibatch: 401 | Dis/Gen Cost:    0.825/1.871
# Minibatch: 601 | Dis/Gen Cost:    0.922/1.573
# Minibatch: 801 | Dis/Gen Cost:    0.841/2.071
# Epoch:     289 | Dis/Gen AvgCost: 0.894/1.806
# Time elapsed: 10.47 min
# Minibatch: 001 | Dis/Gen Cost:    0.890/1.692
# Minibatch: 201 | Dis/Gen Cost:    0.909/1.806
# Minibatch: 401 | Dis/Gen Cost:    0.803/1.859
# Minibatch: 601 | Dis/Gen Cost:    0.888/1.970
# Minibatch: 801 | Dis/Gen Cost:    0.963/1.766
# Epoch:     290 | Dis/Gen AvgCost: 0.896/1.789
# Time elapsed: 10.50 min
# Minibatch: 001 | Dis/Gen Cost:    0.820/1.797
# Minibatch: 201 | Dis/Gen Cost:    0.855/1.788
# Minibatch: 401 | Dis/Gen Cost:    0.867/1.955
# Minibatch: 601 | Dis/Gen Cost:    0.867/1.714
# Minibatch: 801 | Dis/Gen Cost:    0.837/1.975
# Epoch:     291 | Dis/Gen AvgCost: 0.894/1.794
# Time elapsed: 10.54 min
# Minibatch: 001 | Dis/Gen Cost:    1.019/1.444
# Minibatch: 201 | Dis/Gen Cost:    0.975/1.622
# Minibatch: 401 | Dis/Gen Cost:    0.952/1.497
# Minibatch: 601 | Dis/Gen Cost:    0.797/2.137
# Minibatch: 801 | Dis/Gen Cost:    0.715/2.095
# Epoch:     292 | Dis/Gen AvgCost: 0.888/1.796
# Time elapsed: 10.58 min
# Minibatch: 001 | Dis/Gen Cost:    0.996/1.819
# Minibatch: 201 | Dis/Gen Cost:    0.607/1.761
# Minibatch: 401 | Dis/Gen Cost:    0.786/1.707
# Minibatch: 601 | Dis/Gen Cost:    1.032/1.936
# Minibatch: 801 | Dis/Gen Cost:    0.887/1.791
# Epoch:     293 | Dis/Gen AvgCost: 0.905/1.805
# Time elapsed: 10.61 min
# Minibatch: 001 | Dis/Gen Cost:    0.798/1.712
# Minibatch: 201 | Dis/Gen Cost:    0.779/2.129
# Minibatch: 401 | Dis/Gen Cost:    0.917/1.736
# Minibatch: 601 | Dis/Gen Cost:    0.755/1.967
# Minibatch: 801 | Dis/Gen Cost:    0.899/1.596
# Epoch:     294 | Dis/Gen AvgCost: 0.890/1.790
# Time elapsed: 10.65 min
# Minibatch: 001 | Dis/Gen Cost:    0.849/1.872
# Minibatch: 201 | Dis/Gen Cost:    0.945/2.045
# Minibatch: 401 | Dis/Gen Cost:    0.901/1.871
# Minibatch: 601 | Dis/Gen Cost:    0.824/1.723
# Minibatch: 801 | Dis/Gen Cost:    0.854/1.652
# Epoch:     295 | Dis/Gen AvgCost: 0.897/1.787
# Time elapsed: 10.69 min
# Minibatch: 001 | Dis/Gen Cost:    0.894/1.682
# Minibatch: 201 | Dis/Gen Cost:    0.784/1.805
# Minibatch: 401 | Dis/Gen Cost:    0.890/1.663
# Minibatch: 601 | Dis/Gen Cost:    0.813/1.920
# Minibatch: 801 | Dis/Gen Cost:    0.901/1.632
# Epoch:     296 | Dis/Gen AvgCost: 0.899/1.775
# Time elapsed: 10.72 min
# Minibatch: 001 | Dis/Gen Cost:    0.816/1.899
# Minibatch: 201 | Dis/Gen Cost:    0.947/1.676
# Minibatch: 401 | Dis/Gen Cost:    0.812/1.829
# Minibatch: 601 | Dis/Gen Cost:    0.960/1.965
# Minibatch: 801 | Dis/Gen Cost:    0.880/1.616
# Epoch:     297 | Dis/Gen AvgCost: 0.896/1.820
# Time elapsed: 10.76 min
# Minibatch: 001 | Dis/Gen Cost:    0.890/1.844
# Minibatch: 201 | Dis/Gen Cost:    0.774/1.792
# Minibatch: 401 | Dis/Gen Cost:    1.067/1.556
# Minibatch: 601 | Dis/Gen Cost:    1.043/1.542
# Minibatch: 801 | Dis/Gen Cost:    0.946/1.492
# Epoch:     298 | Dis/Gen AvgCost: 0.897/1.787
# Time elapsed: 10.80 min
# Minibatch: 001 | Dis/Gen Cost:    0.983/1.651
# Minibatch: 201 | Dis/Gen Cost:    0.852/1.785
# Minibatch: 401 | Dis/Gen Cost:    0.844/1.825
# Minibatch: 601 | Dis/Gen Cost:    0.892/2.005
# Minibatch: 801 | Dis/Gen Cost:    0.809/2.232
# Epoch:     299 | Dis/Gen AvgCost: 0.888/1.821
# Time elapsed: 10.83 min
# Minibatch: 001 | Dis/Gen Cost:    1.094/1.288
# Minibatch: 201 | Dis/Gen Cost:    0.896/1.682
# Minibatch: 401 | Dis/Gen Cost:    0.891/1.813
# Minibatch: 601 | Dis/Gen Cost:    0.939/1.649
# Minibatch: 801 | Dis/Gen Cost:    0.952/1.925
# Epoch:     300 | Dis/Gen AvgCost: 0.893/1.795
# Time elapsed: 10.87 min
# Total Training Time: 10.87 min

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(range(len(avg_costs['discriminator'])), 
         avg_costs['discriminator'], label='discriminator')
plt.plot(range(len(avg_costs['generator'])),
         avg_costs['generator'], label='generator')
plt.legend()
plt.show()

# %%
####################################
### RELOAD & GENERATE SAMPLE IMAGES
####################################


n_examples = 25

with tf.Session(graph=g) as sess:
    saver.restore(sess, save_path='./model/gan.ckpt')

    batch_randsample = np.random.uniform(-1, 1, size=(n_examples, gen_input_size))
    new_examples = sess.run('generator/generator_output:0',
                            feed_dict={'generator_input:0': batch_randsample,
                                       'dropout:0': 0.0,
                                       'is_training:0': False})

fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(8, 8),
                         sharey=True, sharex=True)

for image, ax in zip(new_examples, axes.flatten()):
    ax.imshow(image.reshape((dis_input_size // 28, dis_input_size // 28)), cmap='binary')

plt.show()
# Out:
# W0628 01:55:55.179756 139803829532480 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
