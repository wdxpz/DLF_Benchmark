# %%
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import pickle as pkl

tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
### Abbreviatiuons
# dis_*: discriminator network
# gen_*: generator network

########################
### Helper functions
########################

def leaky_relu(x, alpha=0.0001):
    return tf.maximum(alpha * x, x)


########################
### DATASET
########################

mnist = input_data.read_data_sets('./dataset/MNIST_data')


#########################
### SETTINGS
#########################

# Hyperparameters
learning_rate = 0.0001
training_epochs = 200
batch_size = 64
dropout_rate = 0.5

# Architecture
dis_input_size = 784
gen_input_size = 100

# Other settings
print_interval = 200

#########################
### GRAPH DEFINITION
#########################

g = tf.Graph()
with g.as_default():
    
    # Placeholders for settings
    dropout = tf.placeholder(tf.float32, shape=None, name='dropout')
    is_training = tf.placeholder(tf.bool, shape=None, name='is_training')
    
    # Input data
    dis_x = tf.placeholder(tf.float32, shape=[None, dis_input_size],
                           name='discriminator_inputs')     
    gen_x = tf.placeholder(tf.float32, [None, gen_input_size],
                           name='generator_inputs')


    ##################
    # Generator Model
    ##################

    with tf.variable_scope('generator'):
        
        # 100 => 784 => 7x7x64
        gen_fc = tf.layers.dense(inputs=gen_x, units=3136,
                                 bias_initializer=None, # no bias required when using batch_norm
                                 activation=None)
        gen_fc = tf.layers.batch_normalization(gen_fc, training=is_training)
        gen_fc = leaky_relu(gen_fc)
        gen_fc = tf.reshape(gen_fc, (-1, 7, 7, 64))
        
        # 7x7x64 => 14x14x32
        deconv1 = tf.layers.conv2d_transpose(gen_fc, filters=32, 
                                             kernel_size=(3, 3), strides=(2, 2), 
                                             padding='same',
                                             bias_initializer=None,
                                             activation=None)
        deconv1 = tf.layers.batch_normalization(deconv1, training=is_training)
        deconv1 = leaky_relu(deconv1)     
        deconv1 = tf.layers.dropout(deconv1, rate=dropout_rate)
        
        # 14x14x32 => 28x28x16
        deconv2 = tf.layers.conv2d_transpose(deconv1, filters=16, 
                                             kernel_size=(3, 3), strides=(2, 2), 
                                             padding='same',
                                             bias_initializer=None,
                                             activation=None)
        deconv2 = tf.layers.batch_normalization(deconv2, training=is_training)
        deconv2 = leaky_relu(deconv2)     
        deconv2 = tf.layers.dropout(deconv2, rate=dropout_rate)
        
        # 28x28x16 => 28x28x8
        deconv3 = tf.layers.conv2d_transpose(deconv2, filters=8, 
                                             kernel_size=(3, 3), strides=(1, 1), 
                                             padding='same',
                                             bias_initializer=None,
                                             activation=None)
        deconv3 = tf.layers.batch_normalization(deconv3, training=is_training)
        deconv3 = leaky_relu(deconv3)     
        deconv3 = tf.layers.dropout(deconv3, rate=dropout_rate)
        
        # 28x28x8 => 28x28x1
        gen_logits = tf.layers.conv2d_transpose(deconv3, filters=1, 
                                                kernel_size=(3, 3), strides=(1, 1), 
                                                padding='same',
                                                bias_initializer=None,
                                                activation=None)
        gen_out = tf.tanh(gen_logits, 'generator_outputs')


    ######################
    # Discriminator Model
    ######################
    
    def build_discriminator_graph(input_x, reuse=None):

        with tf.variable_scope('discriminator', reuse=reuse):
            
            # 28x28x1 => 14x14x8
            conv_input = tf.reshape(input_x, (-1, 28, 28, 1))
            conv1 = tf.layers.conv2d(conv_input, filters=8, kernel_size=(3, 3),
                                     strides=(2, 2), padding='same',
                                     bias_initializer=None,
                                     activation=None)
            conv1 = tf.layers.batch_normalization(conv1, training=is_training)
            conv1 = leaky_relu(conv1)
            conv1 = tf.layers.dropout(conv1, rate=dropout_rate)
            
            # 14x14x8 => 7x7x32
            conv2 = tf.layers.conv2d(conv1, filters=32, kernel_size=(3, 3),
                                     strides=(2, 2), padding='same',
                                     bias_initializer=None,
                                     activation=None)
            conv2 = tf.layers.batch_normalization(conv2, training=is_training)
            conv2 = leaky_relu(conv2)
            conv2 = tf.layers.dropout(conv2, rate=dropout_rate)

            # fully connected layer
            fc_input = tf.reshape(conv2, (-1, 7*7*32))
            logits = tf.layers.dense(inputs=fc_input, units=1, activation=None)
            out = tf.sigmoid(logits)
            
        return logits, out    

    # Create a discriminator for real data and a discriminator for fake data
    dis_real_logits, dis_real_out = build_discriminator_graph(dis_x, reuse=False)
    dis_fake_logits, dis_fake_out = build_discriminator_graph(gen_out, reuse=True)


    #####################################
    # Generator and Discriminator Losses
    #####################################
    
    # Two discriminator cost components: loss on real data + loss on fake data
    # Real data has class label 0, fake data has class label 1
    dis_real_loss = tf.nn.sigmoid_cross_entropy_with_logits(logits=dis_real_logits, 
                                                            labels=tf.zeros_like(dis_real_logits))
    dis_fake_loss = tf.nn.sigmoid_cross_entropy_with_logits(logits=dis_fake_logits, 
                                                            labels=tf.ones_like(dis_fake_logits))
    dis_cost = tf.add(tf.reduce_mean(dis_fake_loss), 
                      tf.reduce_mean(dis_real_loss), 
                      name='discriminator_cost')
 
    # Generator cost: difference between dis. prediction and label "0" for real images
    gen_loss = tf.nn.sigmoid_cross_entropy_with_logits(logits=dis_fake_logits,
                                                       labels=tf.zeros_like(dis_fake_logits))
    gen_cost = tf.reduce_mean(gen_loss, name='generator_cost')
    
    
    #########################################
    # Generator and Discriminator Optimizers
    #########################################
      
    dis_optimizer = tf.train.AdamOptimizer(learning_rate)
    dis_train_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='discriminator')
    dis_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS, scope='discriminator')
    
    with tf.control_dependencies(dis_update_ops): # required to upd. batch_norm params
        dis_train = dis_optimizer.minimize(dis_cost, var_list=dis_train_vars,
                                           name='train_discriminator')
    
    gen_optimizer = tf.train.AdamOptimizer(learning_rate)
    gen_train_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='generator')
    gen_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS, scope='generator')
    
    with tf.control_dependencies(gen_update_ops): # required to upd. batch_norm params
        gen_train = gen_optimizer.minimize(gen_cost, var_list=gen_train_vars,
                                           name='train_generator')
    
    # Saver to save session for reuse
    saver = tf.train.Saver()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0628 04:46:33.286369 139655104055104 deprecation.py:323] From <ipython-input-2-31def1cf6b17>:17: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# W0628 04:46:33.287293 139655104055104 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# W0628 04:46:33.287825 139655104055104 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# W0628 04:46:33.475405 139655104055104 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./dataset/MNIST_data/train-images-idx3-ubyte.gz
# Extracting ./dataset/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ./dataset/MNIST_data/t10k-images-idx3-ubyte.gz
# W0628 04:46:33.508905 139655104055104 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# W0628 04:46:33.655077 139655104055104 deprecation.py:323] From <ipython-input-2-31def1cf6b17>:64: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# W0628 04:46:33.659044 139655104055104 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Extracting ./dataset/MNIST_data/t10k-labels-idx1-ubyte.gz
# W0628 04:46:34.016828 139655104055104 deprecation.py:323] From <ipython-input-2-31def1cf6b17>:65: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# W0628 04:46:34.116640 139655104055104 deprecation.py:323] From <ipython-input-2-31def1cf6b17>:74: conv2d_transpose (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2DTranspose` instead.
# W0628 04:46:34.692932 139655104055104 deprecation.py:323] From <ipython-input-2-31def1cf6b17>:77: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# W0628 04:46:34.897454 139655104055104 deprecation.py:323] From <ipython-input-2-31def1cf6b17>:121: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# W0628 04:46:35.357950 139655104055104 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
##########################
### TRAINING & EVALUATION
##########################
import time 
start_time = time.time()

with tf.Session(graph=g) as sess:
    sess.run(tf.global_variables_initializer())
    
    avg_costs = {'discriminator': [], 'generator': []}

    for epoch in range(training_epochs):
        dis_avg_cost, gen_avg_cost = 0., 0.
        total_batch = mnist.train.num_examples // batch_size

        for i in range(total_batch):
            
            batch_x, batch_y = mnist.train.next_batch(batch_size)
            batch_x = batch_x*2 - 1 # normalize
            batch_randsample = np.random.uniform(-1, 1, size=(batch_size, gen_input_size))
            
            # Train
            
            _, dc = sess.run(['train_discriminator', 'discriminator_cost:0'],
                             feed_dict={'discriminator_inputs:0': batch_x, 
                                        'generator_inputs:0': batch_randsample,
                                        'dropout:0': dropout_rate,
                                        'is_training:0': True})
            
            _, gc = sess.run(['train_generator', 'generator_cost:0'],
                             feed_dict={'generator_inputs:0': batch_randsample,
                                        'dropout:0': dropout_rate,
                                        'is_training:0': True})
            
            dis_avg_cost += dc
            gen_avg_cost += gc

            if not i % print_interval:
                print("Minibatch: %04d | Dis/Gen Cost:    %.3f/%.3f" % (i + 1, dc, gc))
                

        print("Epoch:     %04d | Dis/Gen AvgCost: %.3f/%.3f" % 
              (epoch + 1, dis_avg_cost / total_batch, gen_avg_cost / total_batch))
        print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))
        
        avg_costs['discriminator'].append(dis_avg_cost / total_batch)
        avg_costs['generator'].append(gen_avg_cost / total_batch)
    
    print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
    saver.save(sess, save_path='./model/gan-conv.ckpt')
# Out:
# Minibatch: 0001 | Dis/Gen Cost:    1.344/0.799
# Minibatch: 0201 | Dis/Gen Cost:    0.387/1.934
# Minibatch: 0401 | Dis/Gen Cost:    0.147/2.712
# Minibatch: 0601 | Dis/Gen Cost:    0.408/2.030
# Minibatch: 0801 | Dis/Gen Cost:    0.870/1.344
# Epoch:     0001 | Dis/Gen AvgCost: 0.448/1.963
# Time elapsed: 0.16 min
# Minibatch: 0001 | Dis/Gen Cost:    0.792/1.451
# Minibatch: 0201 | Dis/Gen Cost:    0.897/1.143
# Minibatch: 0401 | Dis/Gen Cost:    0.955/1.200
# Minibatch: 0601 | Dis/Gen Cost:    0.732/1.276
# Minibatch: 0801 | Dis/Gen Cost:    0.854/1.227
# Epoch:     0002 | Dis/Gen AvgCost: 0.876/1.203
# Time elapsed: 0.29 min
# Minibatch: 0001 | Dis/Gen Cost:    1.003/1.227
# Minibatch: 0201 | Dis/Gen Cost:    0.983/1.136
# Minibatch: 0401 | Dis/Gen Cost:    0.854/1.161
# Minibatch: 0601 | Dis/Gen Cost:    0.791/1.161
# Minibatch: 0801 | Dis/Gen Cost:    0.835/1.089
# Epoch:     0003 | Dis/Gen AvgCost: 0.869/1.189
# Time elapsed: 0.41 min
# Minibatch: 0001 | Dis/Gen Cost:    0.799/1.273
# Minibatch: 0201 | Dis/Gen Cost:    0.828/1.156
# Minibatch: 0401 | Dis/Gen Cost:    0.946/1.222
# Minibatch: 0601 | Dis/Gen Cost:    1.043/1.114
# Minibatch: 0801 | Dis/Gen Cost:    0.923/1.152
# Epoch:     0004 | Dis/Gen AvgCost: 0.895/1.188
# Time elapsed: 0.53 min
# Minibatch: 0001 | Dis/Gen Cost:    1.086/1.046
# Minibatch: 0201 | Dis/Gen Cost:    0.991/1.136
# Minibatch: 0401 | Dis/Gen Cost:    0.982/1.187
# Minibatch: 0601 | Dis/Gen Cost:    1.008/1.077
# Minibatch: 0801 | Dis/Gen Cost:    0.956/1.098
# Epoch:     0005 | Dis/Gen AvgCost: 0.992/1.099
# Time elapsed: 0.66 min
# Minibatch: 0001 | Dis/Gen Cost:    0.996/1.060
# Minibatch: 0201 | Dis/Gen Cost:    1.006/1.084
# Minibatch: 0401 | Dis/Gen Cost:    1.074/1.015
# Minibatch: 0601 | Dis/Gen Cost:    1.100/0.933
# Minibatch: 0801 | Dis/Gen Cost:    1.040/1.052
# Epoch:     0006 | Dis/Gen AvgCost: 1.057/1.033
# Time elapsed: 0.78 min
# Minibatch: 0001 | Dis/Gen Cost:    1.032/1.031
# Minibatch: 0201 | Dis/Gen Cost:    1.049/0.989
# Minibatch: 0401 | Dis/Gen Cost:    1.202/0.905
# Minibatch: 0601 | Dis/Gen Cost:    1.175/1.028
# Minibatch: 0801 | Dis/Gen Cost:    1.056/0.927
# Epoch:     0007 | Dis/Gen AvgCost: 1.082/1.013
# Time elapsed: 0.90 min
# Minibatch: 0001 | Dis/Gen Cost:    0.995/1.073
# Minibatch: 0201 | Dis/Gen Cost:    1.123/0.922
# Minibatch: 0401 | Dis/Gen Cost:    1.078/1.055
# Minibatch: 0601 | Dis/Gen Cost:    1.078/1.105
# Minibatch: 0801 | Dis/Gen Cost:    1.064/1.013
# Epoch:     0008 | Dis/Gen AvgCost: 1.112/0.989
# Time elapsed: 1.03 min
# Minibatch: 0001 | Dis/Gen Cost:    1.166/0.894
# Minibatch: 0201 | Dis/Gen Cost:    1.247/0.813
# Minibatch: 0401 | Dis/Gen Cost:    1.254/0.931
# Minibatch: 0601 | Dis/Gen Cost:    1.110/0.994
# Minibatch: 0801 | Dis/Gen Cost:    1.208/0.938
# Epoch:     0009 | Dis/Gen AvgCost: 1.148/0.966
# Time elapsed: 1.15 min
# Minibatch: 0001 | Dis/Gen Cost:    1.343/0.894
# Minibatch: 0201 | Dis/Gen Cost:    1.160/0.998
# Minibatch: 0401 | Dis/Gen Cost:    1.112/0.944
# Minibatch: 0601 | Dis/Gen Cost:    1.046/1.014
# Minibatch: 0801 | Dis/Gen Cost:    1.089/1.096
# Epoch:     0010 | Dis/Gen AvgCost: 1.173/0.939
# Time elapsed: 1.27 min
# Minibatch: 0001 | Dis/Gen Cost:    1.278/0.793
# Minibatch: 0201 | Dis/Gen Cost:    1.274/0.860
# Minibatch: 0401 | Dis/Gen Cost:    1.140/0.961
# Minibatch: 0601 | Dis/Gen Cost:    1.304/0.868
# Minibatch: 0801 | Dis/Gen Cost:    1.231/0.825
# Epoch:     0011 | Dis/Gen AvgCost: 1.191/0.923
# Time elapsed: 1.40 min
# Minibatch: 0001 | Dis/Gen Cost:    1.172/0.970
# Minibatch: 0201 | Dis/Gen Cost:    1.209/0.914
# Minibatch: 0401 | Dis/Gen Cost:    1.281/1.023
# Minibatch: 0601 | Dis/Gen Cost:    1.167/0.877
# Minibatch: 0801 | Dis/Gen Cost:    1.264/0.826
# Epoch:     0012 | Dis/Gen AvgCost: 1.196/0.920
# Time elapsed: 1.52 min
# Minibatch: 0001 | Dis/Gen Cost:    1.136/0.960
# Minibatch: 0201 | Dis/Gen Cost:    1.178/0.900
# Minibatch: 0401 | Dis/Gen Cost:    1.223/0.921
# Minibatch: 0601 | Dis/Gen Cost:    1.316/0.884
# Minibatch: 0801 | Dis/Gen Cost:    1.206/0.864
# Epoch:     0013 | Dis/Gen AvgCost: 1.199/0.914
# Time elapsed: 1.65 min
# Minibatch: 0001 | Dis/Gen Cost:    1.281/0.874
# Minibatch: 0201 | Dis/Gen Cost:    1.200/0.908
# Minibatch: 0401 | Dis/Gen Cost:    1.120/0.974
# Minibatch: 0601 | Dis/Gen Cost:    1.103/0.986
# Minibatch: 0801 | Dis/Gen Cost:    1.251/0.932
# Epoch:     0014 | Dis/Gen AvgCost: 1.212/0.903
# Time elapsed: 1.77 min
# Minibatch: 0001 | Dis/Gen Cost:    1.217/0.971
# Minibatch: 0201 | Dis/Gen Cost:    1.253/0.798
# Minibatch: 0401 | Dis/Gen Cost:    1.155/0.992
# Minibatch: 0601 | Dis/Gen Cost:    1.372/0.862
# Minibatch: 0801 | Dis/Gen Cost:    1.258/0.885
# Epoch:     0015 | Dis/Gen AvgCost: 1.225/0.893
# Time elapsed: 1.89 min
# Minibatch: 0001 | Dis/Gen Cost:    1.288/0.830
# Minibatch: 0201 | Dis/Gen Cost:    1.243/0.910
# Minibatch: 0401 | Dis/Gen Cost:    1.175/0.977
# Minibatch: 0601 | Dis/Gen Cost:    1.240/0.943
# Minibatch: 0801 | Dis/Gen Cost:    1.155/0.924
# Epoch:     0016 | Dis/Gen AvgCost: 1.234/0.884
# Time elapsed: 2.02 min
# Minibatch: 0001 | Dis/Gen Cost:    1.270/0.899
# Minibatch: 0201 | Dis/Gen Cost:    1.286/0.838
# Minibatch: 0401 | Dis/Gen Cost:    1.209/0.981
# Minibatch: 0601 | Dis/Gen Cost:    1.199/0.961
# Minibatch: 0801 | Dis/Gen Cost:    1.247/0.870
# Epoch:     0017 | Dis/Gen AvgCost: 1.247/0.879
# Time elapsed: 2.14 min
# Minibatch: 0001 | Dis/Gen Cost:    1.250/0.899
# Minibatch: 0201 | Dis/Gen Cost:    1.271/0.846
# Minibatch: 0401 | Dis/Gen Cost:    1.131/0.917
# Minibatch: 0601 | Dis/Gen Cost:    1.167/0.922
# Minibatch: 0801 | Dis/Gen Cost:    1.243/0.854
# Epoch:     0018 | Dis/Gen AvgCost: 1.257/0.868
# Time elapsed: 2.26 min
# Minibatch: 0001 | Dis/Gen Cost:    1.301/0.757
# Minibatch: 0201 | Dis/Gen Cost:    1.335/0.853
# Minibatch: 0401 | Dis/Gen Cost:    1.396/0.835
# Minibatch: 0601 | Dis/Gen Cost:    1.283/0.894
# Minibatch: 0801 | Dis/Gen Cost:    1.297/0.804
# Epoch:     0019 | Dis/Gen AvgCost: 1.270/0.861
# Time elapsed: 2.38 min
# Minibatch: 0001 | Dis/Gen Cost:    1.300/0.853
# Minibatch: 0201 | Dis/Gen Cost:    1.224/0.978
# Minibatch: 0401 | Dis/Gen Cost:    1.250/0.811
# Minibatch: 0601 | Dis/Gen Cost:    1.349/0.813
# Minibatch: 0801 | Dis/Gen Cost:    1.259/0.828
# Epoch:     0020 | Dis/Gen AvgCost: 1.275/0.852
# Time elapsed: 2.51 min
# Minibatch: 0001 | Dis/Gen Cost:    1.221/0.857
# Minibatch: 0201 | Dis/Gen Cost:    1.242/0.870
# Minibatch: 0401 | Dis/Gen Cost:    1.280/0.849
# Minibatch: 0601 | Dis/Gen Cost:    1.356/0.781
# Minibatch: 0801 | Dis/Gen Cost:    1.181/0.894
# Epoch:     0021 | Dis/Gen AvgCost: 1.281/0.844
# Time elapsed: 2.63 min
# Minibatch: 0001 | Dis/Gen Cost:    1.301/0.834
# Minibatch: 0201 | Dis/Gen Cost:    1.351/0.846
# Minibatch: 0401 | Dis/Gen Cost:    1.208/0.915
# Minibatch: 0601 | Dis/Gen Cost:    1.202/0.951
# Minibatch: 0801 | Dis/Gen Cost:    1.232/0.858
# Epoch:     0022 | Dis/Gen AvgCost: 1.288/0.838
# Time elapsed: 2.76 min
# Minibatch: 0001 | Dis/Gen Cost:    1.268/0.821
# Minibatch: 0201 | Dis/Gen Cost:    1.348/0.834
# Minibatch: 0401 | Dis/Gen Cost:    1.286/0.855
# Minibatch: 0601 | Dis/Gen Cost:    1.366/0.823
# Minibatch: 0801 | Dis/Gen Cost:    1.303/0.857
# Epoch:     0023 | Dis/Gen AvgCost: 1.292/0.834
# Time elapsed: 2.88 min
# Minibatch: 0001 | Dis/Gen Cost:    1.296/0.734
# Minibatch: 0201 | Dis/Gen Cost:    1.218/0.912
# Minibatch: 0401 | Dis/Gen Cost:    1.284/0.887
# Minibatch: 0601 | Dis/Gen Cost:    1.358/0.791
# Minibatch: 0801 | Dis/Gen Cost:    1.366/0.726
# Epoch:     0024 | Dis/Gen AvgCost: 1.299/0.826
# Time elapsed: 3.00 min
# Minibatch: 0001 | Dis/Gen Cost:    1.289/0.774
# Minibatch: 0201 | Dis/Gen Cost:    1.217/0.816
# Minibatch: 0401 | Dis/Gen Cost:    1.324/0.835
# Minibatch: 0601 | Dis/Gen Cost:    1.361/0.841
# Minibatch: 0801 | Dis/Gen Cost:    1.307/0.864
# Epoch:     0025 | Dis/Gen AvgCost: 1.306/0.818
# Time elapsed: 3.13 min
# Minibatch: 0001 | Dis/Gen Cost:    1.400/0.749
# Minibatch: 0201 | Dis/Gen Cost:    1.324/0.779
# Minibatch: 0401 | Dis/Gen Cost:    1.309/0.758
# Minibatch: 0601 | Dis/Gen Cost:    1.340/0.818
# Minibatch: 0801 | Dis/Gen Cost:    1.383/0.763
# Epoch:     0026 | Dis/Gen AvgCost: 1.315/0.814
# Time elapsed: 3.25 min
# Minibatch: 0001 | Dis/Gen Cost:    1.280/0.813
# Minibatch: 0201 | Dis/Gen Cost:    1.434/0.767
# Minibatch: 0401 | Dis/Gen Cost:    1.505/0.761
# Minibatch: 0601 | Dis/Gen Cost:    1.342/0.779
# Minibatch: 0801 | Dis/Gen Cost:    1.363/0.858
# Epoch:     0027 | Dis/Gen AvgCost: 1.318/0.809
# Time elapsed: 3.37 min
# Minibatch: 0001 | Dis/Gen Cost:    1.316/0.822
# Minibatch: 0201 | Dis/Gen Cost:    1.359/0.790
# Minibatch: 0401 | Dis/Gen Cost:    1.311/0.785
# Minibatch: 0601 | Dis/Gen Cost:    1.263/0.884
# Minibatch: 0801 | Dis/Gen Cost:    1.324/0.747
# Epoch:     0028 | Dis/Gen AvgCost: 1.319/0.804
# Time elapsed: 3.50 min
# Minibatch: 0001 | Dis/Gen Cost:    1.212/0.860
# Minibatch: 0201 | Dis/Gen Cost:    1.262/0.790
# Minibatch: 0401 | Dis/Gen Cost:    1.279/0.834
# Minibatch: 0601 | Dis/Gen Cost:    1.252/0.893
# Minibatch: 0801 | Dis/Gen Cost:    1.317/0.853
# Epoch:     0029 | Dis/Gen AvgCost: 1.327/0.798
# Time elapsed: 3.62 min
# Minibatch: 0001 | Dis/Gen Cost:    1.343/0.758
# Minibatch: 0201 | Dis/Gen Cost:    1.332/0.833
# Minibatch: 0401 | Dis/Gen Cost:    1.405/0.791
# Minibatch: 0601 | Dis/Gen Cost:    1.307/0.805
# Minibatch: 0801 | Dis/Gen Cost:    1.310/0.832
# Epoch:     0030 | Dis/Gen AvgCost: 1.345/0.793
# Time elapsed: 3.74 min
# Minibatch: 0001 | Dis/Gen Cost:    1.373/0.750
# Minibatch: 0201 | Dis/Gen Cost:    1.348/0.773
# Minibatch: 0401 | Dis/Gen Cost:    1.346/0.857
# Minibatch: 0601 | Dis/Gen Cost:    1.405/0.815
# Minibatch: 0801 | Dis/Gen Cost:    1.378/0.769
# Epoch:     0031 | Dis/Gen AvgCost: 1.341/0.787
# Time elapsed: 3.87 min
# Minibatch: 0001 | Dis/Gen Cost:    1.368/0.751
# Minibatch: 0201 | Dis/Gen Cost:    1.421/0.696
# Minibatch: 0401 | Dis/Gen Cost:    1.346/0.718
# Minibatch: 0601 | Dis/Gen Cost:    1.239/0.865
# Minibatch: 0801 | Dis/Gen Cost:    1.335/0.798
# Epoch:     0032 | Dis/Gen AvgCost: 1.346/0.779
# Time elapsed: 3.99 min
# Minibatch: 0001 | Dis/Gen Cost:    1.326/0.748
# Minibatch: 0201 | Dis/Gen Cost:    1.166/0.853
# Minibatch: 0401 | Dis/Gen Cost:    1.354/0.801
# Minibatch: 0601 | Dis/Gen Cost:    1.345/0.725
# Minibatch: 0801 | Dis/Gen Cost:    1.289/0.825
# Epoch:     0033 | Dis/Gen AvgCost: 1.346/0.779
# Time elapsed: 4.11 min
# Minibatch: 0001 | Dis/Gen Cost:    1.400/0.800
# Minibatch: 0201 | Dis/Gen Cost:    1.296/0.835
# Minibatch: 0401 | Dis/Gen Cost:    1.438/0.723
# Minibatch: 0601 | Dis/Gen Cost:    1.344/0.775
# Minibatch: 0801 | Dis/Gen Cost:    1.403/0.779
# Epoch:     0034 | Dis/Gen AvgCost: 1.349/0.775
# Time elapsed: 4.24 min
# Minibatch: 0001 | Dis/Gen Cost:    1.385/0.739
# Minibatch: 0201 | Dis/Gen Cost:    1.277/0.806
# Minibatch: 0401 | Dis/Gen Cost:    1.330/0.751
# Minibatch: 0601 | Dis/Gen Cost:    1.292/0.808
# Minibatch: 0801 | Dis/Gen Cost:    1.317/0.771
# Epoch:     0035 | Dis/Gen AvgCost: 1.351/0.774
# Time elapsed: 4.36 min
# Minibatch: 0001 | Dis/Gen Cost:    1.332/0.805
# Minibatch: 0201 | Dis/Gen Cost:    1.312/0.777
# Minibatch: 0401 | Dis/Gen Cost:    1.331/0.781
# Minibatch: 0601 | Dis/Gen Cost:    1.311/0.779
# Minibatch: 0801 | Dis/Gen Cost:    1.347/0.775
# Epoch:     0036 | Dis/Gen AvgCost: 1.358/0.766
# Time elapsed: 4.48 min
# Minibatch: 0001 | Dis/Gen Cost:    1.324/0.824
# Minibatch: 0201 | Dis/Gen Cost:    1.403/0.728
# Minibatch: 0401 | Dis/Gen Cost:    1.322/0.750
# Minibatch: 0601 | Dis/Gen Cost:    1.280/0.808
# Minibatch: 0801 | Dis/Gen Cost:    1.265/0.828
# Epoch:     0037 | Dis/Gen AvgCost: 1.359/0.766
# Time elapsed: 4.60 min
# Minibatch: 0001 | Dis/Gen Cost:    1.417/0.754
# Minibatch: 0201 | Dis/Gen Cost:    1.328/0.772
# Minibatch: 0401 | Dis/Gen Cost:    1.292/0.753
# Minibatch: 0601 | Dis/Gen Cost:    1.329/0.775
# Minibatch: 0801 | Dis/Gen Cost:    1.339/0.747
# Epoch:     0038 | Dis/Gen AvgCost: 1.364/0.759
# Time elapsed: 4.73 min
# Minibatch: 0001 | Dis/Gen Cost:    1.451/0.731
# Minibatch: 0201 | Dis/Gen Cost:    1.348/0.754
# Minibatch: 0401 | Dis/Gen Cost:    1.408/0.730
# Minibatch: 0601 | Dis/Gen Cost:    1.405/0.758
# Minibatch: 0801 | Dis/Gen Cost:    1.374/0.732
# Epoch:     0039 | Dis/Gen AvgCost: 1.368/0.755
# Time elapsed: 4.85 min
# Minibatch: 0001 | Dis/Gen Cost:    1.312/0.786
# Minibatch: 0201 | Dis/Gen Cost:    1.281/0.802
# Minibatch: 0401 | Dis/Gen Cost:    1.433/0.738
# Minibatch: 0601 | Dis/Gen Cost:    1.291/0.774
# Minibatch: 0801 | Dis/Gen Cost:    1.377/0.709
# Epoch:     0040 | Dis/Gen AvgCost: 1.378/0.752
# Time elapsed: 4.97 min
# Minibatch: 0001 | Dis/Gen Cost:    1.296/0.798
# Minibatch: 0201 | Dis/Gen Cost:    1.372/0.714
# Minibatch: 0401 | Dis/Gen Cost:    1.317/0.806
# Minibatch: 0601 | Dis/Gen Cost:    1.497/0.717
# Minibatch: 0801 | Dis/Gen Cost:    1.439/0.702
# Epoch:     0041 | Dis/Gen AvgCost: 1.380/0.747
# Time elapsed: 5.10 min
# Minibatch: 0001 | Dis/Gen Cost:    1.396/0.711
# Minibatch: 0201 | Dis/Gen Cost:    1.371/0.759
# Minibatch: 0401 | Dis/Gen Cost:    1.366/0.710
# Minibatch: 0601 | Dis/Gen Cost:    1.337/0.789
# Minibatch: 0801 | Dis/Gen Cost:    1.409/0.666
# Epoch:     0042 | Dis/Gen AvgCost: 1.378/0.749
# Time elapsed: 5.22 min
# Minibatch: 0001 | Dis/Gen Cost:    1.445/0.671
# Minibatch: 0201 | Dis/Gen Cost:    1.333/0.801
# Minibatch: 0401 | Dis/Gen Cost:    1.408/0.706
# Minibatch: 0601 | Dis/Gen Cost:    1.390/0.743
# Minibatch: 0801 | Dis/Gen Cost:    1.454/0.723
# Epoch:     0043 | Dis/Gen AvgCost: 1.379/0.742
# Time elapsed: 5.34 min
# Minibatch: 0001 | Dis/Gen Cost:    1.352/0.804
# Minibatch: 0201 | Dis/Gen Cost:    1.422/0.709
# Minibatch: 0401 | Dis/Gen Cost:    1.434/0.729
# Minibatch: 0601 | Dis/Gen Cost:    1.462/0.675
# Minibatch: 0801 | Dis/Gen Cost:    1.342/0.840
# Epoch:     0044 | Dis/Gen AvgCost: 1.378/0.741
# Time elapsed: 5.47 min
# Minibatch: 0001 | Dis/Gen Cost:    1.391/0.736
# Minibatch: 0201 | Dis/Gen Cost:    1.345/0.717
# Minibatch: 0401 | Dis/Gen Cost:    1.380/0.738
# Minibatch: 0601 | Dis/Gen Cost:    1.380/0.720
# Minibatch: 0801 | Dis/Gen Cost:    1.392/0.685
# Epoch:     0045 | Dis/Gen AvgCost: 1.378/0.742
# Time elapsed: 5.59 min
# Minibatch: 0001 | Dis/Gen Cost:    1.477/0.691
# Minibatch: 0201 | Dis/Gen Cost:    1.363/0.744
# Minibatch: 0401 | Dis/Gen Cost:    1.445/0.721
# Minibatch: 0601 | Dis/Gen Cost:    1.413/0.708
# Minibatch: 0801 | Dis/Gen Cost:    1.466/0.683
# Epoch:     0046 | Dis/Gen AvgCost: 1.378/0.740
# Time elapsed: 5.72 min
# Minibatch: 0001 | Dis/Gen Cost:    1.392/0.738
# Minibatch: 0201 | Dis/Gen Cost:    1.365/0.709
# Minibatch: 0401 | Dis/Gen Cost:    1.437/0.690
# Minibatch: 0601 | Dis/Gen Cost:    1.348/0.793
# Minibatch: 0801 | Dis/Gen Cost:    1.363/0.766
# Epoch:     0047 | Dis/Gen AvgCost: 1.381/0.737
# Time elapsed: 5.84 min
# Minibatch: 0001 | Dis/Gen Cost:    1.438/0.693
# Minibatch: 0201 | Dis/Gen Cost:    1.328/0.749
# Minibatch: 0401 | Dis/Gen Cost:    1.395/0.686
# Minibatch: 0601 | Dis/Gen Cost:    1.373/0.793
# Minibatch: 0801 | Dis/Gen Cost:    1.378/0.787
# Epoch:     0048 | Dis/Gen AvgCost: 1.386/0.735
# Time elapsed: 5.96 min
# Minibatch: 0001 | Dis/Gen Cost:    1.384/0.756
# Minibatch: 0201 | Dis/Gen Cost:    1.402/0.766
# Minibatch: 0401 | Dis/Gen Cost:    1.411/0.762
# Minibatch: 0601 | Dis/Gen Cost:    1.358/0.744
# Minibatch: 0801 | Dis/Gen Cost:    1.374/0.712
# Epoch:     0049 | Dis/Gen AvgCost: 1.387/0.734
# Time elapsed: 6.09 min
# Minibatch: 0001 | Dis/Gen Cost:    1.393/0.721
# Minibatch: 0201 | Dis/Gen Cost:    1.388/0.711
# Minibatch: 0401 | Dis/Gen Cost:    1.423/0.737
# Minibatch: 0601 | Dis/Gen Cost:    1.413/0.711
# Minibatch: 0801 | Dis/Gen Cost:    1.421/0.680
# Epoch:     0050 | Dis/Gen AvgCost: 1.386/0.731
# Time elapsed: 6.21 min
# Minibatch: 0001 | Dis/Gen Cost:    1.410/0.717
# Minibatch: 0201 | Dis/Gen Cost:    1.367/0.761
# Minibatch: 0401 | Dis/Gen Cost:    1.407/0.711
# Minibatch: 0601 | Dis/Gen Cost:    1.313/0.756
# Minibatch: 0801 | Dis/Gen Cost:    1.343/0.755
# Epoch:     0051 | Dis/Gen AvgCost: 1.380/0.732
# Time elapsed: 6.33 min
# Minibatch: 0001 | Dis/Gen Cost:    1.383/0.694
# Minibatch: 0201 | Dis/Gen Cost:    1.374/0.727
# Minibatch: 0401 | Dis/Gen Cost:    1.357/0.709
# Minibatch: 0601 | Dis/Gen Cost:    1.334/0.747
# Minibatch: 0801 | Dis/Gen Cost:    1.413/0.746
# Epoch:     0052 | Dis/Gen AvgCost: 1.386/0.727
# Time elapsed: 6.46 min
# Minibatch: 0001 | Dis/Gen Cost:    1.443/0.716
# Minibatch: 0201 | Dis/Gen Cost:    1.291/0.791
# Minibatch: 0401 | Dis/Gen Cost:    1.381/0.714
# Minibatch: 0601 | Dis/Gen Cost:    1.444/0.709
# Minibatch: 0801 | Dis/Gen Cost:    1.370/0.773
# Epoch:     0053 | Dis/Gen AvgCost: 1.389/0.727
# Time elapsed: 6.58 min
# Minibatch: 0001 | Dis/Gen Cost:    1.298/0.770
# Minibatch: 0201 | Dis/Gen Cost:    1.470/0.665
# Minibatch: 0401 | Dis/Gen Cost:    1.367/0.717
# Minibatch: 0601 | Dis/Gen Cost:    1.373/0.721
# Minibatch: 0801 | Dis/Gen Cost:    1.373/0.715
# Epoch:     0054 | Dis/Gen AvgCost: 1.385/0.726
# Time elapsed: 6.70 min
# Minibatch: 0001 | Dis/Gen Cost:    1.428/0.701
# Minibatch: 0201 | Dis/Gen Cost:    1.433/0.667
# Minibatch: 0401 | Dis/Gen Cost:    1.384/0.687
# Minibatch: 0601 | Dis/Gen Cost:    1.349/0.741
# Minibatch: 0801 | Dis/Gen Cost:    1.358/0.725
# Epoch:     0055 | Dis/Gen AvgCost: 1.388/0.724
# Time elapsed: 6.83 min
# Minibatch: 0001 | Dis/Gen Cost:    1.401/0.733
# Minibatch: 0201 | Dis/Gen Cost:    1.367/0.725
# Minibatch: 0401 | Dis/Gen Cost:    1.310/0.708
# Minibatch: 0601 | Dis/Gen Cost:    1.441/0.704
# Minibatch: 0801 | Dis/Gen Cost:    1.390/0.706
# Epoch:     0056 | Dis/Gen AvgCost: 1.388/0.725
# Time elapsed: 6.95 min
# Minibatch: 0001 | Dis/Gen Cost:    1.412/0.697
# Minibatch: 0201 | Dis/Gen Cost:    1.385/0.741
# Minibatch: 0401 | Dis/Gen Cost:    1.420/0.726
# Minibatch: 0601 | Dis/Gen Cost:    1.425/0.722
# Minibatch: 0801 | Dis/Gen Cost:    1.369/0.704
# Epoch:     0057 | Dis/Gen AvgCost: 1.383/0.726
# Time elapsed: 7.07 min
# Minibatch: 0001 | Dis/Gen Cost:    1.384/0.728
# Minibatch: 0201 | Dis/Gen Cost:    1.340/0.746
# Minibatch: 0401 | Dis/Gen Cost:    1.369/0.719
# Minibatch: 0601 | Dis/Gen Cost:    1.412/0.714
# Minibatch: 0801 | Dis/Gen Cost:    1.392/0.719
# Epoch:     0058 | Dis/Gen AvgCost: 1.386/0.721
# Time elapsed: 7.20 min
# Minibatch: 0001 | Dis/Gen Cost:    1.402/0.705
# Minibatch: 0201 | Dis/Gen Cost:    1.352/0.751
# Minibatch: 0401 | Dis/Gen Cost:    1.368/0.745
# Minibatch: 0601 | Dis/Gen Cost:    1.459/0.707
# Minibatch: 0801 | Dis/Gen Cost:    1.348/0.717
# Epoch:     0059 | Dis/Gen AvgCost: 1.388/0.722
# Time elapsed: 7.32 min
# Minibatch: 0001 | Dis/Gen Cost:    1.336/0.738
# Minibatch: 0201 | Dis/Gen Cost:    1.321/0.766
# Minibatch: 0401 | Dis/Gen Cost:    1.405/0.771
# Minibatch: 0601 | Dis/Gen Cost:    1.376/0.706
# Minibatch: 0801 | Dis/Gen Cost:    1.372/0.747
# Epoch:     0060 | Dis/Gen AvgCost: 1.386/0.722
# Time elapsed: 7.45 min
# Minibatch: 0001 | Dis/Gen Cost:    1.341/0.719
# Minibatch: 0201 | Dis/Gen Cost:    1.364/0.758
# Minibatch: 0401 | Dis/Gen Cost:    1.376/0.716
# Minibatch: 0601 | Dis/Gen Cost:    1.359/0.724
# Minibatch: 0801 | Dis/Gen Cost:    1.397/0.722
# Epoch:     0061 | Dis/Gen AvgCost: 1.384/0.720
# Time elapsed: 7.57 min
# Minibatch: 0001 | Dis/Gen Cost:    1.338/0.734
# Minibatch: 0201 | Dis/Gen Cost:    1.437/0.711
# Minibatch: 0401 | Dis/Gen Cost:    1.342/0.751
# Minibatch: 0601 | Dis/Gen Cost:    1.353/0.758
# Minibatch: 0801 | Dis/Gen Cost:    1.380/0.736
# Epoch:     0062 | Dis/Gen AvgCost: 1.387/0.719
# Time elapsed: 7.69 min
# Minibatch: 0001 | Dis/Gen Cost:    1.410/0.713
# Minibatch: 0201 | Dis/Gen Cost:    1.339/0.711
# Minibatch: 0401 | Dis/Gen Cost:    1.387/0.714
# Minibatch: 0601 | Dis/Gen Cost:    1.317/0.782
# Minibatch: 0801 | Dis/Gen Cost:    1.394/0.740
# Epoch:     0063 | Dis/Gen AvgCost: 1.385/0.720
# Time elapsed: 7.81 min
# Minibatch: 0001 | Dis/Gen Cost:    1.462/0.695
# Minibatch: 0201 | Dis/Gen Cost:    1.359/0.742
# Minibatch: 0401 | Dis/Gen Cost:    1.380/0.743
# Minibatch: 0601 | Dis/Gen Cost:    1.374/0.704
# Minibatch: 0801 | Dis/Gen Cost:    1.425/0.693
# Epoch:     0064 | Dis/Gen AvgCost: 1.386/0.716
# Time elapsed: 7.94 min
# Minibatch: 0001 | Dis/Gen Cost:    1.333/0.730
# Minibatch: 0201 | Dis/Gen Cost:    1.378/0.715
# Minibatch: 0401 | Dis/Gen Cost:    1.435/0.736
# Minibatch: 0601 | Dis/Gen Cost:    1.415/0.722
# Minibatch: 0801 | Dis/Gen Cost:    1.364/0.771
# Epoch:     0065 | Dis/Gen AvgCost: 1.388/0.720
# Time elapsed: 8.06 min
# Minibatch: 0001 | Dis/Gen Cost:    1.378/0.758
# Minibatch: 0201 | Dis/Gen Cost:    1.534/0.671
# Minibatch: 0401 | Dis/Gen Cost:    1.411/0.700
# Minibatch: 0601 | Dis/Gen Cost:    1.454/0.640
# Minibatch: 0801 | Dis/Gen Cost:    1.374/0.704
# Epoch:     0066 | Dis/Gen AvgCost: 1.389/0.715
# Time elapsed: 8.19 min
# Minibatch: 0001 | Dis/Gen Cost:    1.399/0.675
# Minibatch: 0201 | Dis/Gen Cost:    1.332/0.707
# Minibatch: 0401 | Dis/Gen Cost:    1.389/0.703
# Minibatch: 0601 | Dis/Gen Cost:    1.326/0.738
# Minibatch: 0801 | Dis/Gen Cost:    1.396/0.694
# Epoch:     0067 | Dis/Gen AvgCost: 1.391/0.712
# Time elapsed: 8.31 min
# Minibatch: 0001 | Dis/Gen Cost:    1.415/0.703
# Minibatch: 0201 | Dis/Gen Cost:    1.377/0.716
# Minibatch: 0401 | Dis/Gen Cost:    1.418/0.690
# Minibatch: 0601 | Dis/Gen Cost:    1.388/0.749
# Minibatch: 0801 | Dis/Gen Cost:    1.356/0.711
# Epoch:     0068 | Dis/Gen AvgCost: 1.391/0.713
# Time elapsed: 8.43 min
# Minibatch: 0001 | Dis/Gen Cost:    1.371/0.733
# Minibatch: 0201 | Dis/Gen Cost:    1.378/0.712
# Minibatch: 0401 | Dis/Gen Cost:    1.396/0.722
# Minibatch: 0601 | Dis/Gen Cost:    1.330/0.769
# Minibatch: 0801 | Dis/Gen Cost:    1.377/0.732
# Epoch:     0069 | Dis/Gen AvgCost: 1.393/0.715
# Time elapsed: 8.56 min
# Minibatch: 0001 | Dis/Gen Cost:    1.339/0.728
# Minibatch: 0201 | Dis/Gen Cost:    1.381/0.719
# Minibatch: 0401 | Dis/Gen Cost:    1.392/0.747
# Minibatch: 0601 | Dis/Gen Cost:    1.451/0.675
# Minibatch: 0801 | Dis/Gen Cost:    1.377/0.714
# Epoch:     0070 | Dis/Gen AvgCost: 1.392/0.713
# Time elapsed: 8.68 min
# Minibatch: 0001 | Dis/Gen Cost:    1.429/0.692
# Minibatch: 0201 | Dis/Gen Cost:    1.396/0.700
# Minibatch: 0401 | Dis/Gen Cost:    1.365/0.745
# Minibatch: 0601 | Dis/Gen Cost:    1.475/0.692
# Minibatch: 0801 | Dis/Gen Cost:    1.378/0.704
# Epoch:     0071 | Dis/Gen AvgCost: 1.388/0.713
# Time elapsed: 8.81 min
# Minibatch: 0001 | Dis/Gen Cost:    1.336/0.744
# Minibatch: 0201 | Dis/Gen Cost:    1.300/0.761
# Minibatch: 0401 | Dis/Gen Cost:    1.373/0.689
# Minibatch: 0601 | Dis/Gen Cost:    1.377/0.726
# Minibatch: 0801 | Dis/Gen Cost:    1.431/0.665
# Epoch:     0072 | Dis/Gen AvgCost: 1.390/0.711
# Time elapsed: 8.93 min
# Minibatch: 0001 | Dis/Gen Cost:    1.382/0.721
# Minibatch: 0201 | Dis/Gen Cost:    1.431/0.684
# Minibatch: 0401 | Dis/Gen Cost:    1.334/0.748
# Minibatch: 0601 | Dis/Gen Cost:    1.430/0.684
# Minibatch: 0801 | Dis/Gen Cost:    1.487/0.682
# Epoch:     0073 | Dis/Gen AvgCost: 1.392/0.711
# Time elapsed: 9.05 min
# Minibatch: 0001 | Dis/Gen Cost:    1.348/0.748
# Minibatch: 0201 | Dis/Gen Cost:    1.506/0.668
# Minibatch: 0401 | Dis/Gen Cost:    1.338/0.744
# Minibatch: 0601 | Dis/Gen Cost:    1.388/0.708
# Minibatch: 0801 | Dis/Gen Cost:    1.366/0.744
# Epoch:     0074 | Dis/Gen AvgCost: 1.394/0.712
# Time elapsed: 9.18 min
# Minibatch: 0001 | Dis/Gen Cost:    1.318/0.771
# Minibatch: 0201 | Dis/Gen Cost:    1.410/0.708
# Minibatch: 0401 | Dis/Gen Cost:    1.435/0.688
# Minibatch: 0601 | Dis/Gen Cost:    1.427/0.717
# Minibatch: 0801 | Dis/Gen Cost:    1.343/0.736
# Epoch:     0075 | Dis/Gen AvgCost: 1.390/0.712
# Time elapsed: 9.30 min
# Minibatch: 0001 | Dis/Gen Cost:    1.410/0.702
# Minibatch: 0201 | Dis/Gen Cost:    1.392/0.659
# Minibatch: 0401 | Dis/Gen Cost:    1.401/0.692
# Minibatch: 0601 | Dis/Gen Cost:    1.387/0.696
# Minibatch: 0801 | Dis/Gen Cost:    1.345/0.724
# Epoch:     0076 | Dis/Gen AvgCost: 1.393/0.709
# Time elapsed: 9.42 min
# Minibatch: 0001 | Dis/Gen Cost:    1.380/0.709
# Minibatch: 0201 | Dis/Gen Cost:    1.417/0.685
# Minibatch: 0401 | Dis/Gen Cost:    1.406/0.703
# Minibatch: 0601 | Dis/Gen Cost:    1.365/0.733
# Minibatch: 0801 | Dis/Gen Cost:    1.371/0.717
# Epoch:     0077 | Dis/Gen AvgCost: 1.393/0.708
# Time elapsed: 9.55 min
# Minibatch: 0001 | Dis/Gen Cost:    1.377/0.704
# Minibatch: 0201 | Dis/Gen Cost:    1.361/0.707
# Minibatch: 0401 | Dis/Gen Cost:    1.356/0.723
# Minibatch: 0601 | Dis/Gen Cost:    1.407/0.722
# Minibatch: 0801 | Dis/Gen Cost:    1.443/0.688
# Epoch:     0078 | Dis/Gen AvgCost: 1.390/0.710
# Time elapsed: 9.67 min
# Minibatch: 0001 | Dis/Gen Cost:    1.436/0.700
# Minibatch: 0201 | Dis/Gen Cost:    1.381/0.737
# Minibatch: 0401 | Dis/Gen Cost:    1.384/0.701
# Minibatch: 0601 | Dis/Gen Cost:    1.353/0.704
# Minibatch: 0801 | Dis/Gen Cost:    1.387/0.742
# Epoch:     0079 | Dis/Gen AvgCost: 1.392/0.708
# Time elapsed: 9.79 min
# Minibatch: 0001 | Dis/Gen Cost:    1.376/0.698
# Minibatch: 0201 | Dis/Gen Cost:    1.417/0.687
# Minibatch: 0401 | Dis/Gen Cost:    1.404/0.698
# Minibatch: 0601 | Dis/Gen Cost:    1.383/0.717
# Minibatch: 0801 | Dis/Gen Cost:    1.340/0.773
# Epoch:     0080 | Dis/Gen AvgCost: 1.392/0.707
# Time elapsed: 9.92 min
# Minibatch: 0001 | Dis/Gen Cost:    1.398/0.712
# Minibatch: 0201 | Dis/Gen Cost:    1.380/0.717
# Minibatch: 0401 | Dis/Gen Cost:    1.410/0.716
# Minibatch: 0601 | Dis/Gen Cost:    1.386/0.702
# Minibatch: 0801 | Dis/Gen Cost:    1.428/0.674
# Epoch:     0081 | Dis/Gen AvgCost: 1.393/0.707
# Time elapsed: 10.04 min
# Minibatch: 0001 | Dis/Gen Cost:    1.395/0.727
# Minibatch: 0201 | Dis/Gen Cost:    1.417/0.715
# Minibatch: 0401 | Dis/Gen Cost:    1.478/0.634
# Minibatch: 0601 | Dis/Gen Cost:    1.465/0.683
# Minibatch: 0801 | Dis/Gen Cost:    1.396/0.724
# Epoch:     0082 | Dis/Gen AvgCost: 1.390/0.708
# Time elapsed: 10.17 min
# Minibatch: 0001 | Dis/Gen Cost:    1.369/0.697
# Minibatch: 0201 | Dis/Gen Cost:    1.433/0.708
# Minibatch: 0401 | Dis/Gen Cost:    1.381/0.719
# Minibatch: 0601 | Dis/Gen Cost:    1.368/0.697
# Minibatch: 0801 | Dis/Gen Cost:    1.424/0.699
# Epoch:     0083 | Dis/Gen AvgCost: 1.389/0.707
# Time elapsed: 10.29 min
# Minibatch: 0001 | Dis/Gen Cost:    1.371/0.713
# Minibatch: 0201 | Dis/Gen Cost:    1.427/0.681
# Minibatch: 0401 | Dis/Gen Cost:    1.415/0.718
# Minibatch: 0601 | Dis/Gen Cost:    1.419/0.694
# Minibatch: 0801 | Dis/Gen Cost:    1.398/0.696
# Epoch:     0084 | Dis/Gen AvgCost: 1.388/0.708
# Time elapsed: 10.41 min
# Minibatch: 0001 | Dis/Gen Cost:    1.406/0.707
# Minibatch: 0201 | Dis/Gen Cost:    1.340/0.745
# Minibatch: 0401 | Dis/Gen Cost:    1.417/0.663
# Minibatch: 0601 | Dis/Gen Cost:    1.408/0.707
# Minibatch: 0801 | Dis/Gen Cost:    1.410/0.685
# Epoch:     0085 | Dis/Gen AvgCost: 1.387/0.709
# Time elapsed: 10.54 min
# Minibatch: 0001 | Dis/Gen Cost:    1.334/0.730
# Minibatch: 0201 | Dis/Gen Cost:    1.364/0.726
# Minibatch: 0401 | Dis/Gen Cost:    1.428/0.688
# Minibatch: 0601 | Dis/Gen Cost:    1.338/0.721
# Minibatch: 0801 | Dis/Gen Cost:    1.476/0.656
# Epoch:     0086 | Dis/Gen AvgCost: 1.385/0.710
# Time elapsed: 10.66 min
# Minibatch: 0001 | Dis/Gen Cost:    1.329/0.731
# Minibatch: 0201 | Dis/Gen Cost:    1.394/0.675
# Minibatch: 0401 | Dis/Gen Cost:    1.397/0.708
# Minibatch: 0601 | Dis/Gen Cost:    1.394/0.702
# Minibatch: 0801 | Dis/Gen Cost:    1.351/0.710
# Epoch:     0087 | Dis/Gen AvgCost: 1.388/0.710
# Time elapsed: 10.79 min
# Minibatch: 0001 | Dis/Gen Cost:    1.396/0.699
# Minibatch: 0201 | Dis/Gen Cost:    1.405/0.707
# Minibatch: 0401 | Dis/Gen Cost:    1.422/0.703
# Minibatch: 0601 | Dis/Gen Cost:    1.420/0.693
# Minibatch: 0801 | Dis/Gen Cost:    1.391/0.722
# Epoch:     0088 | Dis/Gen AvgCost: 1.387/0.709
# Time elapsed: 10.91 min
# Minibatch: 0001 | Dis/Gen Cost:    1.416/0.706
# Minibatch: 0201 | Dis/Gen Cost:    1.434/0.698
# Minibatch: 0401 | Dis/Gen Cost:    1.372/0.731
# Minibatch: 0601 | Dis/Gen Cost:    1.395/0.670
# Minibatch: 0801 | Dis/Gen Cost:    1.419/0.688
# Epoch:     0089 | Dis/Gen AvgCost: 1.389/0.710
# Time elapsed: 11.03 min
# Minibatch: 0001 | Dis/Gen Cost:    1.483/0.684
# Minibatch: 0201 | Dis/Gen Cost:    1.313/0.750
# Minibatch: 0401 | Dis/Gen Cost:    1.402/0.687
# Minibatch: 0601 | Dis/Gen Cost:    1.388/0.706
# Minibatch: 0801 | Dis/Gen Cost:    1.376/0.718
# Epoch:     0090 | Dis/Gen AvgCost: 1.386/0.710
# Time elapsed: 11.16 min
# Minibatch: 0001 | Dis/Gen Cost:    1.385/0.699
# Minibatch: 0201 | Dis/Gen Cost:    1.351/0.733
# Minibatch: 0401 | Dis/Gen Cost:    1.366/0.704
# Minibatch: 0601 | Dis/Gen Cost:    1.416/0.699
# Minibatch: 0801 | Dis/Gen Cost:    1.376/0.729
# Epoch:     0091 | Dis/Gen AvgCost: 1.386/0.708
# Time elapsed: 11.28 min
# Minibatch: 0001 | Dis/Gen Cost:    1.366/0.722
# Minibatch: 0201 | Dis/Gen Cost:    1.451/0.687
# Minibatch: 0401 | Dis/Gen Cost:    1.406/0.683
# Minibatch: 0601 | Dis/Gen Cost:    1.335/0.735
# Minibatch: 0801 | Dis/Gen Cost:    1.358/0.724
# Epoch:     0092 | Dis/Gen AvgCost: 1.387/0.708
# Time elapsed: 11.41 min
# Minibatch: 0001 | Dis/Gen Cost:    1.409/0.734
# Minibatch: 0201 | Dis/Gen Cost:    1.414/0.699
# Minibatch: 0401 | Dis/Gen Cost:    1.376/0.729
# Minibatch: 0601 | Dis/Gen Cost:    1.403/0.692
# Minibatch: 0801 | Dis/Gen Cost:    1.407/0.729
# Epoch:     0093 | Dis/Gen AvgCost: 1.388/0.708
# Time elapsed: 11.53 min
# Minibatch: 0001 | Dis/Gen Cost:    1.324/0.748
# Minibatch: 0201 | Dis/Gen Cost:    1.370/0.746
# Minibatch: 0401 | Dis/Gen Cost:    1.378/0.726
# Minibatch: 0601 | Dis/Gen Cost:    1.375/0.697
# Minibatch: 0801 | Dis/Gen Cost:    1.370/0.707
# Epoch:     0094 | Dis/Gen AvgCost: 1.387/0.709
# Time elapsed: 11.65 min
# Minibatch: 0001 | Dis/Gen Cost:    1.388/0.707
# Minibatch: 0201 | Dis/Gen Cost:    1.389/0.695
# Minibatch: 0401 | Dis/Gen Cost:    1.393/0.680
# Minibatch: 0601 | Dis/Gen Cost:    1.386/0.736
# Minibatch: 0801 | Dis/Gen Cost:    1.385/0.718
# Epoch:     0095 | Dis/Gen AvgCost: 1.388/0.706
# Time elapsed: 11.78 min
# Minibatch: 0001 | Dis/Gen Cost:    1.404/0.689
# Minibatch: 0201 | Dis/Gen Cost:    1.387/0.706
# Minibatch: 0401 | Dis/Gen Cost:    1.391/0.699
# Minibatch: 0601 | Dis/Gen Cost:    1.369/0.714
# Minibatch: 0801 | Dis/Gen Cost:    1.421/0.699
# Epoch:     0096 | Dis/Gen AvgCost: 1.388/0.706
# Time elapsed: 11.90 min
# Minibatch: 0001 | Dis/Gen Cost:    1.389/0.700
# Minibatch: 0201 | Dis/Gen Cost:    1.356/0.715
# Minibatch: 0401 | Dis/Gen Cost:    1.378/0.721
# Minibatch: 0601 | Dis/Gen Cost:    1.418/0.685
# Minibatch: 0801 | Dis/Gen Cost:    1.377/0.684
# Epoch:     0097 | Dis/Gen AvgCost: 1.389/0.707
# Time elapsed: 12.02 min
# Minibatch: 0001 | Dis/Gen Cost:    1.408/0.694
# Minibatch: 0201 | Dis/Gen Cost:    1.392/0.713
# Minibatch: 0401 | Dis/Gen Cost:    1.438/0.692
# Minibatch: 0601 | Dis/Gen Cost:    1.360/0.697
# Minibatch: 0801 | Dis/Gen Cost:    1.353/0.708
# Epoch:     0098 | Dis/Gen AvgCost: 1.387/0.707
# Time elapsed: 12.15 min
# Minibatch: 0001 | Dis/Gen Cost:    1.386/0.667
# Minibatch: 0201 | Dis/Gen Cost:    1.387/0.694
# Minibatch: 0401 | Dis/Gen Cost:    1.406/0.699
# Minibatch: 0601 | Dis/Gen Cost:    1.394/0.679
# Minibatch: 0801 | Dis/Gen Cost:    1.404/0.688
# Epoch:     0099 | Dis/Gen AvgCost: 1.390/0.705
# Time elapsed: 12.27 min
# Minibatch: 0001 | Dis/Gen Cost:    1.446/0.677
# Minibatch: 0201 | Dis/Gen Cost:    1.425/0.717
# Minibatch: 0401 | Dis/Gen Cost:    1.403/0.728
# Minibatch: 0601 | Dis/Gen Cost:    1.371/0.716
# Minibatch: 0801 | Dis/Gen Cost:    1.435/0.687
# Epoch:     0100 | Dis/Gen AvgCost: 1.389/0.706
# Time elapsed: 12.40 min
# Minibatch: 0001 | Dis/Gen Cost:    1.387/0.695
# Minibatch: 0201 | Dis/Gen Cost:    1.452/0.667
# Minibatch: 0401 | Dis/Gen Cost:    1.321/0.727
# Minibatch: 0601 | Dis/Gen Cost:    1.349/0.726
# Minibatch: 0801 | Dis/Gen Cost:    1.365/0.706
# Epoch:     0101 | Dis/Gen AvgCost: 1.391/0.705
# Time elapsed: 12.52 min
# Minibatch: 0001 | Dis/Gen Cost:    1.417/0.713
# Minibatch: 0201 | Dis/Gen Cost:    1.370/0.719
# Minibatch: 0401 | Dis/Gen Cost:    1.428/0.705
# Minibatch: 0601 | Dis/Gen Cost:    1.416/0.700
# Minibatch: 0801 | Dis/Gen Cost:    1.412/0.670
# Epoch:     0102 | Dis/Gen AvgCost: 1.387/0.705
# Time elapsed: 12.64 min
# Minibatch: 0001 | Dis/Gen Cost:    1.366/0.690
# Minibatch: 0201 | Dis/Gen Cost:    1.353/0.712
# Minibatch: 0401 | Dis/Gen Cost:    1.427/0.679
# Minibatch: 0601 | Dis/Gen Cost:    1.360/0.709
# Minibatch: 0801 | Dis/Gen Cost:    1.373/0.712
# Epoch:     0103 | Dis/Gen AvgCost: 1.388/0.705
# Time elapsed: 12.77 min
# Minibatch: 0001 | Dis/Gen Cost:    1.433/0.687
# Minibatch: 0201 | Dis/Gen Cost:    1.369/0.732
# Minibatch: 0401 | Dis/Gen Cost:    1.377/0.721
# Minibatch: 0601 | Dis/Gen Cost:    1.408/0.687
# Minibatch: 0801 | Dis/Gen Cost:    1.377/0.721
# Epoch:     0104 | Dis/Gen AvgCost: 1.390/0.705
# Time elapsed: 12.89 min
# Minibatch: 0001 | Dis/Gen Cost:    1.407/0.694
# Minibatch: 0201 | Dis/Gen Cost:    1.392/0.717
# Minibatch: 0401 | Dis/Gen Cost:    1.381/0.706
# Minibatch: 0601 | Dis/Gen Cost:    1.407/0.684
# Minibatch: 0801 | Dis/Gen Cost:    1.468/0.660
# Epoch:     0105 | Dis/Gen AvgCost: 1.397/0.702
# Time elapsed: 13.02 min
# Minibatch: 0001 | Dis/Gen Cost:    1.390/0.699
# Minibatch: 0201 | Dis/Gen Cost:    1.370/0.727
# Minibatch: 0401 | Dis/Gen Cost:    1.359/0.713
# Minibatch: 0601 | Dis/Gen Cost:    1.362/0.708
# Minibatch: 0801 | Dis/Gen Cost:    1.390/0.731
# Epoch:     0106 | Dis/Gen AvgCost: 1.392/0.704
# Time elapsed: 13.14 min
# Minibatch: 0001 | Dis/Gen Cost:    1.397/0.688
# Minibatch: 0201 | Dis/Gen Cost:    1.414/0.678
# Minibatch: 0401 | Dis/Gen Cost:    1.390/0.722
# Minibatch: 0601 | Dis/Gen Cost:    1.455/0.672
# Minibatch: 0801 | Dis/Gen Cost:    1.415/0.697
# Epoch:     0107 | Dis/Gen AvgCost: 1.393/0.703
# Time elapsed: 13.26 min
# Minibatch: 0001 | Dis/Gen Cost:    1.416/0.698
# Minibatch: 0201 | Dis/Gen Cost:    1.453/0.695
# Minibatch: 0401 | Dis/Gen Cost:    1.322/0.739
# Minibatch: 0601 | Dis/Gen Cost:    1.351/0.710
# Minibatch: 0801 | Dis/Gen Cost:    1.450/0.683
# Epoch:     0108 | Dis/Gen AvgCost: 1.390/0.705
# Time elapsed: 13.39 min
# Minibatch: 0001 | Dis/Gen Cost:    1.392/0.692
# Minibatch: 0201 | Dis/Gen Cost:    1.422/0.681
# Minibatch: 0401 | Dis/Gen Cost:    1.367/0.707
# Minibatch: 0601 | Dis/Gen Cost:    1.371/0.732
# Minibatch: 0801 | Dis/Gen Cost:    1.396/0.701
# Epoch:     0109 | Dis/Gen AvgCost: 1.389/0.704
# Time elapsed: 13.51 min
# Minibatch: 0001 | Dis/Gen Cost:    1.365/0.680
# Minibatch: 0201 | Dis/Gen Cost:    1.368/0.708
# Minibatch: 0401 | Dis/Gen Cost:    1.395/0.705
# Minibatch: 0601 | Dis/Gen Cost:    1.391/0.683
# Minibatch: 0801 | Dis/Gen Cost:    1.379/0.714
# Epoch:     0110 | Dis/Gen AvgCost: 1.389/0.704
# Time elapsed: 13.63 min
# Minibatch: 0001 | Dis/Gen Cost:    1.373/0.694
# Minibatch: 0201 | Dis/Gen Cost:    1.425/0.688
# Minibatch: 0401 | Dis/Gen Cost:    1.362/0.712
# Minibatch: 0601 | Dis/Gen Cost:    1.401/0.705
# Minibatch: 0801 | Dis/Gen Cost:    1.413/0.706
# Epoch:     0111 | Dis/Gen AvgCost: 1.389/0.705
# Time elapsed: 13.76 min
# Minibatch: 0001 | Dis/Gen Cost:    1.339/0.743
# Minibatch: 0201 | Dis/Gen Cost:    1.415/0.667
# Minibatch: 0401 | Dis/Gen Cost:    1.450/0.679
# Minibatch: 0601 | Dis/Gen Cost:    1.402/0.696
# Minibatch: 0801 | Dis/Gen Cost:    1.362/0.711
# Epoch:     0112 | Dis/Gen AvgCost: 1.391/0.703
# Time elapsed: 13.88 min
# Minibatch: 0001 | Dis/Gen Cost:    1.405/0.716
# Minibatch: 0201 | Dis/Gen Cost:    1.369/0.725
# Minibatch: 0401 | Dis/Gen Cost:    1.379/0.683
# Minibatch: 0601 | Dis/Gen Cost:    1.390/0.713
# Minibatch: 0801 | Dis/Gen Cost:    1.404/0.706
# Epoch:     0113 | Dis/Gen AvgCost: 1.391/0.702
# Time elapsed: 14.01 min
# Minibatch: 0001 | Dis/Gen Cost:    1.386/0.680
# Minibatch: 0201 | Dis/Gen Cost:    1.378/0.718
# Minibatch: 0401 | Dis/Gen Cost:    1.385/0.708
# Minibatch: 0601 | Dis/Gen Cost:    1.410/0.671
# Minibatch: 0801 | Dis/Gen Cost:    1.412/0.686
# Epoch:     0114 | Dis/Gen AvgCost: 1.390/0.703
# Time elapsed: 14.13 min
# Minibatch: 0001 | Dis/Gen Cost:    1.403/0.706
# Minibatch: 0201 | Dis/Gen Cost:    1.337/0.731
# Minibatch: 0401 | Dis/Gen Cost:    1.383/0.705
# Minibatch: 0601 | Dis/Gen Cost:    1.412/0.682
# Minibatch: 0801 | Dis/Gen Cost:    1.395/0.690
# Epoch:     0115 | Dis/Gen AvgCost: 1.390/0.702
# Time elapsed: 14.25 min
# Minibatch: 0001 | Dis/Gen Cost:    1.397/0.685
# Minibatch: 0201 | Dis/Gen Cost:    1.398/0.722
# Minibatch: 0401 | Dis/Gen Cost:    1.397/0.698
# Minibatch: 0601 | Dis/Gen Cost:    1.363/0.714
# Minibatch: 0801 | Dis/Gen Cost:    1.398/0.699
# Epoch:     0116 | Dis/Gen AvgCost: 1.391/0.700
# Time elapsed: 14.38 min
# Minibatch: 0001 | Dis/Gen Cost:    1.385/0.709
# Minibatch: 0201 | Dis/Gen Cost:    1.359/0.723
# Minibatch: 0401 | Dis/Gen Cost:    1.340/0.742
# Minibatch: 0601 | Dis/Gen Cost:    1.364/0.714
# Minibatch: 0801 | Dis/Gen Cost:    1.418/0.695
# Epoch:     0117 | Dis/Gen AvgCost: 1.391/0.704
# Time elapsed: 14.50 min
# Minibatch: 0001 | Dis/Gen Cost:    1.406/0.692
# Minibatch: 0201 | Dis/Gen Cost:    1.398/0.698
# Minibatch: 0401 | Dis/Gen Cost:    1.367/0.716
# Minibatch: 0601 | Dis/Gen Cost:    1.389/0.700
# Minibatch: 0801 | Dis/Gen Cost:    1.360/0.713
# Epoch:     0118 | Dis/Gen AvgCost: 1.392/0.701
# Time elapsed: 14.63 min
# Minibatch: 0001 | Dis/Gen Cost:    1.397/0.692
# Minibatch: 0201 | Dis/Gen Cost:    1.394/0.713
# Minibatch: 0401 | Dis/Gen Cost:    1.390/0.704
# Minibatch: 0601 | Dis/Gen Cost:    1.358/0.713
# Minibatch: 0801 | Dis/Gen Cost:    1.421/0.695
# Epoch:     0119 | Dis/Gen AvgCost: 1.393/0.701
# Time elapsed: 14.75 min
# Minibatch: 0001 | Dis/Gen Cost:    1.411/0.701
# Minibatch: 0201 | Dis/Gen Cost:    1.383/0.709
# Minibatch: 0401 | Dis/Gen Cost:    1.373/0.702
# Minibatch: 0601 | Dis/Gen Cost:    1.363/0.686
# Minibatch: 0801 | Dis/Gen Cost:    1.460/0.680
# Epoch:     0120 | Dis/Gen AvgCost: 1.392/0.701
# Time elapsed: 14.87 min
# Minibatch: 0001 | Dis/Gen Cost:    1.398/0.705
# Minibatch: 0201 | Dis/Gen Cost:    1.415/0.664
# Minibatch: 0401 | Dis/Gen Cost:    1.354/0.712
# Minibatch: 0601 | Dis/Gen Cost:    1.382/0.726
# Minibatch: 0801 | Dis/Gen Cost:    1.458/0.690
# Epoch:     0121 | Dis/Gen AvgCost: 1.390/0.700
# Time elapsed: 15.00 min
# Minibatch: 0001 | Dis/Gen Cost:    1.416/0.691
# Minibatch: 0201 | Dis/Gen Cost:    1.365/0.722
# Minibatch: 0401 | Dis/Gen Cost:    1.361/0.736
# Minibatch: 0601 | Dis/Gen Cost:    1.392/0.714
# Minibatch: 0801 | Dis/Gen Cost:    1.393/0.698
# Epoch:     0122 | Dis/Gen AvgCost: 1.389/0.701
# Time elapsed: 15.12 min
# Minibatch: 0001 | Dis/Gen Cost:    1.420/0.675
# Minibatch: 0201 | Dis/Gen Cost:    1.443/0.703
# Minibatch: 0401 | Dis/Gen Cost:    1.388/0.708
# Minibatch: 0601 | Dis/Gen Cost:    1.370/0.701
# Minibatch: 0801 | Dis/Gen Cost:    1.385/0.702
# Epoch:     0123 | Dis/Gen AvgCost: 1.391/0.700
# Time elapsed: 15.25 min
# Minibatch: 0001 | Dis/Gen Cost:    1.382/0.700
# Minibatch: 0201 | Dis/Gen Cost:    1.386/0.677
# Minibatch: 0401 | Dis/Gen Cost:    1.385/0.701
# Minibatch: 0601 | Dis/Gen Cost:    1.385/0.718
# Minibatch: 0801 | Dis/Gen Cost:    1.387/0.699
# Epoch:     0124 | Dis/Gen AvgCost: 1.391/0.701
# Time elapsed: 15.37 min
# Minibatch: 0001 | Dis/Gen Cost:    1.399/0.724
# Minibatch: 0201 | Dis/Gen Cost:    1.390/0.693
# Minibatch: 0401 | Dis/Gen Cost:    1.403/0.705
# Minibatch: 0601 | Dis/Gen Cost:    1.384/0.701
# Minibatch: 0801 | Dis/Gen Cost:    1.367/0.713
# Epoch:     0125 | Dis/Gen AvgCost: 1.391/0.700
# Time elapsed: 15.50 min
# Minibatch: 0001 | Dis/Gen Cost:    1.407/0.708
# Minibatch: 0201 | Dis/Gen Cost:    1.378/0.700
# Minibatch: 0401 | Dis/Gen Cost:    1.374/0.717
# Minibatch: 0601 | Dis/Gen Cost:    1.388/0.705
# Minibatch: 0801 | Dis/Gen Cost:    1.359/0.722
# Epoch:     0126 | Dis/Gen AvgCost: 1.391/0.700
# Time elapsed: 15.62 min
# Minibatch: 0001 | Dis/Gen Cost:    1.390/0.685
# Minibatch: 0201 | Dis/Gen Cost:    1.384/0.712
# Minibatch: 0401 | Dis/Gen Cost:    1.412/0.687
# Minibatch: 0601 | Dis/Gen Cost:    1.397/0.696
# Minibatch: 0801 | Dis/Gen Cost:    1.412/0.706
# Epoch:     0127 | Dis/Gen AvgCost: 1.391/0.701
# Time elapsed: 15.74 min
# Minibatch: 0001 | Dis/Gen Cost:    1.403/0.702
# Minibatch: 0201 | Dis/Gen Cost:    1.420/0.679
# Minibatch: 0401 | Dis/Gen Cost:    1.384/0.711
# Minibatch: 0601 | Dis/Gen Cost:    1.390/0.704
# Minibatch: 0801 | Dis/Gen Cost:    1.364/0.711
# Epoch:     0128 | Dis/Gen AvgCost: 1.390/0.700
# Time elapsed: 15.87 min
# Minibatch: 0001 | Dis/Gen Cost:    1.387/0.700
# Minibatch: 0201 | Dis/Gen Cost:    1.382/0.704
# Minibatch: 0401 | Dis/Gen Cost:    1.395/0.693
# Minibatch: 0601 | Dis/Gen Cost:    1.376/0.701
# Minibatch: 0801 | Dis/Gen Cost:    1.397/0.696
# Epoch:     0129 | Dis/Gen AvgCost: 1.389/0.700
# Time elapsed: 15.99 min
# Minibatch: 0001 | Dis/Gen Cost:    1.315/0.729
# Minibatch: 0201 | Dis/Gen Cost:    1.404/0.691
# Minibatch: 0401 | Dis/Gen Cost:    1.365/0.695
# Minibatch: 0601 | Dis/Gen Cost:    1.386/0.705
# Minibatch: 0801 | Dis/Gen Cost:    1.378/0.713
# Epoch:     0130 | Dis/Gen AvgCost: 1.390/0.700
# Time elapsed: 16.11 min
# Minibatch: 0001 | Dis/Gen Cost:    1.418/0.677
# Minibatch: 0201 | Dis/Gen Cost:    1.335/0.727
# Minibatch: 0401 | Dis/Gen Cost:    1.402/0.682
# Minibatch: 0601 | Dis/Gen Cost:    1.373/0.712
# Minibatch: 0801 | Dis/Gen Cost:    1.409/0.701
# Epoch:     0131 | Dis/Gen AvgCost: 1.392/0.699
# Time elapsed: 16.24 min
# Minibatch: 0001 | Dis/Gen Cost:    1.392/0.697
# Minibatch: 0201 | Dis/Gen Cost:    1.361/0.706
# Minibatch: 0401 | Dis/Gen Cost:    1.381/0.722
# Minibatch: 0601 | Dis/Gen Cost:    1.398/0.697
# Minibatch: 0801 | Dis/Gen Cost:    1.387/0.706
# Epoch:     0132 | Dis/Gen AvgCost: 1.389/0.700
# Time elapsed: 16.36 min
# Minibatch: 0001 | Dis/Gen Cost:    1.382/0.706
# Minibatch: 0201 | Dis/Gen Cost:    1.364/0.704
# Minibatch: 0401 | Dis/Gen Cost:    1.404/0.686
# Minibatch: 0601 | Dis/Gen Cost:    1.378/0.679
# Minibatch: 0801 | Dis/Gen Cost:    1.388/0.723
# Epoch:     0133 | Dis/Gen AvgCost: 1.392/0.698
# Time elapsed: 16.49 min
# Minibatch: 0001 | Dis/Gen Cost:    1.394/0.681
# Minibatch: 0201 | Dis/Gen Cost:    1.370/0.695
# Minibatch: 0401 | Dis/Gen Cost:    1.416/0.672
# Minibatch: 0601 | Dis/Gen Cost:    1.401/0.690
# Minibatch: 0801 | Dis/Gen Cost:    1.388/0.698
# Epoch:     0134 | Dis/Gen AvgCost: 1.391/0.700
# Time elapsed: 16.61 min
# Minibatch: 0001 | Dis/Gen Cost:    1.391/0.692
# Minibatch: 0201 | Dis/Gen Cost:    1.409/0.694
# Minibatch: 0401 | Dis/Gen Cost:    1.391/0.699
# Minibatch: 0601 | Dis/Gen Cost:    1.401/0.700
# Minibatch: 0801 | Dis/Gen Cost:    1.380/0.712
# Epoch:     0135 | Dis/Gen AvgCost: 1.391/0.699
# Time elapsed: 16.73 min
# Minibatch: 0001 | Dis/Gen Cost:    1.370/0.700
# Minibatch: 0201 | Dis/Gen Cost:    1.375/0.704
# Minibatch: 0401 | Dis/Gen Cost:    1.395/0.703
# Minibatch: 0601 | Dis/Gen Cost:    1.380/0.703
# Minibatch: 0801 | Dis/Gen Cost:    1.401/0.694
# Epoch:     0136 | Dis/Gen AvgCost: 1.393/0.696
# Time elapsed: 16.86 min
# Minibatch: 0001 | Dis/Gen Cost:    1.378/0.707
# Minibatch: 0201 | Dis/Gen Cost:    1.398/0.703
# Minibatch: 0401 | Dis/Gen Cost:    1.372/0.702
# Minibatch: 0601 | Dis/Gen Cost:    1.371/0.690
# Minibatch: 0801 | Dis/Gen Cost:    1.377/0.710
# Epoch:     0137 | Dis/Gen AvgCost: 1.391/0.698
# Time elapsed: 16.98 min
# Minibatch: 0001 | Dis/Gen Cost:    1.388/0.712
# Minibatch: 0201 | Dis/Gen Cost:    1.406/0.693
# Minibatch: 0401 | Dis/Gen Cost:    1.385/0.699
# Minibatch: 0601 | Dis/Gen Cost:    1.366/0.718
# Minibatch: 0801 | Dis/Gen Cost:    1.395/0.677
# Epoch:     0138 | Dis/Gen AvgCost: 1.392/0.697
# Time elapsed: 17.10 min
# Minibatch: 0001 | Dis/Gen Cost:    1.402/0.692
# Minibatch: 0201 | Dis/Gen Cost:    1.374/0.714
# Minibatch: 0401 | Dis/Gen Cost:    1.416/0.677
# Minibatch: 0601 | Dis/Gen Cost:    1.411/0.681
# Minibatch: 0801 | Dis/Gen Cost:    1.359/0.714
# Epoch:     0139 | Dis/Gen AvgCost: 1.390/0.699
# Time elapsed: 17.23 min
# Minibatch: 0001 | Dis/Gen Cost:    1.366/0.699
# Minibatch: 0201 | Dis/Gen Cost:    1.358/0.700
# Minibatch: 0401 | Dis/Gen Cost:    1.422/0.677
# Minibatch: 0601 | Dis/Gen Cost:    1.407/0.692
# Minibatch: 0801 | Dis/Gen Cost:    1.403/0.685
# Epoch:     0140 | Dis/Gen AvgCost: 1.391/0.699
# Time elapsed: 17.35 min
# Minibatch: 0001 | Dis/Gen Cost:    1.394/0.694
# Minibatch: 0201 | Dis/Gen Cost:    1.383/0.710
# Minibatch: 0401 | Dis/Gen Cost:    1.394/0.693
# Minibatch: 0601 | Dis/Gen Cost:    1.404/0.704
# Minibatch: 0801 | Dis/Gen Cost:    1.349/0.705
# Epoch:     0141 | Dis/Gen AvgCost: 1.392/0.698
# Time elapsed: 17.48 min
# Minibatch: 0001 | Dis/Gen Cost:    1.372/0.700
# Minibatch: 0201 | Dis/Gen Cost:    1.376/0.703
# Minibatch: 0401 | Dis/Gen Cost:    1.391/0.688
# Minibatch: 0601 | Dis/Gen Cost:    1.401/0.693
# Minibatch: 0801 | Dis/Gen Cost:    1.394/0.697
# Epoch:     0142 | Dis/Gen AvgCost: 1.391/0.699
# Time elapsed: 17.60 min
# Minibatch: 0001 | Dis/Gen Cost:    1.396/0.705
# Minibatch: 0201 | Dis/Gen Cost:    1.376/0.704
# Minibatch: 0401 | Dis/Gen Cost:    1.405/0.675
# Minibatch: 0601 | Dis/Gen Cost:    1.419/0.681
# Minibatch: 0801 | Dis/Gen Cost:    1.399/0.697
# Epoch:     0143 | Dis/Gen AvgCost: 1.390/0.699
# Time elapsed: 17.72 min
# Minibatch: 0001 | Dis/Gen Cost:    1.408/0.676
# Minibatch: 0201 | Dis/Gen Cost:    1.375/0.688
# Minibatch: 0401 | Dis/Gen Cost:    1.364/0.716
# Minibatch: 0601 | Dis/Gen Cost:    1.404/0.695
# Minibatch: 0801 | Dis/Gen Cost:    1.406/0.691
# Epoch:     0144 | Dis/Gen AvgCost: 1.390/0.698
# Time elapsed: 17.85 min
# Minibatch: 0001 | Dis/Gen Cost:    1.391/0.708
# Minibatch: 0201 | Dis/Gen Cost:    1.407/0.704
# Minibatch: 0401 | Dis/Gen Cost:    1.410/0.699
# Minibatch: 0601 | Dis/Gen Cost:    1.364/0.721
# Minibatch: 0801 | Dis/Gen Cost:    1.408/0.681
# Epoch:     0145 | Dis/Gen AvgCost: 1.388/0.699
# Time elapsed: 17.97 min
# Minibatch: 0001 | Dis/Gen Cost:    1.388/0.698
# Minibatch: 0201 | Dis/Gen Cost:    1.382/0.712
# Minibatch: 0401 | Dis/Gen Cost:    1.402/0.690
# Minibatch: 0601 | Dis/Gen Cost:    1.373/0.701
# Minibatch: 0801 | Dis/Gen Cost:    1.387/0.696
# Epoch:     0146 | Dis/Gen AvgCost: 1.390/0.698
# Time elapsed: 18.10 min
# Minibatch: 0001 | Dis/Gen Cost:    1.377/0.696
# Minibatch: 0201 | Dis/Gen Cost:    1.391/0.700
# Minibatch: 0401 | Dis/Gen Cost:    1.417/0.680
# Minibatch: 0601 | Dis/Gen Cost:    1.368/0.705
# Minibatch: 0801 | Dis/Gen Cost:    1.422/0.679
# Epoch:     0147 | Dis/Gen AvgCost: 1.391/0.698
# Time elapsed: 18.22 min
# Minibatch: 0001 | Dis/Gen Cost:    1.362/0.707
# Minibatch: 0201 | Dis/Gen Cost:    1.383/0.700
# Minibatch: 0401 | Dis/Gen Cost:    1.406/0.686
# Minibatch: 0601 | Dis/Gen Cost:    1.379/0.700
# Minibatch: 0801 | Dis/Gen Cost:    1.380/0.699
# Epoch:     0148 | Dis/Gen AvgCost: 1.389/0.699
# Time elapsed: 18.34 min
# Minibatch: 0001 | Dis/Gen Cost:    1.400/0.683
# Minibatch: 0201 | Dis/Gen Cost:    1.381/0.685
# Minibatch: 0401 | Dis/Gen Cost:    1.378/0.692
# Minibatch: 0601 | Dis/Gen Cost:    1.392/0.694
# Minibatch: 0801 | Dis/Gen Cost:    1.397/0.698
# Epoch:     0149 | Dis/Gen AvgCost: 1.390/0.698
# Time elapsed: 18.47 min
# Minibatch: 0001 | Dis/Gen Cost:    1.400/0.682
# Minibatch: 0201 | Dis/Gen Cost:    1.388/0.684
# Minibatch: 0401 | Dis/Gen Cost:    1.414/0.690
# Minibatch: 0601 | Dis/Gen Cost:    1.402/0.683
# Minibatch: 0801 | Dis/Gen Cost:    1.327/0.729
# Epoch:     0150 | Dis/Gen AvgCost: 1.391/0.697
# Time elapsed: 18.59 min
# Minibatch: 0001 | Dis/Gen Cost:    1.366/0.712
# Minibatch: 0201 | Dis/Gen Cost:    1.386/0.689
# Minibatch: 0401 | Dis/Gen Cost:    1.409/0.696
# Minibatch: 0601 | Dis/Gen Cost:    1.404/0.699
# Minibatch: 0801 | Dis/Gen Cost:    1.372/0.693
# Epoch:     0151 | Dis/Gen AvgCost: 1.390/0.699
# Time elapsed: 18.72 min
# Minibatch: 0001 | Dis/Gen Cost:    1.388/0.702
# Minibatch: 0201 | Dis/Gen Cost:    1.342/0.711
# Minibatch: 0401 | Dis/Gen Cost:    1.370/0.690
# Minibatch: 0601 | Dis/Gen Cost:    1.422/0.699
# Minibatch: 0801 | Dis/Gen Cost:    1.408/0.684
# Epoch:     0152 | Dis/Gen AvgCost: 1.390/0.697
# Time elapsed: 18.84 min
# Minibatch: 0001 | Dis/Gen Cost:    1.382/0.692
# Minibatch: 0201 | Dis/Gen Cost:    1.410/0.690
# Minibatch: 0401 | Dis/Gen Cost:    1.401/0.705
# Minibatch: 0601 | Dis/Gen Cost:    1.387/0.689
# Minibatch: 0801 | Dis/Gen Cost:    1.374/0.714
# Epoch:     0153 | Dis/Gen AvgCost: 1.391/0.697
# Time elapsed: 18.96 min
# Minibatch: 0001 | Dis/Gen Cost:    1.407/0.697
# Minibatch: 0201 | Dis/Gen Cost:    1.373/0.694
# Minibatch: 0401 | Dis/Gen Cost:    1.394/0.686
# Minibatch: 0601 | Dis/Gen Cost:    1.402/0.678
# Minibatch: 0801 | Dis/Gen Cost:    1.400/0.700
# Epoch:     0154 | Dis/Gen AvgCost: 1.389/0.698
# Time elapsed: 19.09 min
# Minibatch: 0001 | Dis/Gen Cost:    1.396/0.680
# Minibatch: 0201 | Dis/Gen Cost:    1.390/0.692
# Minibatch: 0401 | Dis/Gen Cost:    1.393/0.711
# Minibatch: 0601 | Dis/Gen Cost:    1.369/0.692
# Minibatch: 0801 | Dis/Gen Cost:    1.396/0.696
# Epoch:     0155 | Dis/Gen AvgCost: 1.391/0.697
# Time elapsed: 19.21 min
# Minibatch: 0001 | Dis/Gen Cost:    1.398/0.687
# Minibatch: 0201 | Dis/Gen Cost:    1.397/0.696
# Minibatch: 0401 | Dis/Gen Cost:    1.364/0.709
# Minibatch: 0601 | Dis/Gen Cost:    1.370/0.694
# Minibatch: 0801 | Dis/Gen Cost:    1.399/0.687
# Epoch:     0156 | Dis/Gen AvgCost: 1.391/0.697
# Time elapsed: 19.33 min
# Minibatch: 0001 | Dis/Gen Cost:    1.376/0.708
# Minibatch: 0201 | Dis/Gen Cost:    1.408/0.701
# Minibatch: 0401 | Dis/Gen Cost:    1.419/0.672
# Minibatch: 0601 | Dis/Gen Cost:    1.391/0.693
# Minibatch: 0801 | Dis/Gen Cost:    1.404/0.685
# Epoch:     0157 | Dis/Gen AvgCost: 1.389/0.698
# Time elapsed: 19.46 min
# Minibatch: 0001 | Dis/Gen Cost:    1.371/0.700
# Minibatch: 0201 | Dis/Gen Cost:    1.380/0.695
# Minibatch: 0401 | Dis/Gen Cost:    1.377/0.722
# Minibatch: 0601 | Dis/Gen Cost:    1.371/0.700
# Minibatch: 0801 | Dis/Gen Cost:    1.414/0.672
# Epoch:     0158 | Dis/Gen AvgCost: 1.390/0.698
# Time elapsed: 19.58 min
# Minibatch: 0001 | Dis/Gen Cost:    1.406/0.704
# Minibatch: 0201 | Dis/Gen Cost:    1.372/0.696
# Minibatch: 0401 | Dis/Gen Cost:    1.376/0.697
# Minibatch: 0601 | Dis/Gen Cost:    1.393/0.686
# Minibatch: 0801 | Dis/Gen Cost:    1.376/0.726
# Epoch:     0159 | Dis/Gen AvgCost: 1.389/0.697
# Time elapsed: 19.71 min
# Minibatch: 0001 | Dis/Gen Cost:    1.415/0.675
# Minibatch: 0201 | Dis/Gen Cost:    1.379/0.706
# Minibatch: 0401 | Dis/Gen Cost:    1.382/0.711
# Minibatch: 0601 | Dis/Gen Cost:    1.376/0.710
# Minibatch: 0801 | Dis/Gen Cost:    1.387/0.682
# Epoch:     0160 | Dis/Gen AvgCost: 1.391/0.697
# Time elapsed: 19.83 min
# Minibatch: 0001 | Dis/Gen Cost:    1.386/0.701
# Minibatch: 0201 | Dis/Gen Cost:    1.379/0.709
# Minibatch: 0401 | Dis/Gen Cost:    1.402/0.691
# Minibatch: 0601 | Dis/Gen Cost:    1.356/0.723
# Minibatch: 0801 | Dis/Gen Cost:    1.394/0.696
# Epoch:     0161 | Dis/Gen AvgCost: 1.387/0.699
# Time elapsed: 19.95 min
# Minibatch: 0001 | Dis/Gen Cost:    1.397/0.683
# Minibatch: 0201 | Dis/Gen Cost:    1.371/0.710
# Minibatch: 0401 | Dis/Gen Cost:    1.364/0.705
# Minibatch: 0601 | Dis/Gen Cost:    1.350/0.707
# Minibatch: 0801 | Dis/Gen Cost:    1.393/0.699
# Epoch:     0162 | Dis/Gen AvgCost: 1.389/0.697
# Time elapsed: 20.08 min
# Minibatch: 0001 | Dis/Gen Cost:    1.389/0.708
# Minibatch: 0201 | Dis/Gen Cost:    1.402/0.692
# Minibatch: 0401 | Dis/Gen Cost:    1.360/0.710
# Minibatch: 0601 | Dis/Gen Cost:    1.359/0.720
# Minibatch: 0801 | Dis/Gen Cost:    1.374/0.704
# Epoch:     0163 | Dis/Gen AvgCost: 1.389/0.698
# Time elapsed: 20.20 min
# Minibatch: 0001 | Dis/Gen Cost:    1.399/0.683
# Minibatch: 0201 | Dis/Gen Cost:    1.401/0.678
# Minibatch: 0401 | Dis/Gen Cost:    1.373/0.697
# Minibatch: 0601 | Dis/Gen Cost:    1.407/0.680
# Minibatch: 0801 | Dis/Gen Cost:    1.407/0.685
# Epoch:     0164 | Dis/Gen AvgCost: 1.391/0.696
# Time elapsed: 20.33 min
# Minibatch: 0001 | Dis/Gen Cost:    1.403/0.696
# Minibatch: 0201 | Dis/Gen Cost:    1.434/0.684
# Minibatch: 0401 | Dis/Gen Cost:    1.377/0.706
# Minibatch: 0601 | Dis/Gen Cost:    1.385/0.700
# Minibatch: 0801 | Dis/Gen Cost:    1.371/0.695
# Epoch:     0165 | Dis/Gen AvgCost: 1.388/0.698
# Time elapsed: 20.45 min
# Minibatch: 0001 | Dis/Gen Cost:    1.402/0.690
# Minibatch: 0201 | Dis/Gen Cost:    1.366/0.704
# Minibatch: 0401 | Dis/Gen Cost:    1.393/0.697
# Minibatch: 0601 | Dis/Gen Cost:    1.388/0.703
# Minibatch: 0801 | Dis/Gen Cost:    1.373/0.697
# Epoch:     0166 | Dis/Gen AvgCost: 1.390/0.697
# Time elapsed: 20.57 min
# Minibatch: 0001 | Dis/Gen Cost:    1.383/0.700
# Minibatch: 0201 | Dis/Gen Cost:    1.387/0.696
# Minibatch: 0401 | Dis/Gen Cost:    1.377/0.698
# Minibatch: 0601 | Dis/Gen Cost:    1.395/0.696
# Minibatch: 0801 | Dis/Gen Cost:    1.417/0.686
# Epoch:     0167 | Dis/Gen AvgCost: 1.389/0.697
# Time elapsed: 20.70 min
# Minibatch: 0001 | Dis/Gen Cost:    1.377/0.703
# Minibatch: 0201 | Dis/Gen Cost:    1.399/0.682
# Minibatch: 0401 | Dis/Gen Cost:    1.377/0.714
# Minibatch: 0601 | Dis/Gen Cost:    1.381/0.695
# Minibatch: 0801 | Dis/Gen Cost:    1.425/0.681
# Epoch:     0168 | Dis/Gen AvgCost: 1.390/0.697
# Time elapsed: 20.82 min
# Minibatch: 0001 | Dis/Gen Cost:    1.410/0.684
# Minibatch: 0201 | Dis/Gen Cost:    1.395/0.696
# Minibatch: 0401 | Dis/Gen Cost:    1.403/0.692
# Minibatch: 0601 | Dis/Gen Cost:    1.386/0.694
# Minibatch: 0801 | Dis/Gen Cost:    1.420/0.675
# Epoch:     0169 | Dis/Gen AvgCost: 1.389/0.697
# Time elapsed: 20.95 min
# Minibatch: 0001 | Dis/Gen Cost:    1.401/0.691
# Minibatch: 0201 | Dis/Gen Cost:    1.411/0.692
# Minibatch: 0401 | Dis/Gen Cost:    1.387/0.699
# Minibatch: 0601 | Dis/Gen Cost:    1.398/0.678
# Minibatch: 0801 | Dis/Gen Cost:    1.398/0.693
# Epoch:     0170 | Dis/Gen AvgCost: 1.391/0.698
# Time elapsed: 21.07 min
# Minibatch: 0001 | Dis/Gen Cost:    1.398/0.699
# Minibatch: 0201 | Dis/Gen Cost:    1.379/0.678
# Minibatch: 0401 | Dis/Gen Cost:    1.383/0.708
# Minibatch: 0601 | Dis/Gen Cost:    1.393/0.702
# Minibatch: 0801 | Dis/Gen Cost:    1.407/0.689
# Epoch:     0171 | Dis/Gen AvgCost: 1.390/0.696
# Time elapsed: 21.20 min
# Minibatch: 0001 | Dis/Gen Cost:    1.392/0.703
# Minibatch: 0201 | Dis/Gen Cost:    1.377/0.700
# Minibatch: 0401 | Dis/Gen Cost:    1.361/0.706
# Minibatch: 0601 | Dis/Gen Cost:    1.389/0.701
# Minibatch: 0801 | Dis/Gen Cost:    1.374/0.703
# Epoch:     0172 | Dis/Gen AvgCost: 1.389/0.698
# Time elapsed: 21.32 min
# Minibatch: 0001 | Dis/Gen Cost:    1.378/0.689
# Minibatch: 0201 | Dis/Gen Cost:    1.419/0.685
# Minibatch: 0401 | Dis/Gen Cost:    1.381/0.698
# Minibatch: 0601 | Dis/Gen Cost:    1.403/0.693
# Minibatch: 0801 | Dis/Gen Cost:    1.386/0.691
# Epoch:     0173 | Dis/Gen AvgCost: 1.390/0.697
# Time elapsed: 21.44 min
# Minibatch: 0001 | Dis/Gen Cost:    1.408/0.669
# Minibatch: 0201 | Dis/Gen Cost:    1.389/0.690
# Minibatch: 0401 | Dis/Gen Cost:    1.361/0.710
# Minibatch: 0601 | Dis/Gen Cost:    1.386/0.702
# Minibatch: 0801 | Dis/Gen Cost:    1.370/0.703
# Epoch:     0174 | Dis/Gen AvgCost: 1.391/0.696
# Time elapsed: 21.57 min
# Minibatch: 0001 | Dis/Gen Cost:    1.372/0.709
# Minibatch: 0201 | Dis/Gen Cost:    1.387/0.688
# Minibatch: 0401 | Dis/Gen Cost:    1.372/0.703
# Minibatch: 0601 | Dis/Gen Cost:    1.371/0.719
# Minibatch: 0801 | Dis/Gen Cost:    1.427/0.673
# Epoch:     0175 | Dis/Gen AvgCost: 1.391/0.696
# Time elapsed: 21.69 min
# Minibatch: 0001 | Dis/Gen Cost:    1.396/0.684
# Minibatch: 0201 | Dis/Gen Cost:    1.373/0.698
# Minibatch: 0401 | Dis/Gen Cost:    1.382/0.695
# Minibatch: 0601 | Dis/Gen Cost:    1.372/0.702
# Minibatch: 0801 | Dis/Gen Cost:    1.392/0.689
# Epoch:     0176 | Dis/Gen AvgCost: 1.390/0.697
# Time elapsed: 21.81 min
# Minibatch: 0001 | Dis/Gen Cost:    1.396/0.688
# Minibatch: 0201 | Dis/Gen Cost:    1.398/0.696
# Minibatch: 0401 | Dis/Gen Cost:    1.372/0.697
# Minibatch: 0601 | Dis/Gen Cost:    1.362/0.710
# Minibatch: 0801 | Dis/Gen Cost:    1.410/0.686
# Epoch:     0177 | Dis/Gen AvgCost: 1.389/0.697
# Time elapsed: 21.94 min
# Minibatch: 0001 | Dis/Gen Cost:    1.411/0.687
# Minibatch: 0201 | Dis/Gen Cost:    1.376/0.700
# Minibatch: 0401 | Dis/Gen Cost:    1.416/0.699
# Minibatch: 0601 | Dis/Gen Cost:    1.397/0.698
# Minibatch: 0801 | Dis/Gen Cost:    1.389/0.694
# Epoch:     0178 | Dis/Gen AvgCost: 1.391/0.696
# Time elapsed: 22.06 min
# Minibatch: 0001 | Dis/Gen Cost:    1.399/0.698
# Minibatch: 0201 | Dis/Gen Cost:    1.390/0.707
# Minibatch: 0401 | Dis/Gen Cost:    1.381/0.696
# Minibatch: 0601 | Dis/Gen Cost:    1.389/0.701
# Minibatch: 0801 | Dis/Gen Cost:    1.383/0.703
# Epoch:     0179 | Dis/Gen AvgCost: 1.391/0.695
# Time elapsed: 22.18 min
# Minibatch: 0001 | Dis/Gen Cost:    1.379/0.695
# Minibatch: 0201 | Dis/Gen Cost:    1.358/0.725
# Minibatch: 0401 | Dis/Gen Cost:    1.391/0.698
# Minibatch: 0601 | Dis/Gen Cost:    1.396/0.688
# Minibatch: 0801 | Dis/Gen Cost:    1.393/0.692
# Epoch:     0180 | Dis/Gen AvgCost: 1.390/0.696
# Time elapsed: 22.31 min
# Minibatch: 0001 | Dis/Gen Cost:    1.391/0.692
# Minibatch: 0201 | Dis/Gen Cost:    1.398/0.681
# Minibatch: 0401 | Dis/Gen Cost:    1.397/0.690
# Minibatch: 0601 | Dis/Gen Cost:    1.400/0.692
# Minibatch: 0801 | Dis/Gen Cost:    1.404/0.701
# Epoch:     0181 | Dis/Gen AvgCost: 1.390/0.696
# Time elapsed: 22.43 min
# Minibatch: 0001 | Dis/Gen Cost:    1.366/0.711
# Minibatch: 0201 | Dis/Gen Cost:    1.398/0.696
# Minibatch: 0401 | Dis/Gen Cost:    1.405/0.689
# Minibatch: 0601 | Dis/Gen Cost:    1.390/0.696
# Minibatch: 0801 | Dis/Gen Cost:    1.390/0.703
# Epoch:     0182 | Dis/Gen AvgCost: 1.390/0.696
# Time elapsed: 22.56 min
# Minibatch: 0001 | Dis/Gen Cost:    1.383/0.694
# Minibatch: 0201 | Dis/Gen Cost:    1.376/0.700
# Minibatch: 0401 | Dis/Gen Cost:    1.398/0.705
# Minibatch: 0601 | Dis/Gen Cost:    1.395/0.691
# Minibatch: 0801 | Dis/Gen Cost:    1.387/0.700
# Epoch:     0183 | Dis/Gen AvgCost: 1.389/0.696
# Time elapsed: 22.68 min
# Minibatch: 0001 | Dis/Gen Cost:    1.410/0.681
# Minibatch: 0201 | Dis/Gen Cost:    1.360/0.707
# Minibatch: 0401 | Dis/Gen Cost:    1.388/0.694
# Minibatch: 0601 | Dis/Gen Cost:    1.412/0.686
# Minibatch: 0801 | Dis/Gen Cost:    1.385/0.703
# Epoch:     0184 | Dis/Gen AvgCost: 1.390/0.696
# Time elapsed: 22.80 min
# Minibatch: 0001 | Dis/Gen Cost:    1.404/0.680
# Minibatch: 0201 | Dis/Gen Cost:    1.401/0.691
# Minibatch: 0401 | Dis/Gen Cost:    1.404/0.694
# Minibatch: 0601 | Dis/Gen Cost:    1.404/0.696
# Minibatch: 0801 | Dis/Gen Cost:    1.392/0.695
# Epoch:     0185 | Dis/Gen AvgCost: 1.390/0.696
# Time elapsed: 22.93 min
# Minibatch: 0001 | Dis/Gen Cost:    1.375/0.703
# Minibatch: 0201 | Dis/Gen Cost:    1.411/0.694
# Minibatch: 0401 | Dis/Gen Cost:    1.393/0.673
# Minibatch: 0601 | Dis/Gen Cost:    1.372/0.707
# Minibatch: 0801 | Dis/Gen Cost:    1.392/0.697
# Epoch:     0186 | Dis/Gen AvgCost: 1.391/0.696
# Time elapsed: 23.05 min
# Minibatch: 0001 | Dis/Gen Cost:    1.397/0.695
# Minibatch: 0201 | Dis/Gen Cost:    1.396/0.699
# Minibatch: 0401 | Dis/Gen Cost:    1.395/0.687
# Minibatch: 0601 | Dis/Gen Cost:    1.412/0.681
# Minibatch: 0801 | Dis/Gen Cost:    1.390/0.703
# Epoch:     0187 | Dis/Gen AvgCost: 1.390/0.696
# Time elapsed: 23.18 min
# Minibatch: 0001 | Dis/Gen Cost:    1.404/0.684
# Minibatch: 0201 | Dis/Gen Cost:    1.386/0.711
# Minibatch: 0401 | Dis/Gen Cost:    1.379/0.704
# Minibatch: 0601 | Dis/Gen Cost:    1.386/0.698
# Minibatch: 0801 | Dis/Gen Cost:    1.387/0.692
# Epoch:     0188 | Dis/Gen AvgCost: 1.389/0.696
# Time elapsed: 23.30 min
# Minibatch: 0001 | Dis/Gen Cost:    1.403/0.682
# Minibatch: 0201 | Dis/Gen Cost:    1.456/0.662
# Minibatch: 0401 | Dis/Gen Cost:    1.364/0.710
# Minibatch: 0601 | Dis/Gen Cost:    1.382/0.693
# Minibatch: 0801 | Dis/Gen Cost:    1.380/0.703
# Epoch:     0189 | Dis/Gen AvgCost: 1.390/0.697
# Time elapsed: 23.42 min
# Minibatch: 0001 | Dis/Gen Cost:    1.402/0.693
# Minibatch: 0201 | Dis/Gen Cost:    1.403/0.679
# Minibatch: 0401 | Dis/Gen Cost:    1.407/0.685
# Minibatch: 0601 | Dis/Gen Cost:    1.378/0.700
# Minibatch: 0801 | Dis/Gen Cost:    1.392/0.693
# Epoch:     0190 | Dis/Gen AvgCost: 1.391/0.695
# Time elapsed: 23.55 min
# Minibatch: 0001 | Dis/Gen Cost:    1.369/0.689
# Minibatch: 0201 | Dis/Gen Cost:    1.371/0.704
# Minibatch: 0401 | Dis/Gen Cost:    1.389/0.691
# Minibatch: 0601 | Dis/Gen Cost:    1.390/0.698
# Minibatch: 0801 | Dis/Gen Cost:    1.381/0.704
# Epoch:     0191 | Dis/Gen AvgCost: 1.389/0.696
# Time elapsed: 23.67 min
# Minibatch: 0001 | Dis/Gen Cost:    1.396/0.700
# Minibatch: 0201 | Dis/Gen Cost:    1.380/0.704
# Minibatch: 0401 | Dis/Gen Cost:    1.373/0.707
# Minibatch: 0601 | Dis/Gen Cost:    1.392/0.691
# Minibatch: 0801 | Dis/Gen Cost:    1.395/0.702
# Epoch:     0192 | Dis/Gen AvgCost: 1.389/0.696
# Time elapsed: 23.79 min
# Minibatch: 0001 | Dis/Gen Cost:    1.380/0.711
# Minibatch: 0201 | Dis/Gen Cost:    1.369/0.709
# Minibatch: 0401 | Dis/Gen Cost:    1.387/0.698
# Minibatch: 0601 | Dis/Gen Cost:    1.369/0.689
# Minibatch: 0801 | Dis/Gen Cost:    1.387/0.705
# Epoch:     0193 | Dis/Gen AvgCost: 1.389/0.696
# Time elapsed: 23.92 min
# Minibatch: 0001 | Dis/Gen Cost:    1.416/0.688
# Minibatch: 0201 | Dis/Gen Cost:    1.402/0.692
# Minibatch: 0401 | Dis/Gen Cost:    1.370/0.711
# Minibatch: 0601 | Dis/Gen Cost:    1.395/0.697
# Minibatch: 0801 | Dis/Gen Cost:    1.395/0.702
# Epoch:     0194 | Dis/Gen AvgCost: 1.388/0.698
# Time elapsed: 24.04 min
# Minibatch: 0001 | Dis/Gen Cost:    1.387/0.695
# Minibatch: 0201 | Dis/Gen Cost:    1.387/0.709
# Minibatch: 0401 | Dis/Gen Cost:    1.398/0.681
# Minibatch: 0601 | Dis/Gen Cost:    1.375/0.709
# Minibatch: 0801 | Dis/Gen Cost:    1.397/0.691
# Epoch:     0195 | Dis/Gen AvgCost: 1.388/0.697
# Time elapsed: 24.17 min
# Minibatch: 0001 | Dis/Gen Cost:    1.391/0.690
# Minibatch: 0201 | Dis/Gen Cost:    1.386/0.714
# Minibatch: 0401 | Dis/Gen Cost:    1.402/0.687
# Minibatch: 0601 | Dis/Gen Cost:    1.398/0.692
# Minibatch: 0801 | Dis/Gen Cost:    1.407/0.684
# Epoch:     0196 | Dis/Gen AvgCost: 1.388/0.696
# Time elapsed: 24.29 min
# Minibatch: 0001 | Dis/Gen Cost:    1.371/0.706
# Minibatch: 0201 | Dis/Gen Cost:    1.406/0.687
# Minibatch: 0401 | Dis/Gen Cost:    1.381/0.701
# Minibatch: 0601 | Dis/Gen Cost:    1.432/0.683
# Minibatch: 0801 | Dis/Gen Cost:    1.396/0.691
# Epoch:     0197 | Dis/Gen AvgCost: 1.389/0.696
# Time elapsed: 24.41 min
# Minibatch: 0001 | Dis/Gen Cost:    1.384/0.700
# Minibatch: 0201 | Dis/Gen Cost:    1.401/0.690
# Minibatch: 0401 | Dis/Gen Cost:    1.399/0.711
# Minibatch: 0601 | Dis/Gen Cost:    1.418/0.681
# Minibatch: 0801 | Dis/Gen Cost:    1.385/0.696
# Epoch:     0198 | Dis/Gen AvgCost: 1.390/0.696
# Time elapsed: 24.54 min
# Minibatch: 0001 | Dis/Gen Cost:    1.380/0.706
# Minibatch: 0201 | Dis/Gen Cost:    1.387/0.693
# Minibatch: 0401 | Dis/Gen Cost:    1.388/0.690
# Minibatch: 0601 | Dis/Gen Cost:    1.403/0.689
# Minibatch: 0801 | Dis/Gen Cost:    1.398/0.702
# Epoch:     0199 | Dis/Gen AvgCost: 1.388/0.696
# Time elapsed: 24.66 min
# Minibatch: 0001 | Dis/Gen Cost:    1.388/0.699
# Minibatch: 0201 | Dis/Gen Cost:    1.409/0.684
# Minibatch: 0401 | Dis/Gen Cost:    1.377/0.716
# Minibatch: 0601 | Dis/Gen Cost:    1.384/0.696
# Minibatch: 0801 | Dis/Gen Cost:    1.383/0.689
# Epoch:     0200 | Dis/Gen AvgCost: 1.390/0.695
# Time elapsed: 24.79 min
# Total Training Time: 24.79 min

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(range(len(avg_costs['discriminator'])), 
         avg_costs['discriminator'], label='discriminator')
plt.plot(range(len(avg_costs['generator'])),
         avg_costs['generator'], label='generator')
plt.legend()
plt.show()

# %%
####################################
### RELOAD & GENERATE SAMPLE IMAGES
####################################


n_examples = 25

with tf.Session(graph=g) as sess:
    saver.restore(sess, save_path='./model/gan-conv.ckpt')

    batch_randsample = np.random.uniform(-1, 1, size=(n_examples, gen_input_size))
    new_examples = sess.run('generator/generator_outputs:0',
                            feed_dict={'generator_inputs:0': batch_randsample,
                                       'dropout:0': 0.0,
                                       'is_training:0': False})

fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(8, 8),
                         sharey=True, sharex=True)

for image, ax in zip(new_examples, axes.flatten()):
    ax.imshow(image.reshape((dis_input_size // 28, dis_input_size // 28)), cmap='binary')

plt.show()
# Out:
# W0628 05:11:24.199790 139655104055104 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
